# %% [markdown]
# # <b>데이터 전처리</b> Preprocessing

# %% [markdown]
# ## <b>0.0 라이브러리</b>

# %% [markdown]
# ### <b>0.1 사용 툴 / 라이브러리</b> (추후 정리)

# %%
# 로그 기록

import logging
logging.basicConfig(filename='./test.log', level=logging.DEBUG) #기본값은 warning (warning 이상의 로그만 출력됨)

# 로그 생성
logger = logging.getLogger()

# 로그의 출력 기준 설정
logger.setLevel(logging.DEBUG)

# log 출력 형식
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# log를 파일에 출력
file_handler = logging.FileHandler('my.log')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

logger.info("log info")

# %%
# 범용 라이브러리
import pandas as pd     # DataFrame, Series 및 데이터 분석
import numpy as np      # Array 및 
from tqdm import tqdm   # 진행상황 Progress Bar를 위한 tqdm library
import re               # Regular Expression 사용
import pickle           # 토큰화된 단어목록의 인덱스를 저장, 불러오기 위해 사용
from sklearn.model_selection import train_test_split # train, test split

# 토크나이징, 인코딩 관련 라이브러리
from eunjeon import Mecab           # Mecab 형태소 분석기의 한국어+윈도우용 버전인 은전한닢 프로젝트
from collections import Counter     
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


# 그래프 관련 라이브러리
import seaborn as sns
import matplotlib.pyplot as plt
import platform


# 한글 폰트 설정
if (platform.system() == 'Windows'):
    plt.rc('font', family='Malgun Gothic')
else:
    plt.rc('font', family='AppleGothic')


# 음수(-)가 깨지는 현상 방지
plt.rcParams['axes.unicode_minus'] = False 

logger.info("log info")

# %% [markdown]
# ## <b>1.0 데이터 불러오기</b>

# %%
# 실습용자료 불러와 csv로 저장

# train = pd.read_table("./data/1. 실습용자료.txt", encoding='CP949', sep='|') # 실습용자료의 구분자 '|'
# train.to_csv('./data/train.csv', index=False)


#  불러와 csv로 저장

# test = pd.read_table("./data/2. 모델개발용자료.txt", encoding='CP949', sep='|') # 모델개발용자료의 구분자 '|'
# test.to_csv('./data/test.csv', index=False)

# 데이터 불러오기

train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

logger.info("log info")

# %%
# 한국표준산업분류 딕셔너리 생성

cat_dic = pd.read_excel('./data/한국표준산업분류(10차)_국문.xlsx').iloc[2:,0:6]

cat_dic.rename(columns={'개정 분류체계(제10차 기준)':'대분류', 'Unnamed: 1':'대분류명', 
                        'Unnamed: 2': '중분류', 'Unnamed: 3': '중분류명',
                        'Unnamed: 4': '소분류', 'Unnamed: 5': '소분류명'}, inplace=True)

digit_1_df = cat_dic[['대분류', '대분류명']].dropna().reset_index(drop=True) # 대분류 'A' ~ 'U'
digit_2_df = cat_dic[['중분류', '중분류명']].dropna().reset_index(drop=True) # 중분류 1 ~ 99
digit_3_df = cat_dic[['소분류', '소분류명']].dropna().reset_index(drop=True) # 소분류 11 ~ 990

digit_1_dict = {} # 대분류 딕셔너리
digit_2_dict = {} # 중분류 딕셔너리
digit_3_dict = {} # 소분류 딕셔너리

for i in tqdm(range(len(digit_1_df)+len(digit_2_df)+len(digit_3_df))):

    if i < len(digit_1_df):
        digit_1_dict[digit_1_df.iloc[i]['대분류']] = digit_1_df.iloc[i]['대분류명']

    if i < len(digit_2_df):
        digit_2_dict[int(digit_2_df.iloc[i]['중분류'])] = digit_2_df.iloc[i]['중분류명']

    if i < len(digit_3_df):
        digit_3_dict[int(digit_3_df.iloc[i]['소분류'])] = digit_3_df.iloc[i]['소분류명']


# 생성된 딕셔너리 결과 확인

print(digit_1_dict, '\n', digit_2_dict, '\n', digit_3_dict)


# 생성된 딕셔너리 피클로 저장

with open('./data/dictionary/digit_1_dict.pickle', 'wb') as handle:
    pickle.dump(digit_1_dict, handle)

with open('./data/dictionary/digit_2_dict.pickle', 'wb') as handle:
    pickle.dump(digit_2_dict, handle)

with open('./data/dictionary/digit_3_dict.pickle', 'wb') as handle:
    pickle.dump(digit_3_dict, handle)

logger.info("log info")
# Out:
# 100%|██████████| 330/330 [00:00<00:00, 5862.90it/s]
# {'A': '농업, 임업 및 어업(01~03)', 'B': '광업(05~08)', 'C': '제조업(10~34)', 'D': '전기, 가스, 증기 및 공기 조절 공급업(35)', 'E': '수도, 하수 및 폐기물 처리, 원료 재생업(36~39)', 'F': '건설업(41~42)', 'G': '도매 및 소매업(45~47)', 'H': '운수 및 창고업(49~52)', 'I': '숙박 및 음식점업(55~56)', 'J': '정보통신업(58~63)', 'K': '금융 및 보험업(64~66)', 'L': '부동산업(68)', 'M': '전문, 과학 및 기술 서비스업(70~73)', 'N': '사업시설 관리, 사업 지원 및 임대 서비스업(74~76)', 'O': '공공 행정, 국방 및 사회보장 행정(84)', 'P': '교육 서비스업(85)', 'Q': '보건업 및 사회복지 서비스업(86~87)', 'R': '예술, 스포츠 및 여가관련 서비스업(90~91)', 'S': '협회 및 단체, 수리 및 기타 개인 서비스업(94~96)', 'T': '가구 내 고용활동 및 달리 분류되지 않은 자가 소비 생산활동(97~98)', 'U': '국제 및 외국기관(99)'}
#  {1: '농업', 2: '임업', 3: '어업', 5: '석탄, 원유 및 천연가스 광업', 6: '금속 광업', 7: '비금속광물 광업; 연료용 제외', 8: '광업 지원 서비스업', 10: '식료품 제조업', 11: '음료 제조업', 12: '담배 제조업', 13: '섬유제품 제조업; 의복 제외', 14: '의복, 의복 액세서리 및 모피제품 제조업', 15: '가죽, 가방 및 신발 제조업', 16: '목재 및 나무제품 제조업; 가구 제외', 17: '펄프, 종이 및 종이제품 제조업', 18: '인쇄 및 기록매체 복제업', 19: '코크스, 연탄 및 석유정제품 제조업', 20: '화학 물질 및 화학제품 제조업; 의약품 제외', 21: '의료용 물질 및 의약품 제조업', 22: '고무 및 플라스틱제품 제조업', 23: '비금속 광물제품 제조업', 24: '1차 금속 제조업', 25: '금속 가공제품 제조업; 기계 및 가구 제외', 26: '전자 부품, 컴퓨터, 영상, 음향 및 통신장비 제조업', 27: '의료, 정밀, 광학 기기 및 시계 제조업', 28: '전기장비 제조업', 29: '기타 기계 및 장비 제조업', 30: '자동차 및 트레일러 제조업', 31: '기타 운송장비 제조업', 32: '가구 제조업', 33: '기타 제품 제조업', 34: '산업용 기계 및 장비 수리업', 35: '전기, 가스, 증기 및 공기 조절 공급업', 36: '수도업', 37: '하수, 폐수 및 분뇨 처리업', 38: '폐기물 수집, 운반, 처리 및 원료 재생업', 39: '환경 정화 및 복원업', 41: '종합 건설업', 42: '전문직별 공사업', 45: '자동차 및 부품 판매업', 46: '도매 및 상품 중개업', 47: '소매업; 자동차 제외', 49: '육상 운송 및 파이프라인 운송업', 50: '수상 운송업', 51: '항공 운송업', 52: '창고 및 운송관련 서비스업', 55: '숙박업', 56: '음식점 및 주점업', 58: '출판업', 59: '영상ㆍ오디오 기록물 제작 및 배급업', 60: '방송업', 61: '우편 및 통신업', 62: '컴퓨터 프로그래밍, 시스템 통합 및 관리업', 63: '정보서비스업', 64: '금융업', 65: '보험 및 연금업', 66: '금융 및 보험관련 서비스업', 68: '부동산업', 70: '연구개발업', 71: '전문 서비스업', 72: '건축 기술, 엔지니어링 및 기타 과학기술 서비스업', 73: '기타 전문, 과학 및 기술 서비스업', 74: '사업시설 관리 및 조경 서비스업', 75: '사업 지원 서비스업', 76: '임대업; 부동산 제외', 84: '공공 행정, 국방 및 사회보장 행정', 85: '교육 서비스업', 86: '보건업', 87: '사회복지 서비스업', 90: '창작, 예술 및 여가관련 서비스업', 91: '스포츠 및 오락관련 서비스업', 94: '협회 및 단체', 95: '개인 및 소비용품 수리업', 96: '기타 개인 서비스업', 97: '가구 내 고용활동', 98: '달리 분류되지 않은 자가 소비를 위한 가구의 재화 및 서비스 생산활동', 99: '국제 및 외국기관'}
#  {11: '작물 재배업', 12: '축산업', 13: '작물재배 및 축산 복합농업', 14: '작물재배 및 축산 관련 서비스업', 15: '수렵 및 관련 서비스업', 20: '임업', 31: '어로 어업', 32: '양식어업 및 어업관련 서비스업', 51: '석탄 광업', 52: '원유 및 천연가스 채굴업', 61: '철 광업', 62: '비철금속 광업', 71: '토사석 광업', 72: '기타 비금속광물 광업', 80: '광업 지원 서비스업', 101: '도축, 육류 가공 및 저장 처리업', 102: '수산물 가공 및 저장 처리업', 103: '과실, 채소 가공 및 저장 처리업', 104: '동물성 및 식물성 유지 제조업', 105: '낙농제품 및 식용 빙과류 제조업', 106: '곡물 가공품, 전분 및 전분제품 제조업', 107: '기타 식품 제조업', 108: '동물용 사료 및 조제식품 제조업', 111: '알코올 음료 제조업', 112: '비알코올 음료 및 얼음 제조업', 120: '담배 제조업', 131: '방적 및 가공사 제조업', 132: '직물 직조 및 직물제품 제조업', 133: '편조 원단 제조업', 134: '섬유제품 염색, 정리 및 마무리 가공업', 139: '기타 섬유제품 제조업', 141: '봉제의복 제조업', 142: '모피제품 제조업', 143: '편조의복 제조업', 144: '의복 액세서리 제조업', 151: '가죽, 가방 및 유사 제품 제조업', 152: '신발 및 신발 부분품 제조업', 161: '제재 및 목재 가공업', 162: '나무제품 제조업', 163: '코르크 및 조물 제품 제조업', 171: '펄프, 종이 및 판지 제조업', 172: '골판지, 종이 상자 및 종이 용기 제조업', 179: '기타 종이 및 판지 제품 제조업', 181: '인쇄 및 인쇄관련 산업', 182: '기록매체 복제업', 191: '코크스 및 연탄 제조업', 192: '석유 정제품 제조업', 201: '기초 화학물질 제조업', 202: '합성고무 및 플라스틱 물질 제조업', 203: '비료, 농약 및 살균ㆍ살충제 제조업', 204: '기타 화학제품 제조업', 205: '화학섬유 제조업', 211: '기초 의약 물질 및 생물학적 제제 제조업', 212: '의약품 제조업', 213: '의료용품 및 기타 의약 관련제품 제조업', 221: '고무제품 제조업', 222: '플라스틱 제품 제조업', 231: '유리 및 유리제품 제조업', 232: '내화, 비내화 요업제품 제조업', 233: '시멘트, 석회, 플라스터 및 그 제품 제조업', 239: '기타 비금속 광물제품 제조업', 241: '1차 철강 제조업', 242: '1차 비철금속 제조업', 243: '금속 주조업', 251: '구조용 금속제품, 탱크 및 증기발생기 제조업', 252: '무기 및 총포탄 제조업', 259: '기타 금속 가공제품 제조업', 261: '반도체 제조업', 262: '전자 부품 제조업', 263: '컴퓨터 및 주변 장치 제조업', 264: '통신 및 방송장비 제조업', 265: '영상 및 음향 기기 제조업', 266: '마그네틱 및 광학 매체 제조업', 271: '의료용 기기 제조업', 272: '측정, 시험, 항해, 제어 및 기타 정밀 기기 제조업; 광학 기기 제외', 273: '사진장비 및 광학 기기 제조업', 274: '시계 및 시계 부품 제조업', 281: '전동기, 발전기 및 전기 변환ㆍ공급ㆍ제어 장치 제조업', 282: '일차전지 및 축전지 제조업', 283: '절연선 및 케이블 제조업', 284: '전구 및 조명장치 제조업', 285: '가정용 기기 제조업', 289: '기타 전기장비 제조업', 291: '일반 목적용 기계 제조업', 292: '특수 목적용 기계 제조업', 301: '자동차용 엔진 및 자동차 제조업', 302: '자동차 차체 및 트레일러 제조업', 303: '자동차 신품 부품 제조업', 304: '자동차 재제조 부품 제조업', 311: '선박 및 보트 건조업', 312: '철도장비 제조업', 313: '항공기, 우주선 및 부품 제조업', 319: '그 외 기타 운송장비 제조업', 320: '가구 제조업', 331: '귀금속 및 장신용품 제조업', 332: '악기 제조업', 333: '운동 및 경기용구 제조업', 334: '인형, 장난감 및 오락용품 제조업', 339: '그 외 기타 제품 제조업', 340: '산업용 기계 및 장비 수리업', 351: '전기업', 352: '연료용 가스 제조 및 배관공급업', 353: '증기, 냉ㆍ온수 및 공기 조절 공급업', 360: '수도업', 370: '하수, 폐수 및 분뇨 처리업', 381: '폐기물 수집, 운반업', 382: '폐기물 처리업', 383: '해체, 선별 및 원료 재생업', 390: '환경 정화 및 복원업', 411: '건물 건설업', 412: '토목 건설업', 421: '기반조성 및 시설물 축조관련 전문공사업', 422: '건물설비 설치 공사업', 423: '전기 및 통신 공사업', 424: '실내건축 및 건축마무리 공사업', 425: '시설물 유지관리 공사업', 426: '건설장비 운영업', 451: '자동차 판매업', 452: '자동차 부품 및 내장품 판매업', 453: '모터사이클 및 부품 판매업', 461: '상품 중개업', 462: '산업용 농ㆍ축산물 및 동ㆍ식물 도매업', 463: '음ㆍ식료품 및 담배 도매업', 464: '생활용품 도매업', 465: '기계장비 및 관련 물품 도매업', 466: '건축 자재, 철물 및 난방장치 도매업', 467: '기타 전문 도매업', 468: '상품 종합 도매업', 471: '종합 소매업', 472: '음ㆍ식료품 및 담배 소매업', 473: '가전제품 및 정보 통신장비 소매업', 474: '섬유, 의복, 신발 및 가죽제품 소매업', 475: '기타 생활용품 소매업', 476: '문화, 오락 및 여가 용품 소매업', 477: '연료 소매업', 478: '기타 상품 전문 소매업', 479: '무점포 소매업', 491: '철도 운송업', 492: '육상 여객 운송업', 493: '도로 화물 운송업', 494: '소화물 전문 운송업', 495: '파이프라인 운송업', 501: '해상 운송업', 502: '내륙 수상 및 항만 내 운송업', 511: '항공 여객 운송업', 512: '항공 화물 운송업', 521: '보관 및 창고업', 529: '기타 운송관련 서비스업', 551: '일반 및 생활 숙박시설 운영업', 559: '기타 숙박업', 561: '음식점업', 562: '주점 및 비알코올 음료점업', 581: '서적, 잡지 및 기타 인쇄물 출판업', 582: '소프트웨어 개발 및 공급업', 591: '영화, 비디오물, 방송 프로그램 제작 및 배급업', 592: '오디오물 출판 및 원판 녹음업', 601: '라디오 방송업', 602: '텔레비전 방송업', 611: '공영 우편업', 612: '전기 통신업', 620: '컴퓨터 프로그래밍, 시스템 통합 및 관리업', 631: '자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업', 639: '기타 정보 서비스업', 641: '은행 및 저축기관', 642: '신탁업 및 집합 투자업', 649: '기타 금융업', 651: '보험업', 652: '재보험업', 653: '연금 및 공제업', 661: '금융 지원 서비스업', 662: '보험 및 연금관련 서비스업', 681: '부동산 임대 및 공급업', 682: '부동산관련 서비스업', 701: '자연과학 및 공학 연구개발업', 702: '인문 및 사회과학 연구개발업', 711: '법무관련 서비스업', 712: '회계 및 세무관련 서비스업', 713: '광고업', 714: '시장 조사 및 여론 조사업', 715: '회사 본부 및 경영 컨설팅 서비스업', 716: '기타 전문 서비스업', 721: '건축 기술, 엔지니어링 및 관련 기술 서비스업', 729: '기타 과학기술 서비스업', 731: '수의업', 732: '전문 디자인업', 733: '사진 촬영 및 처리업', 739: '그 외 기타 전문, 과학 및 기술 서비스업' ...

# %% [markdown]
# ## <b>2.0 데이터 탐색</b>

# %%
# head()로 첫 5줄 데이터 형태 및 컬럼 탐색

print(train.head(), '\n')

print(test.head())

# 일련번호(AI_id), 산업대분류(digit_1), 산업중분류(digit_2), 산업소분류(digit_3), 
# 사업 대상(text_obj), 사업 방법(text_mthd), 사업 취급품목(text_deal)

logger.info("log info")
# Out:
#         AI_id digit_1  digit_2  digit_3    text_obj    text_mthd text_deal
# 0  id_0000001       S       95      952       카센터에서      자동차부분정비   타이어오일교환
# 1  id_0000002       G       47      472       상점내에서    일반인을 대상으로   채소.과일판매
# 2  id_0000003       G       46      467  절단하여사업체에도매    공업용고무를가지고    합성고무도매
# 3  id_0000004       G       47      475       영업점에서      일반소비자에게    열쇠잠금장치
# 4  id_0000005       Q       87      872        어린이집  보호자의 위탁을 받아   취학전아동보육
#
#        AI_id  digit_1  digit_2  digit_3  text_obj  text_mthd text_deal
# 0  id_000001      NaN      NaN      NaN   치킨전문점에서   고객의주문에의해      치킨판매
# 1  id_000002      NaN      NaN      NaN      산업공구  다른 소매업자에게    철물 수공구
# 2  id_000003      NaN      NaN      NaN       절에서   신도을 대상으로    불교단체운영
# 3  id_000004      NaN      NaN      NaN     영업장에서      고객요구로     자동차튜닝
# 4  id_000005      NaN      NaN      NaN  실내포장마차에서  접객시설을 갖추고   소주,맥주제공

# %%
# info()

print(train.info(), '\n') # 전체 100만 건, text 컬럼들에 널값 존재, digit_2와 3 컬럼은 정수형 타입

print(test.info()) # 전체 100만 건, text 컬럼들에 널값 존재, digit(label) 컬럼들은 널값

logger.info("log info")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 7 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   AI_id      1000000 non-null  object
#  1   digit_1    1000000 non-null  object
#  2   digit_2    1000000 non-null  int64
#  3   digit_3    1000000 non-null  int64
#  4   text_obj   983323 non-null   object
#  5   text_mthd  956381 non-null   object
#  6   text_deal  932348 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 53.4+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   AI_id      100000 non-null  object
#  1   digit_1    0 non-null       float64
#  2   digit_2    0 non-null       float64
#  3   digit_3    0 non-null       float64
#  4   text_obj   98189 non-null   object
#  5   text_mthd  97032 non-null   object
#  6   text_deal  93839 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 5.3+ MB
# None

# %% [markdown]
# ### <b>2.1 시각적 EDA</b>

# %%
# 대분류 분포 그래프

digit_1_count = train.groupby(['digit_1'], as_index=False)['AI_id'].count()
digit_1_count.replace(digit_1_dict, inplace=True)

# Set the figure size
plot1 = plt.figure(figsize=(10, 5))

# plot a bar chart
sns.barplot(
    x = 'AI_id', y = 'digit_1',
    data = digit_1_count,
    estimator=sum, 
    ci=None, 
    order = list(digit_1_count.sort_values('AI_id', ascending=False)['digit_1']),
    color='#69b3a2');

# Hide spines and ticks
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
plt.tick_params(bottom=False)
plt.tick_params(left=False)
plt.xlabel("")
plt.ylabel("")

plt.show()

logger.info("log info")

# %%
# 중분류 분포 그래프

digit_2_count = train.groupby(['digit_2'], as_index=False)['AI_id'].count()
digit_2_count['DDdigit_2'] = digit_2_count['digit_2'].replace(digit_2_dict)

# Set the figure size
plt.figure(figsize=(10, 18))

# plot a bar chart
sns.barplot(
    x = 'AI_id', y = 'digit_2',
    data = digit_2_count,
    estimator=sum, 
    ci=None, 
    order = list(digit_2_count.sort_values('AI_id', ascending=False)['digit_2']),
    color='#69b3a2');

# Hide spines and ticks
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
plt.tick_params(bottom=False)
plt.tick_params(left=False)
plt.xlabel("")
plt.ylabel("")


plt.show()

logger.info("log info")

# %%
# 소분류 분포 그래프

digit_3_count = train.groupby(['digit_3'], as_index=False)['AI_id'].count()
digit_3_count['digit_3'] = digit_3_count['digit_3'].replace(digit_3_dict)

# Set the figure size
plt.figure(figsize=(10, 50))

# plot a bar chart
sns.barplot(
    x = 'AI_id', y = 'digit_3',
    data = digit_3_count,
    estimator=sum, 
    ci=None, 
    order = list(digit_3_count.sort_values('AI_id', ascending=False)['digit_3']),
    color='#69b3a2');

# Hide spines and ticks
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
plt.tick_params(bottom=False)
plt.tick_params(left=False)
plt.xlabel("")
plt.ylabel("")

plt.show()

logger.info("log info")

# %%
# 널값 비율 그래프

# Data
r1 , r2 = [0,1,2], [3,4,5] # for X row

train_data = {'notnull': [train['text_obj'].count(), train['text_mthd'].count(), train['text_deal'].count()],
            'isnull': [train['text_obj'].isnull().sum(), train['text_mthd'].isnull().sum(), train['text_deal'].isnull().sum()]}
test_data = {'notnull': [test['text_obj'].count(), test['text_mthd'].count(), test['text_deal'].count()],
            'isnull': [test['text_obj'].isnull().sum(), test['text_mthd'].isnull().sum(), test['text_deal'].isnull().sum()]}

train_data = pd.DataFrame(train_data)
test_data = pd.DataFrame(test_data)
 
# From raw value to percentage
train_totals = [i+j for i,j in zip(train_data['notnull'], train_data['isnull'])] # for train
train_notnull = [i / j * 100 for i,j in zip(train_data['notnull'], train_totals)]
train_isnull = [i / j * 100 for i,j in zip(train_data['isnull'], train_totals)]

test_totals = [i+j for i,j in zip(test_data['notnull'], test_data['isnull'])] # for test
test_notnull = [i / j * 100 for i,j in zip(test_data['notnull'], test_totals)]
test_isnull = [i / j * 100 for i,j in zip(test_data['isnull'], test_totals)]
 
# plot
plt.figure(figsize=(10, 5))
barWidth = 0.85

# Create train bars
plot1 = plt.bar(r1, train_notnull, color='#B4D4DF', edgecolor='white', width=barWidth)
plt.bar(r1, train_isnull, bottom=train_notnull, color='#11117A', edgecolor='white', width=barWidth)

# Create text bars
plot2 = plt.bar(r2, test_notnull, color='#EDFCD8', edgecolor='white', width=barWidth)
plt.bar(r2, test_isnull, bottom=test_notnull, color='#06481D', edgecolor='white', width=barWidth)

# Custom x axis
names = ('train_obj','train_mthd','train_deal','test_obj','test_mthd', 'test_deal')
plt.xticks(r1+r2, names)

for value in plot1:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             0.95*height,'%d' % int(height), ha='center', va='bottom')

for value in plot2:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             0.95*height,'%d' % int(height), ha='center', va='bottom')

# Hide spines and ticks
ax = plt.gca()
ax.axes.yaxis.set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
plt.tick_params(bottom=False)

# Title
plt.title("Null-value Ratio")

# Show graphic
plt.show()

logger.info("log info")

# %% [markdown]
# ## <b>3.0 데이터 정제</b>

# %% [markdown]
# ### <b>~~구두점, 오타 제거~~</b>

# %%
# 구두점, 오타(ㅋ, ㅡ 등 한글자) 제거

for col in tqdm(train[['text_obj', 'text_mthd', 'text_deal']].columns):
    train[col] = train[col].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣a-zA-z ]',' ', regex=True).str.replace('[* , .]', ' ', regex=True)
    test[col] = test[col].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣a-zA-z ]','', regex=True).str.replace('[* , .]', ' ', regex=True)
    
logger.info("log info")
# Out:
# 100%|██████████| 3/3 [00:04<00:00,  1.64s/it]

# %% [markdown]
# ### <b>결측치 처리</b>

# %%
# 결측값 탐색

condition1 = train['text_obj'].isnull() == True
condition2 = train['text_mthd'].isnull() == True
condition3 = train['text_deal'].isnull() == True

print("세 컬럼 모두 널 값인 경우: ", len(train[condition1&condition2&condition3])) # 세 컬럼 모두 Null 값인 로우는 없음.
print("obj 컬럼 널 값인 경우: ", len(train[condition1]))
print("mthd 컬럼 널 값인 경우: ", len(train[condition2]))
print("deal 컬럼 널 값인 경우: ", len(train[condition3]))


# 결측치를 ""로 대치 

train.fillna("",inplace=True)
test.fillna("", inplace=True)

logger.info("log info")
# Out:
# 세 컬럼 모두 널 값인 경우:  0
# obj 컬럼 널 값인 경우:  16677
# mthd 컬럼 널 값인 경우:  43619
# deal 컬럼 널 값인 경우:  67652

# %% [markdown]
# ## <b>4.0 토큰화</b>

# %%
# 작성해둔 한국어 불용어 사전 불러오기

stopwords = pd.read_csv("./data/stopwords/stopwords.csv", encoding='CP949')
stopwords = stopwords['stopwords']
print(stopwords, len(stopwords))

logger.info("log info")
# Out:
# 0        고
# 1        업
# 2        아
# 3        휴
# 4      아이구
#       ...
# 661      원
# 662      잘
# 663     통하
# 664     소리
# 665      놓
# Name: stopwords, Length: 666, dtype: object 666

# %% [markdown]
# ### Mecab 토크나이징

# %%
# train 데이터 토크나이징

mecab_train_text_obj = []
mecab_train_text_mthd = []
mecab_train_text_deal = []

mecab = Mecab()

for sentence in tqdm(train['text_obj']): # 진행상황 Progress Bar를 위한 tqdm library
    tokenized_sentence = mecab.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_train_text_obj.append(stopwords_removed_sentence)

for sentence in tqdm(train['text_mthd']):
    tokenized_sentence = mecab.morphs(sentence) 
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_train_text_mthd.append(stopwords_removed_sentence)

for sentence in tqdm(train['text_deal']):
    tokenized_sentence = mecab.morphs(sentence) 
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_train_text_deal.append(stopwords_removed_sentence)

logger.info("log info")
# Out:
# 100%|██████████| 1000000/1000000 [04:17<00:00, 3877.72it/s]
# 100%|██████████| 1000000/1000000 [07:11<00:00, 2318.18it/s]
# 100%|██████████| 1000000/1000000 [05:35<00:00, 2983.83it/s]

# %%
# test 데이터 토크나이징

mecab_test_text_obj = []
mecab_test_text_mthd = []
mecab_test_text_deal = []

mecab = Mecab()

for sentence in tqdm(test['text_obj']): # 진행상황 Progress Bar를 위한 tqdm library
    tokenized_sentence = mecab.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_test_text_obj.append(stopwords_removed_sentence)

for sentence in tqdm(test['text_mthd']):
    tokenized_sentence = mecab.morphs(sentence)
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_test_text_mthd.append(stopwords_removed_sentence)

for sentence in tqdm(test['text_deal']): 
    tokenized_sentence = mecab.morphs(sentence) 
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_test_text_deal.append(stopwords_removed_sentence)
    
logger.info("log info")
# Out:
# 100%|██████████| 100000/100000 [00:31<00:00, 3157.51it/s]
# 100%|██████████| 100000/100000 [00:35<00:00, 2855.47it/s]
# 100%|██████████| 100000/100000 [00:38<00:00, 2612.20it/s]

# %%
# 토큰화된 결과 합쳐 text 컬럼으로 생성

# train 데이터
train['text'] = mecab_train_text_obj
train['text'] = train['text'] + mecab_train_text_mthd
train['text'] = train['text'] + mecab_train_text_deal

# test 데이터
test['text'] = mecab_test_text_obj
test['text'] = test['text'] + mecab_test_text_mthd
test['text'] = test['text'] + mecab_test_text_deal

logger.info("log info")
# Out:
# C:\Users\Huitaek\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:69: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return op(a, b)

# %%
# mecab 형태소 분석기로 토큰화된 데이터 사용하기 편하도록 csv 파일로 저장

X_train = train.drop(columns=['text_obj', 'text_mthd', 'text_deal'])
X_train.to_csv('./data/mecab/tokenized_train.csv', encoding='CP949', index=False)

X_test = test.drop(columns=['text_obj', 'text_mthd', 'text_deal'])
X_test.to_csv('./data/mecab/tokenized_test.csv', encoding='CP949', index=False)

logger.info("log info")

# %% [markdown]
# ### <b>토큰화 결과 EDA</b>

# %%
# 대분류 빈도수 카운트

for i in list(X_train['digit_1'].unique()):
    print('<',digit_1_dict[i],'>')
    cat_words = np.hstack(X_train[X_train['digit_1'] == i]['text'].values)
    cat_words_count = Counter(cat_words)
    print(cat_words_count.most_common(20), '\n')

logger.info("log info")
# Out:
# < 협회 및 단체, 수리 및 기타 개인 서비스업(94~96) >
# [('대상', 41820), ('서비스', 40015), ('고객', 31272), ('종교', 25880), ('일반인', 17269), ('미용실', 15414), ('염색', 15149), ('수리', 14153), ('활동', 14064), ('미용', 13828), ('파마', 13729), ('교회', 13073), ('일반', 12459), ('사업장', 11730), ('기독교', 10748), ('발', 10118), ('자동차', 10104), ('계통', 9532), ('컷트', 8129), ('제공', 7383)]
#
# < 도매 및 소매업(45~47) >
# [('일반', 82910), ('소비자', 78369), ('소매', 74629), ('대상', 70956), ('매장', 65071), ('판매', 61918), ('사업장', 49553), ('도매', 47526), ('일반인', 34993), ('고객', 22324), ('소매업자', 22128), ('의류', 19612), ('가게', 14843), ('용품', 13044), ('산업', 12483), ('사용자', 11340), ('영업장', 10905), ('여성', 10644), ('편의점', 10251), ('음식료품', 9715)]
#
# < 보건업 및 사회복지 서비스업(86~87) >
# [('환자', 15135), ('외래', 12553), ('진료', 12085), ('서비스', 12083), ('위주', 10732), ('의원', 9952), ('대상', 9215), ('어린이', 8279), ('보육', 7567), ('치과', 7141), ('유아', 5957), ('취학전', 5536), ('노인', 5502), ('복지', 4969), ('요양', 4557), ('위탁', 4317), ('아동', 4310), ('보호자', 3721), ('치료', 3276), ('시설', 3269)]
#
# < 제조업(10~34) >
# [('제조', 31021), ('가공', 19627), ('사업장', 13842), ('부품', 13080), ('절단', 11976), ('기계', 9810), ('조립', 9457), ('제작', 8699), ('철', 8450), ('금속', 7371), ('입고', 7350), ('고객', 6687), ('재단', 6029), ('철판', 4820), ('원단', 4764), ('플라스틱', 4696), ('용접', 4649), ('절삭', 4183), ('수리', 4179), ('제조업', 4144)]
#
# < 숙박 및 음식점업(55~56) >
# [('시설', 137091), ('접객', 136243), ('갖추', 129265), ('음식점', 71576), ('판매', 45973), ('제공', 38260), ('커피', 22993), ('숙박', 16265), ('대상', 15690), ('주점', 15497), ('맥주', 14841), ('한식', 13590), ('일반인', 11871), ('치킨', 11756), ('음식', 11129), ('요원', 10300), ('매장', 10073), ('음료', 9795), ('없이', 9473), ('서비스', 9461)]
#
# < 공공 행정, 국방 및 사회보장 행정(84) >
# [('행정', 2013), ('서비스', 1668), ('치안', 711), ('집행', 705), ('주민', 652), ('사무', 649), ('지방행정', 550), ('대상', 502), ('센터', 483), ('공공질서', 410), ('화재', 348), ('관리', 322), ('진압', 294), ('구조', 285), ('파출소', 282), ('면사무소', 278), ('안전', 245), ('업무', 239), ('소방서', 211), ('지원', 208)]
#
# < 건설업(41~42) >
# [('고객', 20624), ('공사', 19637), ('현장', 12979), ('건설', 9849), ('요구', 8084), ('사업장', 7680), ('요청', 7522), ('의뢰', 6340), ('건물', 5900), ('설치', 4835), ('인테리어', 4428), ('실내', 3688), ('전기', 3335), ('배관', 2587), ('사업', 2284), ('주택', 2027), ('시공', 2024), ('설비', 1960), ('건축', 1936), ('철근', 1765)]
#
# < 교육 서비스업(85) >
# [('학원', 30051), ('대상', 29110), ('교육', 28710), ('학생', 20872), ('영어', 7777), ('수학', 7484), ('서비스', 7407), ('일반인', 6851), ('피아노', 5472), ('생', 4720), ('교습', 4659), ('미술', 3844), ('초등', 3381), ('사업장', 3258), ('태권도', 2994), ('강습', 2600), ('학교', 2436), ('교습소', 2354), ('유치원', 2190), ('일반', 2141)]
#
# < 운수 및 창고업(49~52) >
# [('운송', 89719), ('서비스', 85899), ('화물', 52118), ('고객', 48592), ('요청', 46741), ('화물자동차', 45972), ('대상', 40255), ('일반인', 38876), ('승객', 38577), ('개인택시', 37856), ('용달', 26129), ('개별', 17431), ('일반', 3878), ('사업장', 3725), ('주차장', 2390), ('택배', 1934), ('화주', 1546), ('주선', 1507), ('창고', 1350), ('간', 1336)]
#
# < 사업시설 관리, 사업 지원 및 임대 서비스업(74~76) >
# [('고객', 6801), ('사업장', 5465), ('대상', 4889), ('알선', 3478), ('서비스', 3034), ('사무실', 2810), ('인력', 2695), ('여행', 2418), ('요청', 2158), ('임대', 1768), ('관리', 1665), ('대여', 1662), ('일반인', 1658), ('의뢰', 1603), ('청소', 1564), ('공급', 1393), ('건물', 1249), ('시설', 1146), ('일반', 1068), ('요구', 1043)]
#
# < 예술, 스포츠 및 여가관련 서비스업(90~91) >
# [('대상', 11714), ('시설', 10873), ('갖추', 10198), ('노래방', 10029), ('일반인', 8868), ('운영', 7954), ('노래', 6282), ('서비스', 6009), ('연습장', 5963), ('제공', 5037), ('당구장', 3671), ('사업장', 3371), ('방', 2943), ('고객', 2828), ('게임', 2724), ('당구', 2663), ('독서실', 2614), ('체력', 2598), ('골프', 2567), ('단련', 2521)]
#
# < 전문, 과학 및 기술 서비스업(70~73) >
# [('고객', 8777), ('사무실', 7645), ('사업장', 7533), ('의뢰', 6477), ('설계', 5213), ('대리', 4883), ('서비스', 4348), ('요청', 4015), ('대상', 3841), ('세무', 3774), ('건축', 3513), ('광고', 3217), ('관련', 3143), ('대행', 3092), ('연구', 2843), ('의뢰인', 2451), ('컨설팅', 2398), ('업무', 2320), ('디자인', 2183), ('경영', 2180)]
#
# < 정보통신업(58~63) >
# [('개발', 4908), ('사업장', 4347), ('소프트웨어', 3603), ('공급', 2186), ('사무실', 1918), ('고객', 1912), ('시스템', 1685), ('제작', 1543), ('컴퓨터', 1441), ('서비스', 1359), ('대상', 1196), ('의뢰', 1180), ('프로그램', 1174), ('응용', 917), ('요청', 833), ('출판', 815), ('정보', 643), ('우체국', 642), ('제공', 630), ('인터넷', 618)]
#
# < 부동산업(68) >
# [('부동산', 45397), ('중개', 31249), ('서비스', 19007), ('계약', 16030), ('관리', 14510), ('개소', 9697), ('아파트', 9293), ('의거', 6752), ('사무실', 6417), ('수수료', 6129), ('건물', 5646), ('사업장', 5641), ('임대', 5364), ('사무소', 5293), ('대상', 5149), ('주거', 4308), ('통해', 4137), ('고객', 4028), ('입주자', 3728), ('음', 3702)]
#
# < 광업(05~08) >
# [('천일염', 206), ('해수', 164), ('증발', 145), ('염전', 114), ('생산', 112), ('시켜', 103), ('골재', 82), ('채취', 81), ('바닷물', 69), ('모래', 68), ('태양열', 67), ('채굴', 58), ('시설', 55), ('원석', 41), ('건설', 34), ('발파', 34), ('자갈', 32), ('쇄석', 28), ('갖춰', 28), ('석회석', 26)]
#
# < 금융 및 보험업(64~66) >
# [('대상', 5882), ('보험', 4975), ('자금', 4168), ('수신', 3876), ('고객', 3345), ('일반', 3191), ('대중', 2259), ('사업장', 1889), ('일반인', 1857), ('기업', 1424), ('은행', 1343), ('중개', 1314), ('대리', 1219), ('대출', 1196), ('농협', 1160), ('서비스', 1142), ('금융', 1139), ('송금', 999), ('조성', 997), ('생명', 936)]
#
# < 수도, 하수 및 폐기물 처리, 원료 재생업(36~39) >
# [('폐기물', 1286), ('처리', 964), ('수집', 919), ('운반', 769), ('사업장', 481), ('건설', 306), ('하수', 278), ('차량', 265), ('이용', 265), ('지정', 264), ('시설', 227), ('분뇨', 224), ('폐', 219), ('수거', 213), ('원료', 197), ('생활', 194), ('재', 188), ('재생', 180), ('현장', 177), ('고객', 175)]
#
# < 전기, 가스, 증기 및 공기 조절 공급업(35) >
# [('전기', 485), ('태양광', 389), ('생산', 352), ('사업장', 239), ('공급', 189), ('발전', 178), ('이용', 120), ('판매', 106), ('태양열', 97), ('가스', 96), ('태양', 89), ('전력', 85), ('발전소', 81), ('전업', 80), ('한전', 77), ('발', 74), ('에너지', 68), ('태양력', 65), ('시설', 59), ('에너지원', 56)]
#
# < 농업, 임업 및 어업(01~03) >
# [('재배', 387), ('사업장', 184), ('사육', 177), ('시설', 147), ('판매', 122), ('서비스', 119), ('작물', 103), ('버섯', 98), ('농장', 97), ('생산', 87), ('양식', 77), ('돼지', 77), ('갖추', 54), ('숲', 51), ('관리', 51), ('선별', 51), ('양', 51), ('가꾸기', 49), ('농업', 49), ('산림', 48)]

# %%
# 중분류 빈도수 카운트

for i in list(X_train['digit_2'].unique()):
    print('<',digit_2_dict[i],'>')
    cat_words = np.hstack(X_train[X_train['digit_2'] == i]['text'].values)
    cat_words_count = Counter(cat_words)
    print(cat_words_count.most_common(20), '\n')

logger.info("log info")
# Out:
# < 개인 및 소비용품 수리업 >
# [('수리', 14119), ('자동차', 10067), ('고객', 8874), ('대상', 6871), ('수선', 5766), ('서비스', 4340), ('사업장', 4213), ('카센타', 3995), ('부분', 3736), ('특정', 3318), ('전문', 3176), ('정비', 2934), ('경정비', 2777), ('일반인', 2775), ('요청', 2727), ('옷', 2193), ('일반', 2079), ('타이어', 1986), ('세차', 1850), ('의뢰', 1767)]
#
# < 소매업; 자동차 제외 >
# [('일반', 76537), ('소비자', 74892), ('소매', 70691), ('대상', 55496), ('매장', 53288), ('판매', 49386), ('일반인', 32378), ('사업장', 19399), ('고객', 16740), ('의류', 16514), ('가게', 13006), ('편의점', 10229), ('음식료품', 9677), ('여성', 9499), ('용품', 8835), ('위주', 8053), ('식료품', 7267), ('체인', 6674), ('계약', 6599), ('화장품', 6579)]
#
# < 도매 및 상품 중개업 >
# [('도매', 46025), ('사업장', 27742), ('소매업자', 21584), ('대상', 12321), ('산업', 12003), ('사용자', 10875), ('매장', 10270), ('판매', 9428), ('영업장', 4658), ('일반', 4372), ('도소매', 3588), ('상가', 3491), ('고객', 3488), ('용품', 3400), ('의류', 3096), ('수집', 3079), ('업체', 2995), ('기계', 2957), ('부품', 2912), ('고철', 2887)]
#
# < 사회복지 서비스업 >
# [('어린이', 8239), ('보육', 7567), ('유아', 5934), ('취학전', 5536), ('노인', 5304), ('서비스', 5052), ('복지', 4935), ('대상', 4840), ('위탁', 4312), ('요양', 4179), ('아동', 4031), ('보호자', 3718), ('시설', 2872), ('센터', 2751), ('교육', 2574), ('인가', 2307), ('관할', 1937), ('방문', 1741), ('어린이집', 1502), ('구청', 1442)]
#
# < 기타 기계 및 장비 제조업 >
# [('가공', 3937), ('제조', 3835), ('기계', 3191), ('부품', 2625), ('철', 2609), ('금형', 2562), ('절단', 2102), ('조립', 2049), ('제작', 1505), ('금속', 1439), ('철판', 1322), ('용접', 1294), ('사업장', 1139), ('입고', 1107), ('산업', 1105), ('절삭', 901), ('장비', 765), ('설계', 716), ('선반', 682), ('밀링', 663)]
#
# < 음식점 및 주점업 >
# [('접객', 136143), ('시설', 130182), ('갖추', 123748), ('음식점', 71559), ('판매', 45972), ('제공', 31527), ('커피', 22993), ('주점', 15497), ('맥주', 14841), ('한식', 13590), ('치킨', 11756), ('음식', 11124), ('대상', 10614), ('요원', 10288), ('매장', 10069), ('음료', 9794), ('소주', 9235), ('식당', 8620), ('사업장', 8013), ('없이', 7962)]
#
# < 식료품 제조업 >
# [('제조', 6409), ('떡', 3114), ('가공', 2036), ('판매', 1979), ('쌀', 1871), ('건강', 1802), ('사업장', 1792), ('즙', 1492), ('방앗간', 1382), ('분쇄', 1362), ('대상', 1232), ('식품', 1128), ('곡물', 993), ('고객', 979), ('류', 974), ('소비자', 925), ('고추', 919), ('일반', 917), ('갖추', 912), ('일반인', 878)]
#
# < 공공 행정, 국방 및 사회보장 행정 >
# [('행정', 2013), ('서비스', 1668), ('치안', 711), ('집행', 705), ('주민', 652), ('사무', 649), ('지방행정', 550), ('대상', 502), ('센터', 483), ('공공질서', 410), ('화재', 348), ('관리', 322), ('진압', 294), ('구조', 285), ('파출소', 282), ('면사무소', 278), ('안전', 245), ('업무', 239), ('소방서', 211), ('지원', 208)]
#
# < 전문직별 공사업 >
# [('공사', 17165), ('고객', 16621), ('현장', 9322), ('사업장', 6427), ('요청', 6388), ('요구', 6015), ('의뢰', 5278), ('건물', 4866), ('건설', 4600), ('인테리어', 4401), ('설치', 4329), ('실내', 3671), ('전기', 3314), ('배관', 2482), ('사업', 2057), ('시공', 1728), ('설비', 1648), ('도배', 1615), ('장식', 1461), ('철근', 1333)]
#
# < 교육 서비스업 >
# [('학원', 30051), ('대상', 29110), ('교육', 28710), ('학생', 20872), ('영어', 7777), ('수학', 7484), ('서비스', 7407), ('일반인', 6851), ('피아노', 5472), ('생', 4720), ('교습', 4659), ('미술', 3844), ('초등', 3381), ('사업장', 3258), ('태권도', 2994), ('강습', 2600), ('학교', 2436), ('교습소', 2354), ('유치원', 2190), ('일반', 2141)]
#
# < 창고 및 운송관련 서비스업 >
# [('화물', 3725), ('운송', 2630), ('주차장', 2388), ('사업장', 2079), ('주선', 1449), ('화주', 1358), ('창고', 1337), ('대상', 1322), ('간', 1185), ('보관', 1145), ('운영', 1123), ('운송업자', 1111), ('서비스', 1109), ('주차', 1069), ('고객', 889), ('알선', 846), ('차량', 784), ('물류', 754), ('일반', 707), ('중개', 648)]
#
# < 임대업; 부동산 제외 >
# [('대상', 1949), ('사업장', 1839), ('임대', 1750), ('고객', 1662), ('대여', 1650), ('일반인', 672), ('건설', 511), ('일반', 438), ('장비', 411), ('영업장', 391), ('매장', 387), ('자동차', 379), ('렌탈', 370), ('정수기', 347), ('산업', 336), ('요청', 324), ('차량', 319), ('사용자', 318), ('한복', 290), ('기계', 276)]
#
# < 스포츠 및 오락관련 서비스업 >
# [('시설', 10229), ('노래방', 10027), ('갖추', 9971), ('대상', 9757), ('일반인', 7219), ('운영', 6438), ('노래', 6272), ('연습장', 5953), ('서비스', 5289), ('제공', 4324), ('당구장', 3670), ('방', 2927), ('사업장', 2749), ('게임', 2724), ('당구', 2662), ('체력', 2598), ('골프', 2567), ('단련', 2521), ('고객', 2476), ('연습', 2182)]
#
# < 고무 및 플라스틱제품 제조업 >
# [('플라스틱', 2675), ('제조', 1473), ('성형', 1345), ('사출', 1066), ('고무', 942), ('가공', 730), ('입고', 697), ('절단', 684), ('부품', 656), ('비닐', 463), ('필름', 459), ('조립', 430), ('제품', 425), ('사업장', 411), ('자동차', 409), ('PVC', 336), ('원료', 334), ('용기', 287), ('원재료', 270), ('PP', 265)]
#
# < 기타 개인 서비스업 >
# [('대상', 30490), ('고객', 22337), ('서비스', 22069), ('미용실', 15412), ('염색', 15141), ('일반인', 13866), ('미용', 13805), ('파마', 13729), ('일반', 10179), ('발', 10106), ('컷트', 8129), ('커트', 6863), ('세탁', 6785), ('피부', 6764), ('사업장', 6556), ('제공', 6370), ('미장원', 6356), ('세탁소', 5751), ('관리', 5406), ('머리', 4662)]
#
# < 협회 및 단체 >
# [('종교', 25872), ('활동', 14005), ('서비스', 13606), ('교회', 13073), ('기독교', 10748), ('계통', 9527), ('대상', 4459), ('불교', 2957), ('회원', 2507), ('단체', 2300), ('신도', 1920), ('사무실', 1579), ('관리', 1470), ('협회', 1458), ('절', 1433), ('사찰', 1118), ('사업장', 961), ('인', 776), ('이익', 734), ('계', 714)]
#
# < 숙박업 >
# [('숙박', 16239), ('서비스', 8808), ('시설', 6909), ('제공', 6733), ('갖추', 5517), ('대상', 5076), ('일반인', 4763), ('모텔', 3148), ('펜션', 2985), ('민박', 2662), ('없이', 1511), ('룸서비스', 1406), ('개별', 1271), ('여관', 1110), ('고시원', 1043), ('운영', 848), ('고객', 737), ('숙식', 526), ('사업장', 488), ('호텔', 420)]
#
# < 육상 운송 및 파이프라인 운송업 >
# [('운송', 86875), ('서비스', 84768), ('화물', 48249), ('고객', 47644), ('요청', 46315), ('화물자동차', 45928), ('대상', 38861), ('승객', 38551), ('일반인', 38432), ('개인택시', 37854), ('용달', 26128), ('개별', 17428), ('일반', 3166), ('택배', 1911), ('사업장', 1600), ('의뢰', 909), ('화물차', 884), ('이용', 635), ('배달', 585), ('택시', 561)]
#
# < 금속 가공제품 제조업; 기계 및 가구 제외 >
# [('가공', 7109), ('부품', 5155), ('금속', 4747), ('철', 4203), ('절단', 3640), ('기계', 3360), ('제조', 3334), ('절삭', 2888), ('용접', 2188), ('철판', 1959), ('제작', 1682), ('알루미늄', 1501), ('사업장', 1314), ('자동차', 1313), ('입고', 1270), ('선반', 1203), ('조립', 1154), ('산업', 1050), ('스텐', 1046), ('밀링', 842)]
#
# < 기타 전문, 과학 및 기술 서비스업 >
# [('고객', 2324), ('동물', 2074), ('촬영', 1850), ('디자인', 1750), ('대상', 1708), ('사진', 1650), ('사업장', 1613), ('병원', 904), ('요청', 898), ('사진관', 789), ('서비스', 750), ('의뢰', 746), ('치료', 700), ('일반인', 502), ('사무실', 478), ('인테리어', 471), ('인물사진', 429), ('제공', 314), ('예방', 309), ('인화', 298)]
#
# < 가구 제조업 >
# [('목재', 1505), ('가구', 1404), ('절단', 1197), ('제조', 1099), ('제작', 748), ('조립', 729), ('씽크대', 718), ('재단', 649), ('접합', 451), ('사업장', 446), ('가공', 358), ('고객', 354), ('주방', 321), ('합판', 280), ('MDF', 271), ('주문', 251), ('나무', 242), ('싱크대', 231), ('원목', 228), ('구입', 186)]
#
# < 전문 서비스업 >
# [('사무실', 5412), ('대리', 4844), ('의뢰', 3934), ('세무', 3774), ('사업장', 3300), ('광고', 3120), ('고객', 2993), ('대행', 2918), ('의뢰인', 2366), ('업무', 2272), ('컨설팅', 2138), ('경영', 2134), ('관련', 2096), ('기장', 1788), ('서비스', 1675), ('대상', 1537), ('소송', 1351), ('조정', 1195), ('서류', 1159), ('신청', 1129)]
#
# < 출판업 >
# [('개발', 3993), ('소프트웨어', 2993), ('사업장', 2507), ('공급', 1908), ('사무실', 1006), ('시스템', 949), ('응용', 851), ('출판', 784), ('고객', 590), ('프로그램', 561), ('대상', 469), ('의뢰', 443), ('컴퓨터', 433), ('발행', 377), ('서적', 352), ('신문', 312), ('운영', 278), ('게임', 271), ('요청', 256), ('체제', 232)]
#
# < 건축 기술, 엔지니어링 및 기타 과학기술 서비스업 >
# [('설계', 4808), ('건축', 3465), ('고객', 3374), ('사업장', 2139), ('요청', 2044), ('서비스', 1858), ('의뢰', 1659), ('사무실', 1473), ('사무소', 1145), ('토목', 967), ('감리', 842), ('관련', 803), ('엔지니어링', 794), ('측량', 624), ('검사', 622), ('대상', 533), ('안전', 499), ('전기', 487), ('제공', 451), ('건물', 444)]
#
# < 보건업 >
# [('환자', 14698), ('외래', 12548), ('진료', 12071), ('위주', 10689), ('의원', 9951), ('치과', 7141), ('서비스', 7031), ('대상', 4375), ('치료', 2888), ('일반', 2878), ('내과', 2524), ('병원', 2090), ('일반인', 1305), ('한방', 1183), ('침', 1082), ('보건', 883), ('의료', 879), ('피부과', 814), ('이비인후과', 667), ('뜸', 656)]
#
# < 의복, 의복 액세서리 및 모피제품 제조업 >
# [('재단', 2414), ('제조', 2384), ('원단', 2056), ('재봉', 1371), ('의류', 1191), ('사업장', 968), ('여성', 806), ('봉제', 713), ('한복', 592), ('티셔츠', 474), ('면', 456), ('정장', 350), ('실', 348), ('고객', 342), ('제작', 326), ('임가공', 313), ('편조', 287), ('공장', 282), ('의뢰', 263), ('제조업', 249)]
#
# < 자동차 및 부품 판매업 >
# [('자동차', 5627), ('대상', 3139), ('판매', 3104), ('사업장', 2412), ('부품', 2263), ('고객', 2096), ('일반', 2001), ('매장', 1513), ('타이어', 1399), ('중고', 1389), ('소비자', 1373), ('소매', 1118), ('일반인', 1079), ('매매', 943), ('용품', 809), ('도매', 763), ('중고차', 579), ('영업장', 548), ('차량', 471), ('오토바이', 433)]
#
# < 부동산업 >
# [('부동산', 45397), ('중개', 31249), ('서비스', 19007), ('계약', 16030), ('관리', 14510), ('개소', 9697), ('아파트', 9293), ('의거', 6752), ('사무실', 6417), ('수수료', 6129), ('건물', 5646), ('사업장', 5641), ('임대', 5364), ('사무소', 5293), ('대상', 5149), ('주거', 4308), ('통해', 4137), ('고객', 4028), ('입주자', 3728), ('음', 3702)]
#
# < 기타 제품 제조업 >
# [('간판', 1689), ('제조', 1491), ('제작', 1472), ('사업장', 1152), ('광고', 1130), ('고객', 966), ('현수막', 934), ('물', 759), ('의뢰', 495), ('요청', 388), ('절단', 357), ('주문', 342), ('귀금속', 315), ('대상', 304), ('가공', 294), ('도장', 263), ('조립', 246), ('아크릴', 236), ('제조업', 232), ('액자', 209)]
#
# < 전기장비 제조업 >
# [('제조', 1924), ('조립', 1905), ('전기', 1793), ('사업장', 818), ('부품', 777), ('조명', 693), ('장치', 686), ('제작', 640), ('전선', 633), ('자동', 597), ('절단', 595), ('LED', 594), ('가공', 585), ('간판', 524), ('판넬', 483), ('입고', 478), ('배전반', 404), ('철판', 363), ('제어반', 356), ('철', 307)]
#
# < 사업 지원 서비스업 >
# [('알선', 3468), ('고객', 3446), ('사업장', 2764), ('인력', 2671), ('대상', 2669), ('사무실', 2431), ('여행', 2417), ('서비스', 1999), ('공급', 1383), ('요청', 1342), ('일반인', 868), ('여행사', 843), ('수수료', 827), ('고용', 823), ('의뢰', 775), ('대행', 764), ('소개', 750), ('국내외', 747), ('직업', 690), ('포장', 626)]
#
# < 화학 물질 및 화학제품 제조업; 의약품 제외 >
# [('제조', 1065), ('원료', 507), ('혼합', 473), ('사업장', 443), ('플라스틱', 365), ('배합', 335), ('화장품', 325), ('가공', 242), ('합성수지', 239), ('입고', 228), ('비료', 216), ('수지', 208), ('제조업', 201), ('재생', 183), ('투입', 179), ('화학', 172), ('생산', 136), ('비누', 135), ('분쇄', 128), ('원재료', 128)]
#
# < 창작, 예술 및 여가관련 서비스업 >
# [('독서실', 2614), ('대상', 1957), ('일반인', 1649), ('운영', 1516), ('학생', 1043), ('공연', 997), ('도서관', 754), ('서비스', 720), ('제공', 713), ('시설', 644), ('사업장', 622), ('기획', 421), ('고객', 352), ('장소', 341), ('도서', 332), ('전시', 279), ('없이', 262), ('일반', 260), ('예술', 255), ('숙박', 254)]
#
# < 사업시설 관리 및 조경 서비스업 >
# [('고객', 1693), ('청소', 1448), ('관리', 1197), ('건물', 1170), ('시설', 925), ('사업장', 862), ('서비스', 778), ('의뢰', 671), ('유지', 573), ('요청', 492), ('사업', 489), ('소독', 484), ('요구', 440), ('대상', 271), ('현장', 262), ('용역', 216), ('방역', 214), ('대행', 203), ('사무실', 192), ('위생', 146)]
#
# < 영상ㆍ오디오 기록물 제작 및 배급업 >
# [('제작', 1031), ('사업장', 570), ('영화', 439), ('영상', 403), ('고객', 329), ('방송', 277), ('광고', 244), ('의뢰', 235), ('요청', 229), ('프로그램', 199), ('사무실', 198), ('비디오', 197), ('대상', 159), ('물', 138), ('시설', 137), ('녹음', 136), ('사업자', 116), ('스튜디오', 115), ('갖추', 113), ('상영', 111)]
#
# < 산업용 기계 및 장비 수리업 >
# [('수리', 3959), ('사업장', 1282), ('기계', 1185), ('고객', 1140), ('농기계', 695), ('대상', 583), ('장비', 554), ('요청', 526), ('의뢰', 523), ('선박', 517), ('서비스', 490), ('전문', 370), ('일반', 323), ('모터', 306), ('산업', 298), ('부품', 256), ('전기', 221), ('기기', 199), ('특정', 189), ('부분', 185)]
#
# < 전자 부품, 컴퓨터, 영상, 음향 및 통신장비 제조업 >
# [('부품', 1329), ('제조', 1001), ('조립', 978), ('기판', 616), ('회로', 599), ('사업장', 483), ('가공', 481), ('PCB', 430), ('반도체', 403), ('입고', 383), ('인쇄', 364), ('장비', 279), ('통신', 228), ('제조업', 200), ('기기', 185), ('검사', 174), ('컴퓨터', 160), ('실장', 149), ('알루미늄', 135), ('인', 133)]
#
# < 종합 건설업 >
# [('건설', 5249), ('고객', 4003), ('현장', 3657), ('공사', 2472), ('요구', 2069), ('주택', 1696), ('사업장', 1253), ('요청', 1134), ('의뢰', 1062), ('건물', 1034), ('조경', 894), ('건축', 862), ('토목', 846), ('건설업', 798), ('단독', 604), ('이용', 524), ('설치', 506), ('철근', 432), ('주거', 428), ('시멘트', 356)]
#
# < 목재 및 나무제품 제조업; 가구 제외 >
# [('목재', 1087), ('절단', 546), ('제조', 502), ('나무', 358), ('가공', 315), ('제작', 269), ('원목', 217), ('합판', 217), ('사업장', 199), ('조립', 188), ('재단', 173), ('고객', 128), ('상자', 113), ('접합', 103), ('입고', 103), ('가구', 100), ('파렛트', 97), ('MDF', 82), ('주문', 75), ('제재', 75)]
#
# < 1차 금속 제조업 >
# [('절단', 755), ('가공', 463), ('알루미늄', 457), ('제조', 427), ('입고', 296), ('철', 293), ('철판', 265), ('파이프', 249), ('금속', 236), ('철강', 200), ('용접', 176), ('스텐', 174), ('주물', 163), ('사업장', 158), ('부품', 158), ('주조', 139), ('레스', 128), ('비철', 125), ('기계', 118), ('제작', 115)]
#
# < 기타 운송장비 제조업 >
# [('선박', 423), ('철판', 261), ('절단', 237), ('제조', 230), ('구성', 212), ('부품', 197), ('부분품', 184), ('용접', 184), ('입고', 145), ('가공', 143), ('조립', 119), ('철', 116), ('사업장', 113), ('취부', 67), ('제작', 64), ('파이프', 60), ('철도', 53), ('건조', 53), ('알루미늄', 51), ('차량', 47)]
#
# < 비금속광물 광업; 연료용 제외 >
# [('천일염', 206), ('해수', 164), ('증발', 145), ('염전', 114), ('생산', 110), ('시켜', 103), ('골재', 82), ('채취', 81), ('바닷물', 69), ('모래', 68), ('태양열', 67), ('시설', 55), ('채굴', 50), ('원석', 41), ('건설', 34), ('발파', 33), ('자갈', 32), ('쇄석', 28), ('갖춰', 28), ('석회석', 26)]
#
# < 인쇄 및 기록매체 복제업 >
# [('쇄', 1828), ('인쇄', 1676), ('인', 1559), ('종이', 1237), ('잉크', 1005), ('사업장', 760), ('옵', 641), ('인쇄물', 638), ('고객', 561), ('전단지', 464), ('스크린', 439), ('판', 407), ('명함', 401), ('의뢰', 397), ('인쇄소', 366), ('계약', 329), ('주문', 279), ('제작', 269), ('경인', 249), ('제조', 237)]
#
# < 금융 및 보험관련 서비스업 >
# [('보험', 2174), ('대상', 1665), ('중개', 1277), ('대리', 1194), ('사업장', 1189), ('고객', 886), ('일반', 757), ('보험계약', 597), ('일반인', 558), ('서비스', 519), ('대중', 495), ('체결', 492), ('대리점', 490), ('기업', 473), ('사무실', 453), ('알선', 438), ('손해', 350), ('금융', 345), ('증권', 334), ('투자', 268)]
#
# < 금융업 >
# [('자금', 4137), ('수신', 3874), ('대상', 3067), ('고객', 2001), ('일반', 1886), ('대중', 1421), ('은행', 1312), ('농협', 1155), ('대출', 1092), ('송금', 990), ('조성', 964), ('일반인', 904), ('으로부터', 891), ('기업', 879), ('금융', 768), ('새', 611), ('지역', 569), ('이자', 529), ('지급', 523), ('사업장', 494)]
#
# < 비금속 광물제품 제조업 >
# [('제조', 918), ('시멘트', 557), ('가공', 541), ('유리', 524), ('성형', 422), ('절단', 415), ('모래', 351), ('사업장', 328), ('석재', 281), ('혼합', 246), ('도', 226), ('콘크리트', 215), ('흙', 208), ('대리석', 203), ('입고', 202), ('도자기', 200), ('원재료', 196), ('투입', 166), ('제작', 156), ('골재', 152)]
#
# < 가죽, 가방 및 신발 제조업 >
# [('제조', 631), ('가죽', 604), ('재단', 449), ('가방', 399), ('사업장', 230), ('신발', 230), ('구두', 209), ('재봉', 191), ('원단', 161), ('지갑', 146), ('핸드백', 140), ('피혁', 135), ('가공', 114), ('갑피', 97), ('봉제', 92), ('합성', 87), ('임가공', 86), ('케이스', 85), ('제조업', 74), ('제작', 71)]
#
# < 보험 및 연금업 >
# [('보험', 2764), ('대상', 1150), ('생명', 832), ('일반', 548), ('회사', 530), ('손해', 479), ('고객', 458), ('일반인', 395), ('대중', 343), ('화재', 246), ('보험업', 226), ('운영', 222), ('사업장', 206), ('판매', 201), ('서비스', 186), ('보증', 182), ('업무', 174), ('계약', 154), ('관리', 153), ('사무실', 145)]
#
# < 컴퓨터 프로그래밍, 시스템 통합 및 관리업 >
# [('컴퓨터', 883), ('개발', 874), ('사업장', 800), ('시스템', 717), ('고객', 632), ('소프트웨어', 599), ('사무실', 499), ('의뢰', 413), ('서비스', 356), ('구축', 326), ('프로그램', 290), ('제작', 277), ('통합', 273), ('요청', 264), ('홈페이지', 236), ('주문', 226), ('자문', 192), ('이용', 185), ('공급', 183), ('관리', 164)]
#
# < 섬유제품 제조업; 의복 제외 >
# [('원단', 1809), ('제조', 1419), ('재단', 742), ('직물', 733), ('원사', 722), ('사업장', 634), ('섬유', 594), ('가공', 591), ('천막', 515), ('자수', 442), ('입고', 416), ('재봉', 369), ('기계', 364), ('염색', 342), ('제작', 334), ('폴리', 328), ('실', 319), ('의류', 295), ('제품', 285), ('연사', 282)]
#
# < 펄프, 종이 및 종이제품 제조업 >
# [('종이', 1007), ('골판지', 639), ('제조', 612), ('박스', 349), ('절단', 347), ('상자', 344), ('재단', 342), ('원지', 253), ('가공', 232), ('사업장', 181), ('입고', 177), ('인', 156), ('쇄', 154), ('원단', 141), ('포장', 135), ('접합', 128), ('인쇄', 125), ('제작', 120), ('접착', 112), ('판지', 110)]
#
# < 음료 제조업 >
# [('제조', 191), ('발효', 131), ('쌀', 103), ('막걸리', 88), ('탁주', 60), ('사업장', 58), ('음료', 53), ('약주', 41), ('제조업', 39), ('판매', 38), ('누룩', 33), ('시켜', 26), ('생산', 23), ('물', 22), ('혼합', 22), ('찹쌀', 22), ('맥주', 20), ('양조장', 20), ('얼음', 19), ('시설', 19)]
#
# < 연구개발업 >
# [('연구', 2258), ('개발', 1271), ('연구소', 564), ('사업장', 481), ('사무실', 282), ('제공', 245), ('공학', 222), ('결과', 195), ('관련', 151), ('의뢰', 138), ('기술', 136), ('전기', 131), ('학술', 102), ('의학', 96), ('신약', 95), ('고객', 86), ('과학', 77), ('연구실', 76), ('분야', 68), ('용역', 68)]
#
# < 자동차 및 트레일러 제조업 >
# [('자동차', 1356), ('부품', 1218), ('가공', 686), ('제조', 641), ('입고', 575), ('조립', 438), ('철', 355), ('절단', 345), ('철판', 344), ('사업장', 312), ('알루미늄', 233), ('엔진', 210), ('프레스', 162), ('장치', 161), ('금속', 159), ('용접', 146), ('원재료', 140), ('플라스틱', 133), ('차체', 130), ('제작', 122)]
#
# < 수상 운송업 >
# [('운송', 180), ('선박', 131), ('화물', 124), ('낚시', 97), ('배', 71), ('해상', 66), ('대상', 65), ('고객', 54), ('취항', 50), ('예인선', 45), ('여객', 45), ('운영', 44), ('내항', 44), ('사업장', 39), ('일반인', 38), ('외항', 38), ('유람선', 35), ('요청', 34), ('운송업', 33), ('이용', 30)]
#
# < 폐기물 수집, 운반, 처리 및 원료 재생업 >
# [('폐기물', 1270), ('수집', 765), ('운반', 657), ('처리', 535), ('사업장', 371), ('건설', 305), ('지정', 261), ('차량', 248), ('폐', 217), ('이용', 198), ('원료', 196), ('재', 188), ('재생', 178), ('생활', 176), ('분리', 169), ('분쇄', 162), ('수거', 161), ('플라스틱', 159), ('현장', 150), ('외', 127)]
#
# < 우편 및 통신업 >
# [('우체국', 642), ('우편', 613), ('우편물', 562), ('서비스', 407), ('대상', 364), ('배달', 333), ('통신', 265), ('수집', 259), ('고객', 218), ('일반인', 200), ('분배', 153), ('유선', 150), ('일반', 133), ('업무', 128), ('택배', 123), ('사업장', 113), ('접수', 95), ('수신', 84), ('취급', 80), ('통신업', 79)]
#
# < 의료, 정밀, 광학 기기 및 시계 제조업 >
# [('제조', 1047), ('조립', 862), ('치과', 583), ('사업장', 567), ('자동', 518), ('부품', 493), ('가공', 455), ('기기', 448), ('제작', 365), ('화', 341), ('기계', 332), ('기공', 304), ('의료', 242), ('의뢰', 237), ('설계', 228), ('장비', 228), ('소', 227), ('기', 225), ('장치', 222), ('산업', 212)]
#
# < 전기, 가스, 증기 및 공기 조절 공급업 >
# [('전기', 485), ('태양광', 389), ('생산', 352), ('사업장', 239), ('공급', 189), ('발전', 178), ('이용', 120), ('판매', 106), ('태양열', 97), ('가스', 96), ('태양', 89), ('전력', 85), ('발전소', 81), ('전업', 80), ('한전', 77), ('발', 74), ('에너지', 68), ('태양력', 65), ('시설', 59), ('에너지원', 56)]
#
# < 정보서비스업 >
# [('정보', 448), ('인터넷', 354), ('제공', 338), ('사업장', 299), ('서비스', 283), ('온라인', 228), ('사무실', 170), ('고객', 123), ('뉴스', 123), ('컴퓨터', 93), ('기사', 74), ('신문', 74), ('대상', 72), ('자료', 71), ('의뢰', 63), ('매개', 56), ('웹', 55), ('일반인', 52), ('이용', 52), ('처리', 50)]
#
# < 하수, 폐수 및 분뇨 처리업 >
# [('처리', 415), ('하수', 261), ('분뇨', 222), ('수집', 154), ('폐수', 144), ('시설', 124), ('정화조', 112), ('운반', 112), ('청소', 90), ('사업장', 88), ('처리장', 56), ('이용', 55), ('고객', 54), ('관리', 48), ('수거', 47), ('서비스', 39), ('산업', 35), ('축산', 32), ('운영', 31), ('정화', 31)]
#
# < 임업 >
# [('숲', 51), ('가꾸기', 49), ('산림', 48), ('임업', 43), ('서비스', 43), ('관련', 26), ('현장', 23), ('벌목', 23), ('고객', 22), ('계약', 22), ('사업', 18), ('의뢰', 18), ('사업장', 16), ('나무', 16), ('병충해', 14), ('수수료', 13), ('영림', 12), ('산림조합', 12), ('요청', 11), ('의하', 11)]
#
# < 방송업 >
# [('방송', 275), ('프로그램', 112), ('유선', 98), ('제작', 66), ('사업장', 58), ('송출', 55), ('공급', 48), ('서비스', 32), ('제공', 31), ('방송국', 30), ('라디오', 26), ('인터넷', 25), ('케이블', 25), ('고객', 20), ('위성', 17), ('지상파', 16), ('종합', 15), ('대상', 14), ('사무실', 14), ('은', 13)]
#
# < 환경 정화 및 복원업 >
# [('정화', 13), ('바다', 11), ('해양', 9), ('사업장', 8), ('토양', 8), ('이용', 8), ('선박', 8), ('고객', 7), ('환경정화', 7), ('오염', 6), ('수거', 5), ('지하수', 4), ('된', 4), ('복원', 4), ('현장', 4), ('의뢰', 4), ('환경', 4), ('화학', 3), ('기계', 3), ('폐기물', 3)]
#
# < 농업 >
# [('재배', 384), ('사육', 177), ('사업장', 159), ('시설', 141), ('판매', 109), ('작물', 103), ('버섯', 98), ('농장', 97), ('생산', 79), ('돼지', 77), ('서비스', 64), ('갖추', 51), ('농업', 49), ('닭', 48), ('선별', 47), ('채소', 47), ('노지', 46), ('관리', 44), ('양', 44), ('농산물', 43)]
#
# < 어업 >
# [('양식', 76), ('양식장', 36), ('해면', 23), ('이용', 23), ('해수', 21), ('광어', 20), ('수산물', 17), ('어업', 13), ('서비스', 12), ('육상', 11), ('어촌계', 11), ('판매', 10), ('종묘', 10), ('출하', 10), ('장어', 10), ('정리', 9), ('사업장', 9), ('전복', 8), ('양식업', 8), ('어장', 8)]
#
# < 의료용 물질 및 의약품 제조업 >
# [('제조', 104), ('원료', 50), ('의료', 44), ('사업장', 43), ('혼합', 36), ('가공', 33), ('입고', 30), ('의약품', 27), ('한약', 26), ('조제', 24), ('투입', 20), ('배합', 16), ('과립', 16), ('원단', 16), ('원재료', 15), ('포장', 14), ('제조업', 14), ('기기', 14), ('개발', 12), ('칭량', 12)]
#
# < 수도업 >
# [('공급', 141), ('생활용수', 86), ('정수', 80), ('시설', 49), ('취수', 43), ('상수도', 33), ('수도', 31), ('물', 29), ('정수장', 28), ('관리', 23), ('수요자', 20), ('용수', 19), ('수돗물', 17), ('업소', 17), ('대상', 16), ('행정', 15), ('사업장', 14), ('처리', 13), ('상하수도', 13), ('가정', 12)]
#
# < 코크스, 연탄 및 석유정제품 제조업 >
# [('정제', 28), ('폐유', 28), ('윤활유', 27), ('제조', 24), ('원유', 12), ('원료', 12), ('사업장', 11), ('투입', 11), ('오일', 11), ('혼합', 10), ('연탄', 10), ('기유', 10), ('입고', 8), ('무연탄', 8), ('재생', 8), ('첨가제', 7), ('배합', 7), ('석탄', 7), ('처리', 6), ('폐', 6)]
#
# < 금속 광업 >
# [('채굴', 7), ('광산', 5), ('기계', 3), ('이용', 3), ('금', 3), ('은', 3), ('고객', 2), ('의뢰', 1), ('철광석', 1), ('세하', 1), ('믹', 1), ('게르마늄', 1), ('체취', 1), ('동', 1), ('정광', 1), ('철광', 1), ('생산', 1), ('몰리브덴', 1), ('휘수연광', 1), ('채광', 1)]
#
# < 항공 운송업 >
# [('운송', 34), ('정기', 26), ('항공', 23), ('화물', 20), ('노선', 16), ('일정', 15), ('항공사', 14), ('운행', 14), ('여객', 13), ('승객', 8), ('대상', 7), ('사업장', 7), ('공항', 7), ('고객', 5), ('서비스', 5), ('국내외', 5), ('항공기', 4), ('운송업', 4), ('여행객', 3), ('의뢰', 3)]
#
# < 광업 지원 서비스업 >
# [('사업장', 3), ('자원', 2), ('유전', 2), ('개발', 2), ('광물', 2), ('에너지', 1), ('운영', 1), ('관련', 1), ('서비스업', 1), ('수수료', 1), ('또는', 1), ('계약', 1), ('의거', 1), ('원유', 1), ('지원', 1), ('탐사', 1), ('서비스', 1), ('해외', 1), ('아프리카', 1), ('금', 1)]
#
# < 석탄, 원유 및 천연가스 광업 >
# [('무연탄', 1), ('발파', 1), ('생산', 1)]
#
# < 담배 제조업 >
# [('담배', 4), ('차세대', 2), ('제조', 2), ('투입', 2), ('잎담배', 1), ('판', 1), ('상엽', 1), ('가공', 1), ('궐련', 1), ('상품', 1), ('향료', 1), ('재료', 1), ('정제', 1), ('혼합', 1), ('출하', 1), ('액상', 1), ('잎', 1), ('잎줄기', 1), ('원료', 1), ('슬러리', 1)]

# %%
# 소분류 빈도수 카운트

for i in list(X_train['digit_3'].unique()):
    print('<',digit_3_dict[i],'>')
    cat_words = np.hstack(X_train[X_train['digit_3'] == i]['text'].values)
    cat_words_count = Counter(cat_words)
    print(cat_words_count.most_common(20), '\n')

logger.info("log info")
# Out:
# < 자동차 및 모터사이클 수리업 >
# [('자동차', 10067), ('수리', 9289), ('고객', 5052), ('대상', 4688), ('카센타', 3995), ('부분', 3663), ('특정', 3260), ('정비', 2927), ('전문', 2875), ('서비스', 2823), ('경정비', 2777), ('사업장', 2184), ('타이어', 1983), ('세차', 1850), ('내장', 1437), ('일반인', 1302), ('차량', 1301), ('만', 1280), ('카센터', 1139), ('일반', 1041)]
#
# < 음ㆍ식료품 및 담배 소매업 >
# [('소비자', 14023), ('일반', 13523), ('소매', 11326), ('대상', 9116), ('판매', 8405), ('매장', 6058), ('일반인', 5402), ('가게', 4453), ('사업장', 3422), ('돼지고기', 2871), ('정육점', 2471), ('소고기', 2258), ('고객', 2211), ('과일', 2067), ('반찬', 1876), ('식품', 1840), ('수산물', 1668), ('채소', 1536), ('건강', 1426), ('영업장', 1309)]
#
# < 기타 전문 도매업 >
# [('도매', 5933), ('사업장', 4188), ('수집', 3040), ('고철', 2878), ('판매', 2630), ('산업', 2289), ('사용자', 2040), ('대상', 1511), ('고물상', 1473), ('소매업자', 1408), ('비철', 1347), ('재생', 1204), ('매장', 1107), ('농약', 929), ('원단', 882), ('금속', 815), ('고물', 804), ('비료', 794), ('폐지', 730), ('재', 632)]
#
# < 기타 생활용품 소매업 >
# [('일반', 6897), ('소매', 6697), ('소비자', 6584), ('대상', 4502), ('매장', 3852), ('판매', 3754), ('일반인', 2987), ('사업장', 2355), ('철물', 1970), ('가구', 1882), ('고객', 1391), ('용품', 1328), ('장판', 1292), ('철물점', 1210), ('벽지', 1169), ('가게', 1052), ('전기', 985), ('열쇠', 966), ('주방', 880), ('공구', 755)]
#
# < 비거주 복지시설 운영업 >
# [('어린이', 8235), ('보육', 7553), ('유아', 5924), ('취학전', 5536), ('서비스', 4446), ('대상', 4302), ('위탁', 4298), ('아동', 3853), ('복지', 3767), ('보호자', 3706), ('센터', 2647), ('노인', 2551), ('교육', 2548), ('인가', 2304), ('요양', 2241), ('관할', 1936), ('방문', 1720), ('어린이집', 1502), ('구청', 1440), ('돌봄', 1349)]
#
# < 일반 목적용 기계 제조업 >
# [('제조', 1534), ('가공', 1315), ('조립', 1095), ('절단', 1007), ('철', 1001), ('부품', 868), ('기계', 867), ('용접', 676), ('철판', 552), ('산업', 521), ('입고', 516), ('제작', 501), ('사업장', 485), ('금속', 414), ('유압', 321), ('장치', 320), ('밸브', 309), ('스텐', 302), ('펌프', 289), ('절삭', 246)]
#
# < 음식점업 >
# [('시설', 95897), ('접객', 95257), ('갖추', 93227), ('음식점', 69602), ('판매', 33137), ('제공', 22038), ('한식', 13529), ('치킨', 11170), ('음식', 10776), ('식당', 8429), ('대상', 7421), ('매장', 6261), ('분식', 5870), ('일반', 5490), ('김밥', 5334), ('조리', 5109), ('사업장', 4921), ('일반인', 4909), ('삼겹살', 4836), ('영업장', 4425)]
#
# < 기타 식품 제조업 >
# [('제조', 4718), ('떡', 3057), ('건강', 1774), ('즙', 1380), ('판매', 1354), ('쌀', 1315), ('방앗간', 1051), ('사업장', 1036), ('분쇄', 1021), ('가공', 1018), ('식품', 962), ('대상', 924), ('류', 824), ('고추', 789), ('고객', 746), ('콩', 740), ('가열', 738), ('혼합', 701), ('일반', 683), ('소비자', 675)]
#
# < 입법 및 일반 정부 행정 >
# [('행정', 1168), ('서비스', 846), ('집행', 650), ('사무', 606), ('지방행정', 549), ('주민', 493), ('센터', 310), ('면사무소', 278), ('대상', 172), ('동', 159), ('지방', 151), ('민원', 124), ('자치', 123), ('사무소', 122), ('업무', 110), ('관리', 105), ('기관', 104), ('선거', 97), ('공공', 94), ('제공', 83)]
#
# < 전기 및 통신 공사업 >
# [('공사', 3994), ('전기', 3198), ('고객', 2437), ('현장', 1417), ('통신', 1140), ('배선', 1068), ('사업장', 1031), ('요청', 984), ('건물', 966), ('내부', 896), ('요구', 838), ('의뢰', 837), ('설치', 780), ('사업', 491), ('건설', 463), ('일반', 299), ('건축물', 274), ('케이블', 252), ('설비', 221), ('전기공', 212)]
#
# < 수산물 가공 및 저장 처리업 >
# [('제조', 358), ('가공', 288), ('김', 196), ('염장', 190), ('건조', 175), ('소금', 157), ('수산물', 151), ('구입', 134), ('사업장', 129), ('멸치', 125), ('굴비', 122), ('세척', 119), ('조기', 118), ('오징어', 112), ('판매', 95), ('물김', 78), ('조미', 76), ('입고', 68), ('냉동', 68), ('미역', 56)]
#
# < 섬유, 의복, 신발 및 가죽제품 소매업 >
# [('매장', 23247), ('일반', 19894), ('소비자', 19269), ('소매', 15872), ('의류', 14342), ('대상', 14277), ('판매', 9779), ('여성', 9126), ('일반인', 7603), ('고객', 4599), ('가게', 3105), ('사업장', 2295), ('바지', 2023), ('셔츠', 1826), ('신발', 1799), ('속옷', 1548), ('정장', 1486), ('남성', 1476), ('옷', 1451), ('겉옷', 1409)]
#
# < 기타 교육기관 >
# [('대상', 16325), ('학원', 14746), ('교육', 12758), ('학생', 9153), ('일반인', 6531), ('피아노', 5251), ('미술', 3468), ('생', 3326), ('태권도', 2981), ('교습', 2765), ('사업장', 2467), ('서비스', 2377), ('강습', 2141), ('음악', 1665), ('수강', 1508), ('영어', 1382), ('도장', 1164), ('요가', 1145), ('지도', 1097), ('교습소', 1047)]
#
# < 기타 운송관련 서비스업 >
# [('화물', 3672), ('운송', 2603), ('주차장', 2387), ('사업장', 1789), ('주선', 1449), ('화주', 1352), ('대상', 1270), ('간', 1184), ('운송업자', 1111), ('주차', 1068), ('운영', 1041), ('서비스', 1030), ('알선', 846), ('차량', 771), ('고객', 656), ('중개', 648), ('일반', 568), ('관리', 448), ('일반인', 392), ('사무실', 356)]
#
# < 가전제품 및 정보 통신장비 소매업 >
# [('매장', 4541), ('일반', 4504), ('소비자', 4259), ('소매', 3999), ('핸드폰', 3926), ('대상', 3705), ('판매', 3630), ('휴대폰', 3013), ('일반인', 2187), ('고객', 1421), ('사업장', 1393), ('컴퓨터', 1113), ('가게', 900), ('기기', 858), ('통신', 775), ('가전제품', 560), ('영업장', 454), ('주변기기', 347), ('소매업', 325), ('제품', 249)]
#
# < 운송장비 임대업 >
# [('고객', 538), ('사업장', 524), ('대상', 500), ('대여', 425), ('자동차', 375), ('차량', 315), ('임대', 262), ('일반인', 163), ('렌트', 149), ('렌트카', 119), ('승용차', 106), ('일반', 95), ('서비스', 95), ('운전자', 95), ('없이', 95), ('요청', 75), ('사무실', 69), ('영업장', 55), ('임대업', 54), ('의뢰', 40)]
#
# < 스포츠 서비스업 >
# [('대상', 4700), ('일반인', 3710), ('당구장', 3668), ('시설', 3652), ('갖추', 3083), ('당구', 2657), ('체력', 2596), ('골프', 2567), ('단련', 2520), ('연습장', 2283), ('서비스', 2250), ('운영', 2070), ('장운영', 1356), ('헬스', 1193), ('고객', 1143), ('제공', 1131), ('사업장', 1071), ('장', 928), ('헬스클럽', 867), ('스크린골프', 718)]
#
# < 주점 및 비알코올 음료점업 >
# [('접객', 40886), ('시설', 34285), ('갖추', 30521), ('커피', 22390), ('주점', 15331), ('맥주', 14460), ('판매', 12835), ('요원', 10218), ('제공', 9489), ('음료', 9143), ('소주', 9095), ('없이', 6594), ('커피숍', 5147), ('주류', 4924), ('양주', 4746), ('안주', 4570), ('매장', 3808), ('무도', 3449), ('대상', 3193), ('사업장', 3092)]
#
# < 고무제품 제조업 >
# [('고무', 889), ('제조', 204), ('성형', 169), ('가공', 116), ('절단', 115), ('자동차', 106), ('제품', 98), ('입고', 98), ('부품', 96), ('패킹', 95), ('프레스', 83), ('실리콘', 70), ('재단', 66), ('배합', 62), ('경화', 60), ('접합', 58), ('비', 54), ('사업장', 50), ('산업', 49), ('창', 47)]
#
# < 미용, 욕탕 및 유사 서비스업 >
# [('대상', 24090), ('서비스', 17518), ('고객', 17510), ('미용실', 15363), ('염색', 15133), ('파마', 13729), ('미용', 13049), ('일반인', 10460), ('발', 10102), ('컷트', 8126), ('일반', 7027), ('커트', 6860), ('피부', 6760), ('미장원', 6356), ('제공', 5539), ('관리', 5235), ('사업장', 4699), ('머리', 4662), ('마사지', 3930), ('자르기', 3706)]
#
# < 특수 목적용 기계 제조업 >
# [('가공', 2622), ('금형', 2518), ('기계', 2324), ('제조', 2301), ('부품', 1757), ('철', 1608), ('절단', 1095), ('금속', 1025), ('제작', 1004), ('조립', 954), ('철판', 770), ('절삭', 655), ('사업장', 654), ('용접', 618), ('입고', 591), ('산업', 584), ('장비', 578), ('반도체', 559), ('밀링', 517), ('설계', 493)]
#
# < 연료 소매업 >
# [('주유소', 2728), ('일반', 1707), ('소매', 1662), ('차량', 1578), ('소비자', 1561), ('경유', 1373), ('가스', 1344), ('휘발유', 1310), ('시설', 1186), ('대상', 1173), ('갖추', 1138), ('판매', 1137), ('연료', 956), ('주유', 922), ('액체', 845), ('LPG', 695), ('일반인', 606), ('급유', 547), ('사업장', 484), ('석유', 471)]
#
# < 그 외 기타 개인 서비스업 >
# [('세탁', 6785), ('대상', 6400), ('세탁소', 5751), ('고객', 4827), ('서비스', 4551), ('일반인', 3406), ('일반', 3152), ('드라이', 2095), ('다림질', 2026), ('사업장', 1857), ('크리', 1643), ('닝', 1636), ('세탁물', 1593), ('애견', 1305), ('의류', 1107), ('제공', 831), ('상대', 813), ('점술', 770), ('미용', 756), ('빨래방', 676)]
#
# < 기타 협회 및 단체 >
# [('종교', 25871), ('활동', 13905), ('서비스', 13459), ('교회', 13072), ('기독교', 10746), ('계통', 9527), ('대상', 3996), ('불교', 2955), ('신도', 1920), ('단체', 1683), ('회원', 1520), ('절', 1433), ('사찰', 1118), ('사무실', 1074), ('관리', 832), ('협회', 761), ('계', 713), ('봉사', 687), ('사업장', 663), ('인', 621)]
#
# < 종합 소매업 >
# [('소매', 12551), ('소비자', 10668), ('일반', 10483), ('편의점', 10196), ('음식료품', 9564), ('위주', 7687), ('대상', 7277), ('판매', 7249), ('식료품', 7014), ('체인', 6640), ('계약', 6371), ('체결', 5531), ('일반인', 3955), ('매장', 3627), ('잡화', 3532), ('미만', 3418), ('담배', 3189), ('슈퍼', 2760), ('음', 2537), ('사업장', 2419)]
#
# < 일반 및 생활 숙박시설 운영업 >
# [('숙박', 15244), ('서비스', 8459), ('시설', 6266), ('제공', 5932), ('갖추', 5023), ('대상', 4749), ('일반인', 4470), ('모텔', 3146), ('펜션', 2981), ('민박', 2657), ('없이', 1498), ('룸서비스', 1405), ('개별', 1263), ('여관', 1110), ('고객', 672), ('운영', 585), ('호텔', 420), ('사업장', 398), ('일반', 375), ('숙박업', 367)]
#
# < 생활용품 도매업 >
# [('도매', 12026), ('소매업자', 6988), ('사업장', 5580), ('대상', 3359), ('매장', 3200), ('상가', 2997), ('의류', 2899), ('용품', 2450), ('판매', 1493), ('화장품', 1381), ('여성', 1133), ('일반', 1104), ('산업', 1049), ('사용자', 981), ('영업장', 975), ('도소매', 949), ('의약품', 948), ('소매', 943), ('고객', 863), ('업체', 718)]
#
# < 도로 화물 운송업 >
# [('화물', 48012), ('운송', 47682), ('고객', 46533), ('화물자동차', 45905), ('요청', 45894), ('서비스', 45675), ('용달', 26127), ('개별', 17424), ('일반', 2887), ('사업장', 810), ('화물차', 791), ('의뢰', 592), ('톤', 480), ('이용', 412), ('운송업', 366), ('이삿짐', 340), ('이사', 338), ('차량', 302), ('대상', 289), ('운반', 197)]
#
# < 기타 금속 가공제품 제조업 >
# [('가공', 6448), ('부품', 5080), ('철', 3594), ('기계', 3277), ('금속', 3274), ('절삭', 2804), ('제조', 2059), ('절단', 1896), ('철판', 1378), ('용접', 1339), ('자동차', 1305), ('선반', 1194), ('입고', 973), ('산업', 952), ('알루미늄', 934), ('밀링', 833), ('스텐', 789), ('사업장', 772), ('제작', 764), ('연마', 752)]
#
# < 전문 디자인업 >
# [('디자인', 1744), ('사업장', 798), ('고객', 750), ('인테리어', 471), ('의뢰', 404), ('요청', 340), ('사무실', 287), ('제품', 216), ('그래픽', 171), ('실내', 152), ('서비스', 145), ('대상', 126), ('제공', 122), ('기획', 116), ('설계', 88), ('현장', 85), ('의류', 78), ('요구', 69), ('산업', 63), ('제작', 61)]
#
# < 기타 상품 전문 소매업 >
# [('일반', 14894), ('소비자', 14379), ('소매', 13762), ('대상', 11011), ('판매', 9636), ('매장', 9402), ('일반인', 6835), ('화장품', 5226), ('약국', 5025), ('꽃', 3696), ('고객', 3467), ('사업장', 3197), ('용품', 2533), ('의약품', 2498), ('안경', 2295), ('가게', 1962), ('중고', 1534), ('귀금속', 1479), ('약', 1474), ('안경점', 1192)]
#
# < 유원지 및 기타 오락관련 서비스업 >
# [('노래방', 10027), ('갖추', 6888), ('시설', 6577), ('노래', 6272), ('대상', 5057), ('운영', 4368), ('연습장', 3670), ('일반인', 3509), ('제공', 3193), ('서비스', 3039), ('방', 2923), ('게임', 2172), ('PC', 1778), ('사업장', 1678), ('연습', 1493), ('컴퓨터', 1488), ('복권', 1379), ('고객', 1333), ('기기', 1241), ('일반', 1089)]
#
# < 건물설비 설치 공사업 >
# [('고객', 3591), ('공사', 3285), ('배관', 2433), ('설치', 2285), ('건물', 1589), ('현장', 1506), ('요구', 1434), ('요청', 1338), ('사업장', 1334), ('설비', 1283), ('의뢰', 1073), ('보일러', 1034), ('시설', 601), ('난방', 591), ('소방', 567), ('냉난방', 442), ('건설', 425), ('에어컨', 423), ('기계', 418), ('시공', 356)]
#
# < 플라스틱 제품 제조업 >
# [('플라스틱', 2660), ('제조', 1269), ('성형', 1176), ('사출', 1033), ('가공', 614), ('입고', 599), ('절단', 569), ('부품', 560), ('비닐', 461), ('필름', 459), ('조립', 408), ('사업장', 361), ('제품', 327), ('PVC', 319), ('자동차', 303), ('원료', 300), ('용기', 283), ('PP', 262), ('원재료', 237), ('제작', 237)]
#
# < 일반 교습학원 >
# [('학원', 15245), ('학생', 10823), ('대상', 10756), ('교육', 9754), ('수학', 7453), ('영어', 6373), ('서비스', 2632), ('교습', 1892), ('보습', 1701), ('초', 1438), ('교과', 1410), ('교습소', 1305), ('생', 1305), ('일반', 1161), ('국어', 856), ('지도', 843), ('논술', 647), ('방문', 644), ('학습', 570), ('과학', 524)]
#
# < 가구 제조업 >
# [('목재', 1505), ('가구', 1404), ('절단', 1197), ('제조', 1099), ('제작', 748), ('조립', 729), ('씽크대', 718), ('재단', 649), ('접합', 451), ('사업장', 446), ('가공', 358), ('고객', 354), ('주방', 321), ('합판', 280), ('MDF', 271), ('주문', 251), ('나무', 242), ('싱크대', 231), ('원목', 228), ('구입', 186)]
#
# < 법무관련 서비스업 >
# [('대리', 2528), ('의뢰인', 2201), ('사무실', 2041), ('대행', 1386), ('소송', 1349), ('신청', 1122), ('등기', 994), ('법률', 957), ('변호', 915), ('의뢰', 910), ('서류', 892), ('경매', 771), ('법무사', 679), ('상담', 665), ('고객', 647), ('사무소', 643), ('서비스', 509), ('작성', 445), ('기관', 425), ('제출', 405)]
#
# < 기계장비 및 관련 물품 도매업 >
# [('도매', 8892), ('사업장', 6296), ('산업', 4862), ('사용자', 4253), ('부품', 2605), ('기계', 2464), ('대상', 2369), ('소매업자', 2190), ('기기', 2110), ('매장', 2050), ('장비', 1889), ('판매', 1857), ('컴퓨터', 1252), ('전기', 1205), ('의료', 1181), ('영업장', 967), ('도소매', 815), ('사무실', 748), ('고객', 746), ('일반', 732)]
#
# < 소프트웨어 개발 및 공급업 >
# [('개발', 3978), ('소프트웨어', 2993), ('사업장', 1956), ('공급', 1904), ('시스템', 949), ('응용', 851), ('사무실', 722), ('프로그램', 561), ('고객', 441), ('컴퓨터', 422), ('의뢰', 326), ('운영', 277), ('게임', 271), ('체제', 232), ('범용', 185), ('요청', 184), ('S', 180), ('W', 178), ('대상', 176), ('성', 164)]
#
# < 건축 기술, 엔지니어링 및 관련 기술 서비스업 >
# [('설계', 4566), ('건축', 3375), ('고객', 2776), ('요청', 1692), ('사업장', 1664), ('서비스', 1509), ('사무실', 1292), ('의뢰', 1252), ('사무소', 1107), ('토목', 900), ('감리', 832), ('엔지니어링', 780), ('관련', 732), ('대상', 436), ('제공', 389), ('건축사', 326), ('건물', 326), ('주택', 312), ('요구', 253), ('건설', 252)]
#
# < 공중 보건 의료업 >
# [('보건', 639), ('대상', 516), ('보건소', 468), ('진료', 460), ('서비스', 458), ('진료소', 263), ('의료', 262), ('예방', 243), ('주민', 232), ('일반', 223), ('국민', 204), ('환자', 194), ('건강', 192), ('공중', 173), ('질병', 168), ('관리', 166), ('외래', 145), ('위주', 122), ('지역', 120), ('지소', 117)]
#
# < 기타 숙박업 >
# [('고시원', 1037), ('숙박', 995), ('제공', 801), ('시설', 643), ('갖추', 494), ('숙식', 455), ('서비스', 349), ('대상', 327), ('텔', 299), ('일반인', 293), ('운영', 263), ('고시', 261), ('비교', 103), ('장기', 101), ('사업장', 90), ('간의', 90), ('기숙사', 70), ('고객', 65), ('장소', 62), ('원룸', 55)]
#
# < 기타 과학기술 서비스업 >
# [('고객', 598), ('검사', 593), ('측량', 538), ('사업장', 475), ('안전', 447), ('의뢰', 407), ('요청', 352), ('서비스', 349), ('전기', 271), ('설계', 242), ('관리', 237), ('현장', 223), ('사무실', 181), ('분석', 177), ('장비', 158), ('기계', 146), ('점검', 139), ('기술', 135), ('시험', 131), ('대행', 129)]
#
# < 봉제의복 제조업 >
# [('재단', 2224), ('제조', 1958), ('원단', 1884), ('재봉', 1281), ('의류', 1029), ('사업장', 810), ('여성', 776), ('봉제', 627), ('한복', 591), ('티셔츠', 463), ('면', 408), ('정장', 350), ('고객', 321), ('제작', 292), ('임가공', 254), ('의뢰', 235), ('셔츠', 209), ('봉재', 209), ('공장', 208), ('실', 208)]
#
# < 문화, 오락 및 여가 용품 소매업 >
# [('소매', 3256), ('일반', 2989), ('대상', 2855), ('소비자', 2851), ('용품', 2678), ('판매', 2448), ('일반인', 2157), ('매장', 2065), ('문구', 1892), ('문구점', 1260), ('낚시', 994), ('사업장', 944), ('류', 917), ('자전거', 908), ('고객', 697), ('스포츠', 629), ('서적', 597), ('서점', 529), ('학생', 424), ('골프', 402)]
#
# < 상품 중개업 >
# [('중개', 1840), ('사업장', 1160), ('무역', 570), ('상품', 516), ('종합', 420), ('사무실', 302), ('중개업', 284), ('대상', 232), ('수산물', 223), ('도매', 203), ('판매', 194), ('고객', 191), ('기계', 169), ('통해', 164), ('산업', 130), ('수출', 129), ('수입', 119), ('대리', 117), ('장비', 117), ('경매', 114)]
#
# < 자동차 부품 및 내장품 판매업 >
# [('자동차', 3486), ('부품', 2153), ('판매', 1926), ('대상', 1812), ('사업장', 1527), ('타이어', 1397), ('고객', 1238), ('일반', 1041), ('매장', 1025), ('소비자', 834), ('용품', 799), ('소매', 771), ('도매', 699), ('일반인', 548), ('차량', 441), ('영업장', 360), ('내장품', 332), ('도소매', 301), ('션', 270), ('산업', 247)]
#
# < 개인 및 가정용품 수리업 >
# [('수선', 5762), ('수리', 3155), ('고객', 3040), ('옷', 2193), ('대상', 1854), ('요청', 1645), ('사업장', 1541), ('의류', 1300), ('일반인', 1271), ('서비스', 1226), ('일반', 896), ('구두', 786), ('매장', 738), ('의뢰', 730), ('영업장', 705), ('소비자', 587), ('가게', 551), ('가전제품', 446), ('제품', 427), ('열쇠', 392)]
#
# < 부동산관련 서비스업 >
# [('부동산', 43846), ('중개', 31243), ('서비스', 18704), ('계약', 15749), ('관리', 14268), ('개소', 9697), ('아파트', 8991), ('의거', 6663), ('수수료', 6089), ('사무소', 5252), ('사무실', 4057), ('통해', 4003), ('사업장', 3889), ('대상', 3884), ('음', 3664), ('입주자', 3556), ('거래', 3369), ('고객', 3096), ('주거', 2806), ('건물', 2640)]
#
# < 그 외 기타 제품 제조업 >
# [('간판', 1688), ('제작', 1375), ('광고', 1130), ('제조', 1002), ('현수막', 934), ('사업장', 891), ('고객', 857), ('물', 756), ('의뢰', 433), ('요청', 341), ('주문', 303), ('대상', 269), ('절단', 266), ('도장', 258), ('아크릴', 229), ('액자', 209), ('표구', 183), ('가공', 172), ('출력', 168), ('일반인', 165)]
#
# < 의원 >
# [('환자', 13760), ('외래', 12204), ('진료', 11069), ('위주', 10350), ('의원', 9937), ('치과', 7031), ('서비스', 5986), ('대상', 2882), ('일반', 2525), ('내과', 2412), ('치료', 2175), ('병원', 1205), ('한방', 1087), ('침', 1064), ('피부과', 811), ('일반인', 807), ('이비인후과', 665), ('뜸', 645), ('한약', 615), ('소아과', 529)]
#
# < 건축 자재, 철물 및 난방장치 도매업 >
# [('도매', 5054), ('사업장', 3298), ('산업', 2615), ('사용자', 2466), ('건축', 1562), ('소매업자', 1490), ('대상', 1455), ('자재', 1369), ('매장', 1217), ('판매', 1123), ('철물', 1008), ('공구', 891), ('페인트', 686), ('일반', 604), ('목재', 599), ('영업장', 529), ('타일', 515), ('재', 514), ('고객', 459), ('건축자', 441)]
#
# < 전동기, 발전기 및 전기 변환ㆍ공급ㆍ제어 장치 제조업 >
# [('전기', 1344), ('조립', 1056), ('제조', 926), ('자동', 580), ('부품', 462), ('판넬', 450), ('장치', 427), ('배전반', 403), ('제어반', 356), ('사업장', 351), ('전선', 340), ('가공', 284), ('제작', 281), ('제어', 268), ('절단', 267), ('입고', 238), ('철판', 225), ('회로', 221), ('철', 191), ('차단기', 172)]
#
# < 회계 및 세무관련 서비스업 >
# [('세무', 3758), ('의뢰', 1984), ('대리', 1889), ('기장', 1785), ('관련', 1740), ('사무실', 1717), ('업무', 1540), ('조정', 1190), ('아서', 702), ('고객', 691), ('서비스', 561), ('회계', 482), ('세무사', 474), ('조세', 465), ('대상', 388), ('대행', 368), ('세', 314), ('사업장', 304), ('무회계', 279), ('사무소', 268)]
#
# < 육상 여객 운송업 >
# [('운송', 38753), ('승객', 38528), ('대상', 38241), ('서비스', 38074), ('일반인', 38061), ('개인택시', 37854), ('택시', 561), ('버스', 400), ('고객', 276), ('운행', 269), ('전세', 183), ('정기', 177), ('일반', 151), ('운송업', 137), ('시내버스', 133), ('도시', 131), ('사업장', 125), ('관광버스', 117), ('이용', 114), ('운영', 107)]
#
# < 여행사 및 기타 여행 보조 서비스업 >
# [('여행', 2414), ('대상', 1653), ('알선', 1532), ('고객', 1069), ('여행사', 841), ('국내외', 745), ('사무실', 705), ('서비스', 514), ('사업장', 456), ('일반인', 429), ('국내', 338), ('일반', 316), ('관광객', 212), ('국외', 208), ('여행객', 172), ('상품', 141), ('판매', 117), ('관광', 110), ('사업', 109), ('제공', 107)]
#
# < 비료, 농약 및 살균ㆍ살충제 제조업 >
# [('비료', 214), ('제조', 140), ('퇴비', 76), ('유기질', 63), ('혼합', 57), ('발효', 55), ('사업장', 52), ('배합', 37), ('생산', 36), ('톱밥', 34), ('화학', 32), ('제조업', 31), ('처리', 29), ('원료', 27), ('복합', 26), ('분', 26), ('미생물', 24), ('분뇨', 23), ('물질', 22), ('식물', 22)]
#
# < 부동산 임대 및 공급업 >
# [('임대', 4798), ('건물', 3006), ('사무실', 2360), ('분양', 1757), ('사업장', 1752), ('개발', 1749), ('부동산', 1551), ('비', 1524), ('주거', 1502), ('상가', 1387), ('대상', 1265), ('고객', 932), ('점포', 888), ('판매', 797), ('임대업', 778), ('거주', 699), ('공급', 665), ('건설', 594), ('공사', 518), ('도', 509)]
#
# < 창작 및 예술관련 서비스업 >
# [('공연', 991), ('대상', 430), ('기획', 416), ('사업장', 329), ('예술', 238), ('일반인', 224), ('고객', 196), ('공연장', 195), ('운영', 166), ('연습', 142), ('사무실', 140), ('행사', 134), ('서비스', 130), ('의뢰', 130), ('시설', 124), ('제작', 115), ('음악', 111), ('연극', 110), ('대중', 109), ('단체', 104)]
#
# < 건물ㆍ산업설비 청소 및 방제 서비스업 >
# [('청소', 1406), ('고객', 1061), ('건물', 1058), ('서비스', 583), ('사업장', 525), ('소독', 479), ('요청', 400), ('요구', 377), ('의뢰', 349), ('관리', 267), ('방역', 214), ('현장', 199), ('대행', 198), ('용역', 193), ('대상', 190), ('방제', 145), ('위생', 140), ('사무실', 119), ('일반인', 113), ('일반', 99)]
#
# < 광고업 >
# [('광고', 3112), ('사업장', 1428), ('대행', 1140), ('고객', 973), ('물', 832), ('의뢰', 625), ('요청', 485), ('광고주', 455), ('사무실', 421), ('대리', 421), ('작성', 408), ('제작', 402), ('디자인', 367), ('기획', 309), ('설계', 284), ('광고문', 283), ('영업장', 273), ('서비스', 256), ('대행업', 250), ('안작', 237)]
#
# < 오디오물 출판 및 원판 녹음업 >
# [('녹음', 130), ('제작', 93), ('사업장', 87), ('음악', 78), ('음반', 69), ('고객', 57), ('시설', 56), ('녹음실', 41), ('스튜디오', 36), ('갖추', 32), ('운영', 30), ('의뢰', 27), ('오디오', 25), ('기획', 24), ('물', 24), ('대상', 23), ('요구', 21), ('사무실', 21), ('출판', 21), ('서비스', 18)]
#
# < 산업용 기계 및 장비 수리업 >
# [('수리', 3959), ('사업장', 1282), ('기계', 1185), ('고객', 1140), ('농기계', 695), ('대상', 583), ('장비', 554), ('요청', 526), ('의뢰', 523), ('선박', 517), ('서비스', 490), ('전문', 370), ('일반', 323), ('모터', 306), ('산업', 298), ('부품', 256), ('전기', 221), ('기기', 199), ('특정', 189), ('부분', 185)]
#
# < 반도체 제조업 >
# [('반도체', 276), ('부품', 193), ('제조', 125), ('가공', 79), ('조립', 66), ('사업장', 62), ('장비', 60), ('소자', 56), ('제조업', 40), ('입고', 35), ('LED', 34), ('알루미늄', 33), ('웨이퍼', 22), ('회로', 21), ('절단', 21), ('기타', 21), ('제작', 17), ('칩', 16), ('다이오드', 15), ('철', 15)]
#
# < 음ㆍ식료품 및 담배 도매업 >
# [('도매', 12028), ('소매업자', 8337), ('사업장', 5978), ('대상', 2825), ('매장', 2337), ('가공', 2250), ('수산물', 2236), ('식품', 1838), ('판매', 1668), ('영업장', 1382), ('채소', 1329), ('일반', 1230), ('류', 1086), ('납품', 1037), ('농산물', 1003), ('식자재', 861), ('과일', 848), ('육류', 791), ('산업', 784), ('우유', 782)]
#
# < 전자 부품 제조업 >
# [('부품', 733), ('기판', 580), ('회로', 539), ('제조', 466), ('조립', 428), ('인쇄', 352), ('PCB', 300), ('가공', 267), ('사업장', 221), ('입고', 211), ('실장', 141), ('인', 119), ('쇄', 115), ('반도체', 100), ('센서', 99), ('검사', 99), ('제조업', 96), ('pcb', 75), ('연성', 62), ('전기', 61)]
#
# < 건물 건설업 >
# [('건설', 3563), ('현장', 2130), ('고객', 2082), ('주택', 1680), ('요구', 1136), ('건물', 955), ('건축', 725), ('단독', 601), ('요청', 600), ('의뢰', 550), ('사업장', 506), ('건설업', 502), ('공사', 494), ('주거', 421), ('이용', 377), ('철근', 371), ('시멘트', 334), ('상업', 236), ('아파트', 233), ('상가', 207)]
#
# < 코르크 및 조물 제품 제조업 >
# [('대나무', 16), ('제조', 15), ('가공', 11), ('사업장', 8), ('매트', 8), ('절단', 8), ('볏짚', 7), ('나무', 6), ('제품', 6), ('조물', 5), ('조합', 5), ('고객', 5), ('제작', 5), ('야자', 5), ('코르크', 5), ('콜크', 5), ('자재', 4), ('죽', 4), ('직조', 3), ('매생', 3)]
#
# < 실내건축 및 건축마무리 공사업 >
# [('고객', 7413), ('공사', 6274), ('인테리어', 4359), ('실내', 3599), ('현장', 3108), ('사업장', 2950), ('요청', 2876), ('의뢰', 2399), ('요구', 2235), ('건물', 1785), ('도배', 1613), ('장식', 1452), ('창호', 1216), ('시공', 1083), ('장판', 938), ('설치', 767), ('건설', 727), ('유리', 726), ('방수', 699), ('대상', 675)]
#
# < 금속 주조업 >
# [('주물', 152), ('알루미늄', 128), ('주조', 109), ('고철', 93), ('제조', 73), ('선철', 70), ('용해', 64), ('부품', 62), ('조형', 55), ('가공', 54), ('금속', 43), ('철', 42), ('해', 42), ('물', 41), ('입고', 39), ('비철', 37), ('캐스팅', 33), ('기계', 33), ('절단', 31), ('제작', 20)]
#
# < 보관 및 창고업 >
# [('창고', 1318), ('보관', 1107), ('물류', 527), ('물품', 475), ('없이', 370), ('사업장', 290), ('온도', 286), ('조절', 279), ('장치', 276), ('고객', 233), ('창고업', 226), ('냉동', 185), ('요청', 172), ('시설', 158), ('일반', 139), ('냉장', 137), ('제공', 116), ('농산물', 108), ('관리', 98), ('특수', 94)]
#
# < 초등 교육기관 >
# [('교육', 3581), ('초등', 2609), ('유치원', 2108), ('학교', 1635), ('취학전', 1594), ('인가', 1434), ('교육청', 1345), ('관할', 1117), ('아동', 1096), ('서비스', 1057), ('대상', 890), ('지역', 801), ('초등학생', 621), ('아동교육', 600), ('유아', 422), ('보육', 269), ('학생', 210), ('위한', 201), ('병설', 191), ('진학', 181)]
#
# < 곡물 가공품, 전분 및 전분제품 제조업 >
# [('도정', 640), ('곡물', 582), ('쌀', 551), ('정미소', 319), ('제조', 240), ('벼', 227), ('분쇄', 211), ('방앗간', 176), ('판매', 142), ('가공', 131), ('사업장', 130), ('보리', 128), ('갖추', 112), ('누룽지', 106), ('대상', 98), ('고객', 96), ('시설', 94), ('생산', 85), ('가루', 81), ('일반인', 80)]
#
# < 기반조성 및 시설물 축조관련 전문공사업 >
# [('공사', 3282), ('현장', 2651), ('고객', 2354), ('건설', 1674), ('철근', 1291), ('콘크리트', 1198), ('요구', 1128), ('요청', 838), ('의뢰', 708), ('사업장', 595), ('사업', 531), ('설치', 464), ('건물', 445), ('철거', 404), ('토목', 386), ('해체', 345), ('철골', 319), ('이용', 287), ('구조물', 283), ('공', 271)]
#
# < 무점포 소매업 >
# [('상거래', 3530), ('판매', 3348), ('사업장', 2890), ('인터넷', 2075), ('온라인', 1838), ('일반', 1646), ('대상', 1580), ('소매', 1566), ('소비자', 1298), ('화장품', 1288), ('방문', 1217), ('의류', 1018), ('사무실', 957), ('고객', 874), ('용품', 845), ('식품', 683), ('배달', 666), ('일반인', 646), ('건강', 576), ('통신망', 431)]
#
# < 산업 및 전문가 단체 >
# [('회원', 921), ('협회', 688), ('관리', 576), ('이익', 571), ('단체', 525), ('대상', 364), ('사무실', 356), ('향상', 312), ('증진', 249), ('사업장', 236), ('위한', 209), ('간', 174), ('상호', 170), ('인', 148), ('도', 148), ('산업', 141), ('서비스', 113), ('권익', 111), ('조합', 110), ('위해', 108)]
#
# < 도서관, 사적지 및 유사 여가관련 서비스업 >
# [('독서실', 2614), ('대상', 1527), ('일반인', 1425), ('운영', 1350), ('학생', 1006), ('도서관', 754), ('제공', 655), ('서비스', 590), ('시설', 520), ('도서', 332), ('장소', 303), ('사업장', 293), ('없이', 262), ('숙박', 254), ('전시', 240), ('일반', 220), ('주민', 203), ('열람', 201), ('공간', 195), ('대여', 181)]
#
# < 선박 및 보트 건조업 >
# [('선박', 423), ('철판', 229), ('구성', 212), ('절단', 189), ('부분품', 178), ('용접', 153), ('제조', 144), ('입고', 109), ('부품', 86), ('철', 83), ('가공', 78), ('취부', 67), ('조립', 62), ('사업장', 61), ('파이프', 53), ('건조', 53), ('조선', 43), ('수리', 42), ('제작', 39), ('엔진', 30)]
#
# < 상품 종합 도매업 >
# [('종합', 400), ('사업장', 351), ('상품', 343), ('도매', 281), ('무역', 212), ('소매업자', 145), ('도매업', 69), ('대상', 68), ('수출', 56), ('사무실', 54), ('계정', 53), ('고객', 48), ('용품', 47), ('생활', 46), ('무역업', 44), ('수입', 42), ('잡화', 38), ('산업', 35), ('판매', 31), ('선용품', 28)]
#
# < 기타 화학제품 제조업 >
# [('제조', 675), ('화장품', 322), ('혼합', 306), ('사업장', 301), ('원료', 277), ('배합', 191), ('비누', 135), ('입고', 124), ('제조업', 107), ('가공', 104), ('활성제', 104), ('계면', 100), ('세제', 93), ('투입', 87), ('화학', 87), ('재료', 80), ('접착제', 80), ('글리세린', 75), ('수지', 68), ('천연', 68)]
#
# < 기타 비금속광물 광업 >
# [('천일염', 206), ('해수', 164), ('증발', 145), ('염전', 114), ('시켜', 103), ('생산', 96), ('바닷물', 69), ('태양열', 67), ('시설', 54), ('갖춰', 28), ('갖추', 21), ('제공', 9), ('광물', 9), ('소금', 8), ('채굴', 7), ('광업', 7), ('채취', 6), ('판매', 5), ('화염', 5), ('천연', 4)]
#
# < 인쇄 및 인쇄관련 산업 >
# [('쇄', 1824), ('인쇄', 1673), ('인', 1556), ('종이', 1235), ('잉크', 1005), ('사업장', 749), ('옵', 641), ('인쇄물', 638), ('고객', 555), ('전단지', 464), ('스크린', 439), ('판', 407), ('명함', 401), ('의뢰', 391), ('인쇄소', 366), ('계약', 329), ('주문', 279), ('제작', 259), ('경인', 248), ('카다', 236)]
#
# < 보험 및 연금관련 서비스업 >
# [('보험', 2162), ('대리', 1175), ('대상', 1155), ('중개', 949), ('사업장', 757), ('일반', 599), ('보험계약', 597), ('체결', 489), ('대리점', 488), ('고객', 475), ('대중', 422), ('기업', 392), ('알선', 388), ('일반인', 387), ('손해', 350), ('서비스', 221), ('사무실', 218), ('사정', 157), ('회사', 147), ('사업자', 139)]
#
# < 중등 교육기관 >
# [('교육', 1500), ('서비스', 893), ('중학교', 773), ('고등학교', 671), ('대상', 540), ('진학', 480), ('위한', 458), ('인문계', 397), ('중등교육', 302), ('중학생', 281), ('학생', 267), ('대학', 235), ('학교', 228), ('고등학생', 143), ('중학', 139), ('과정', 112), ('고등교육', 76), ('제공', 56), ('기관', 55), ('초등', 52)]
#
# < 은행 및 저축기관 >
# [('자금', 3983), ('수신', 3863), ('대상', 2555), ('일반', 1732), ('고객', 1660), ('대중', 1357), ('은행', 1299), ('농협', 1154), ('송금', 985), ('조성', 961), ('대출', 890), ('으로부터', 889), ('기업', 793), ('일반인', 672), ('새', 611), ('지역', 569), ('이자', 520), ('지급', 518), ('금고', 418), ('금융', 416)]
#
# < 기타 비금속 광물제품 제조업 >
# [('가공', 330), ('제조', 326), ('석재', 279), ('절단', 239), ('대리석', 170), ('성형', 160), ('사업장', 112), ('원석', 93), ('석제품', 93), ('콘', 87), ('아스', 86), ('인조', 86), ('비석', 78), ('석', 74), ('건설', 73), ('상판', 64), ('골재', 63), ('연마', 62), ('건축', 61), ('돌', 59)]
#
# < 모터사이클 및 부품 판매업 >
# [('오토바이', 430), ('대상', 203), ('판매', 202), ('매장', 191), ('소매', 174), ('일반', 158), ('소비자', 146), ('일반인', 138), ('사업장', 106), ('부품', 101), ('고객', 64), ('도매', 44), ('영업장', 43), ('수리', 37), ('가게', 28), ('모터사이클', 28), ('이륜차', 24), ('소매업자', 22), ('도소매', 16), ('중고', 16)]
#
# < 구조용 금속제품, 탱크 및 증기발생기 제조업 >
# [('절단', 1743), ('금속', 1468), ('제조', 1269), ('제작', 917), ('용접', 849), ('가공', 646), ('철', 602), ('조립', 593), ('철판', 580), ('샷', 577), ('알루미늄', 562), ('사업장', 541), ('시', 433), ('철구', 396), ('조물', 393), ('고객', 315), ('철골', 314), ('입고', 287), ('샤시', 286), ('창호', 265)]
#
# < 과실, 채소 가공 및 저장 처리업 >
# [('제조', 430), ('사업장', 249), ('배추', 226), ('김치', 223), ('판매', 221), ('절임', 220), ('가공', 219), ('반찬', 156), ('채소', 151), ('즙', 109), ('감', 101), ('건조', 99), ('무', 98), ('과일', 97), ('대상', 88), ('식품', 78), ('류', 72), ('소비자', 66), ('곶감', 65), ('일반', 63)]
#
# < 개인 및 가정용품 임대업 >
# [('대상', 1083), ('대여', 1025), ('고객', 771), ('사업장', 605), ('일반인', 481), ('임대', 384), ('정수기', 346), ('한복', 290), ('매장', 289), ('일반', 285), ('렌탈', 219), ('영업장', 206), ('만화', 160), ('만화책', 154), ('소비자', 149), ('용품', 145), ('드레스', 133), ('책', 131), ('만화방', 116), ('서비스', 111)]
#
# < 합성고무 및 플라스틱 물질 제조업 >
# [('플라스틱', 329), ('합성수지', 220), ('재생', 167), ('원료', 150), ('제조', 148), ('수지', 131), ('분쇄', 100), ('가공', 97), ('배합', 74), ('폐', 70), ('압출', 64), ('혼합', 53), ('사업장', 53), ('입고', 52), ('제조업', 47), ('비닐', 43), ('물질', 40), ('투입', 37), ('재', 36), ('생산', 35)]
#
# < 가죽, 가방 및 유사 제품 제조업 >
# [('제조', 413), ('가죽', 399), ('가방', 397), ('재단', 270), ('사업장', 166), ('지갑', 146), ('핸드백', 140), ('원단', 129), ('재봉', 100), ('피혁', 89), ('가공', 85), ('케이스', 84), ('봉제', 78), ('임가공', 65), ('제조업', 58), ('고객', 51), ('공장', 50), ('원피', 46), ('의뢰', 44), ('제작', 41)]
#
# < 산업용 농ㆍ축산물 및 동ㆍ식물 도매업 >
# [('도매', 1608), ('소매업자', 954), ('사업장', 891), ('사료', 526), ('대상', 502), ('판매', 432), ('쌀', 317), ('매장', 296), ('꽃', 284), ('사용자', 240), ('산업', 239), ('영업장', 221), ('생화', 178), ('일반', 175), ('곡물', 158), ('한약재', 156), ('도소매', 154), ('농산물', 153), ('고객', 150), ('식물', 127)]
#
# < 연금 및 공제업 >
# [('기금', 85), ('공제', 74), ('대상', 61), ('연금', 58), ('운영', 43), ('복지', 40), ('관리', 36), ('공제조합', 34), ('사내', 30), ('조성', 28), ('국민', 28), ('사업장', 27), ('보험', 27), ('사무실', 26), ('사업', 26), ('택시', 26), ('서비스', 23), ('조합원', 23), ('보증', 19), ('공단', 18)]
#
# < 시멘트, 석회, 플라스터 및 그 제품 제조업 >
# [('시멘트', 538), ('모래', 312), ('콘크리트', 199), ('제조', 176), ('혼합', 175), ('원재료', 155), ('투입', 127), ('레미콘', 110), ('입고', 103), ('자갈', 102), ('벽돌', 92), ('골재', 89), ('계량', 71), ('재료', 64), ('성형', 63), ('블럭', 60), ('배합', 60), ('사업장', 57), ('철근', 57), ('원료', 46)]
#
# < 제재 및 목재 가공업 >
# [('목재', 201), ('원목', 118), ('가공', 89), ('절단', 82), ('제재', 59), ('제조', 51), ('나무', 46), ('각재', 44), ('제재목', 44), ('생산', 40), ('톱밥', 37), ('사업장', 30), ('표면', 30), ('일반', 28), ('도장', 26), ('분쇄', 24), ('합판', 23), ('제조업', 22), ('입고', 22), ('판재', 21)]
#
# < 병원 >
# [('병원', 875), ('환자', 688), ('진료', 538), ('입원', 477), ('서비스', 405), ('요양', 377), ('대상', 259), ('시설', 257), ('위주', 206), ('외래', 194), ('노인', 191), ('치료', 179), ('인', 148), ('갖추', 136), ('의료', 108), ('치과', 98), ('한방', 87), ('일반', 81), ('종합', 69), ('행위', 52)]
#
# < 도축, 육류 가공 및 저장 처리업 >
# [('가공', 280), ('포장', 219), ('사업장', 145), ('닭', 129), ('돼지고기', 126), ('제조', 124), ('절단', 111), ('입고', 107), ('육류', 98), ('돼지', 77), ('양념', 75), ('처리', 69), ('닭발', 62), ('발', 61), ('골', 58), ('닭고기', 57), ('도축', 48), ('오리', 47), ('소고기', 47), ('별', 45)]
#
# < 컴퓨터 프로그래밍, 시스템 통합 및 관리업 >
# [('컴퓨터', 883), ('개발', 874), ('사업장', 800), ('시스템', 717), ('고객', 632), ('소프트웨어', 599), ('사무실', 499), ('의뢰', 413), ('서비스', 356), ('구축', 326), ('프로그램', 290), ('제작', 277), ('통합', 273), ('요청', 264), ('홈페이지', 236), ('주문', 226), ('자문', 192), ('이용', 185), ('공급', 183), ('관리', 164)]
#
# < 사진 촬영 및 처리업 >
# [('촬영', 1846), ('사진', 1647), ('고객', 1315), ('대상', 864), ('사진관', 787), ('사업장', 565), ('요청', 491), ('일반인', 433), ('인물사진', 429), ('인화', 298), ('행사', 291), ('스튜디오', 244), ('영상', 211), ('서비스', 199), ('의뢰', 194), ('인물', 187), ('현상', 183), ('일반', 180), ('비디오', 170), ('제공', 128)]
#
# < 동물성 및 식물성 유지 제조업 >
# [('참기름', 686), ('기름', 473), ('제조', 390), ('참깨', 308), ('방앗간', 155), ('깨', 154), ('판매', 125), ('들깨', 102), ('추출', 99), ('볶', 98), ('압착', 97), ('대상', 89), ('성', 86), ('식물', 84), ('소비자', 83), ('일반', 81), ('들기름', 74), ('가공', 73), ('갖추', 69), ('일반인', 65)]
#
# < 토목 건설업 >
# [('공사', 1978), ('고객', 1921), ('건설', 1686), ('현장', 1527), ('요구', 933), ('조경', 893), ('토목', 786), ('사업장', 747), ('요청', 534), ('의뢰', 512), ('설치', 470), ('시설물', 307), ('도로', 304), ('건설업', 296), ('설비', 296), ('시설', 273), ('태양광', 260), ('상하수도', 223), ('조성', 165), ('사업', 164)]
#
# < 교육 지원 서비스업 >
# [('교육', 622), ('대상', 443), ('사업장', 343), ('서비스', 301), ('학생', 259), ('지원', 221), ('유학', 199), ('컨설팅', 175), ('사무실', 153), ('알선', 151), ('학교', 144), ('상담', 141), ('일반인', 115), ('고객', 99), ('관련', 85), ('평가', 66), ('학원', 56), ('자문', 56), ('재단', 54), ('진로', 49)]
#
# < 섬유제품 염색, 정리 및 마무리 가공업 >
# [('원단', 565), ('염색', 300), ('가공', 276), ('의류', 141), ('임가공', 140), ('입고', 139), ('날염', 138), ('직물', 127), ('섬유', 115), ('염료', 114), ('사업장', 108), ('단추', 94), ('제품', 73), ('기계', 70), ('구멍', 67), ('마무리', 56), ('청바지', 56), ('의복', 56), ('폴리', 54), ('제조', 48)]
#
# < 1차 비철금속 제조업 >
# [('알루미늄', 300), ('제조', 121), ('절단', 107), ('가공', 104), ('금속', 88), ('압출', 81), ('비철', 74), ('입고', 63), ('압연', 53), ('사업장', 46), ('동', 43), ('제작', 39), ('부품', 34), ('용해', 33), ('파이프', 32), ('철', 29), ('제품', 25), ('주조', 25), ('스크랩', 25), ('조립', 23)]
#
# < 금융 지원 서비스업 >
# [('대상', 510), ('사업장', 432), ('고객', 411), ('금융', 336), ('증권', 334), ('중개', 328), ('서비스', 298), ('투자', 268), ('사무실', 235), ('대부', 229), ('일반인', 171), ('일반', 158), ('자문', 138), ('환전', 104), ('대출', 83), ('중개업', 82), ('기업', 81), ('컨설팅', 80), ('대중', 73), ('회사', 72)]
#
# < 건설장비 운영업 >
# [('건설', 1193), ('장비', 830), ('고객', 480), ('현장', 419), ('운영', 403), ('기계', 399), ('사업장', 390), ('임대', 388), ('운전자', 362), ('대여', 274), ('요구', 258), ('요청', 225), ('중장비', 186), ('크레인', 175), ('지게차', 174), ('제공', 162), ('계약', 155), ('포크', 151), ('레인', 150), ('건설업자', 149)]
#
# < 직물 직조 및 직물제품 제조업 >
# [('제조', 924), ('원단', 876), ('재단', 650), ('직물', 537), ('천막', 513), ('자수', 430), ('사업장', 382), ('재봉', 343), ('제작', 286), ('원사', 274), ('섬유', 237), ('천', 225), ('고객', 215), ('기계', 210), ('커텐', 199), ('이불', 193), ('제직', 173), ('주문', 167), ('커튼', 165), ('제품', 165)]
#
# < 펄프, 종이 및 판지 제조업 >
# [('종이', 90), ('제조', 64), ('원지', 39), ('입고', 30), ('재단', 27), ('코팅', 27), ('포장지', 24), ('가공', 23), ('절단', 21), ('사업장', 21), ('판지', 19), ('펄프', 16), ('필름', 16), ('접착', 14), ('인쇄', 13), ('한지', 12), ('테이프', 11), ('제조업', 10), ('원단', 10), ('제작', 10)]
#
# < 고용 알선 및 인력 공급업 >
# [('인력', 2640), ('알선', 1908), ('공급', 1369), ('사무실', 1138), ('고객', 1094), ('사업장', 941), ('요청', 910), ('고용', 820), ('수수료', 769), ('소개', 738), ('직업', 690), ('소개소', 528), ('서비스', 430), ('파견', 308), ('구직자', 307), ('대상', 290), ('의뢰', 263), ('업체', 231), ('직업소개소', 221), ('고용주', 168)]
#
# < 비알코올 음료 및 얼음 제조업 >
# [('음료', 53), ('제조', 48), ('사업장', 26), ('물', 20), ('얼음', 19), ('판매', 15), ('배합', 14), ('생산', 14), ('농축', 12), ('식혜', 11), ('혼합', 11), ('액', 10), ('생수', 10), ('추출', 9), ('비알콜', 9), ('갖추', 9), ('취수', 9), ('발효', 8), ('영업장', 8), ('가공', 8)]
#
# < 기타 섬유제품 제조업 >
# [('제조', 253), ('원단', 192), ('섬유', 130), ('부직포', 114), ('가공', 100), ('라벨', 78), ('사업장', 77), ('원사', 74), ('끈', 73), ('어망', 73), ('재단', 67), ('솜', 64), ('직조', 63), ('직물', 62), ('입고', 61), ('실', 51), ('폴리', 51), ('나일론', 47), ('로프', 44), ('제품', 42)]
#
# < 자연과학 및 공학 연구개발업 >
# [('연구', 1746), ('개발', 1122), ('연구소', 495), ('사업장', 399), ('공학', 222), ('제공', 170), ('사무실', 149), ('결과', 132), ('전기', 131), ('기술', 127), ('관련', 112), ('의뢰', 107), ('의학', 96), ('신약', 95), ('연구실', 67), ('기계', 66), ('고객', 64), ('화학', 63), ('분야', 60), ('화장품', 55)]
#
# < 컴퓨터 및 주변 장치 제조업 >
# [('컴퓨터', 138), ('조립', 122), ('제조', 113), ('부품', 84), ('사업장', 60), ('주변기기', 37), ('모니터', 36), ('프린터', 32), ('산업', 27), ('입고', 22), ('장치', 21), ('PCB', 19), ('LCD', 19), ('가공', 19), ('고객', 17), ('제조업', 17), ('플라스틱', 15), ('D', 13), ('기기', 13), ('기', 13)]
#
# < 전구 및 조명장치 제조업 >
# [('조명', 688), ('LED', 565), ('간판', 523), ('제조', 490), ('조립', 377), ('제작', 299), ('사업장', 275), ('광고', 228), ('장치', 208), ('전기', 186), ('고객', 173), ('기구', 163), ('절단', 159), ('아크릴', 131), ('전구', 101), ('광고판', 98), ('의뢰', 97), ('가공', 91), ('알루미늄', 90), ('입고', 89)]
#
# < 나무제품 제조업 >
# [('목재', 886), ('절단', 456), ('제조', 436), ('나무', 306), ('제작', 252), ('가공', 215), ('합판', 194), ('조립', 180), ('사업장', 161), ('재단', 153), ('상자', 113), ('고객', 112), ('접합', 101), ('원목', 99), ('파렛트', 97), ('입고', 79), ('가구', 79), ('문틀', 72), ('주문', 70), ('문', 70)]
#
# < 자동차 신품 부품 제조업 >
# [('자동차', 1253), ('부품', 1158), ('가공', 648), ('입고', 544), ('제조', 516), ('조립', 393), ('철', 321), ('절단', 278), ('철판', 265), ('알루미늄', 217), ('사업장', 210), ('엔진', 197), ('프레스', 153), ('장치', 151), ('금속', 149), ('플라스틱', 130), ('원재료', 129), ('성형', 114), ('용접', 106), ('CNC', 102)]
#
# < 회사 본부 및 경영 컨설팅 서비스업 >
# [('경영', 2117), ('컨설팅', 2080), ('사무실', 1197), ('사업장', 1139), ('관리', 927), ('사업체', 770), ('고객', 642), ('대상', 540), ('업무', 469), ('연구', 429), ('의뢰', 389), ('지원', 342), ('회사', 327), ('제조업', 316), ('서비스', 300), ('본부', 274), ('본사', 255), ('운영', 248), ('요청', 238), ('사업', 233)]
#
# < 노동조합 >
# [('노동조합', 285), ('사무실', 149), ('조합원', 111), ('대상', 99), ('향상', 99), ('근로', 94), ('단체', 92), ('개선', 91), ('권익', 86), ('조건', 86), ('유지', 69), ('근로자', 67), ('회원', 66), ('위한', 65), ('노조', 64), ('관리', 62), ('사업장', 62), ('위해', 58), ('복지', 57), ('노동자', 55)]
#
# < 해상 운송업 >
# [('운송', 163), ('선박', 122), ('화물', 122), ('낚시', 92), ('배', 62), ('해상', 60), ('대상', 54), ('취항', 50), ('고객', 47), ('예인선', 44), ('내항', 44), ('운영', 40), ('외항', 38), ('사업장', 36), ('여객', 36), ('일반인', 32), ('요청', 32), ('운송업', 31), ('항로', 30), ('국내', 28)]
#
# < 내화, 비내화 요업제품 제조업 >
# [('제조', 269), ('도', 209), ('흙', 200), ('도자기', 199), ('성형', 178), ('생활', 132), ('유약', 105), ('구워서', 89), ('빚', 82), ('점토', 77), ('사업장', 76), ('후', 60), ('세라믹', 58), ('소지', 56), ('소성', 51), ('가정용', 49), ('벽돌', 46), ('판매', 45), ('제조업', 40), ('장식', 40)]
#
# < 토사석 광업 >
# [('골재', 82), ('채취', 75), ('모래', 68), ('채굴', 43), ('원석', 39), ('건설', 34), ('자갈', 32), ('발파', 32), ('쇄석', 28), ('석회석', 26), ('파쇄', 24), ('분쇄', 21), ('암석', 16), ('사업장', 16), ('현장', 15), ('생산', 14), ('석재', 12), ('판매', 12), ('화약', 12), ('이용', 11)]
#
# < 의복 액세서리 제조업 >
# [('제조', 267), ('양말', 197), ('편조', 137), ('재단', 118), ('모자', 96), ('사업장', 95), ('원단', 94), ('장갑', 94), ('실', 70), ('원사', 67), ('의류', 64), ('재봉', 63), ('편직', 46), ('봉제', 45), ('면사', 42), ('이용', 41), ('면장갑', 41), ('공장', 38), ('가공', 38), ('가죽', 38)]
#
# < 귀금속 및 장신용품 제조업 >
# [('귀금속', 315), ('제조', 263), ('세공', 167), ('사업장', 155), ('악세사리', 133), ('금', 121), ('은', 115), ('반지', 92), ('목걸이', 90), ('고객', 73), ('장신구', 66), ('모조', 62), ('가공', 57), ('연마', 54), ('성형', 51), ('의뢰', 48), ('제조업', 42), ('금속', 36), ('요청', 34), ('영업장', 32)]
#
# < 해체, 선별 및 원료 재생업 >
# [('원료', 189), ('폐', 187), ('재생', 166), ('플라스틱', 153), ('분리', 151), ('분쇄', 150), ('재', 143), ('금속', 121), ('사업장', 91), ('고철', 90), ('처리', 88), ('가공', 86), ('해체', 85), ('폐차', 83), ('활용', 81), ('파쇄', 72), ('물질', 70), ('압축', 68), ('폐기물', 62), ('수집', 61)]
#
# < 인문 및 사회과학 연구개발업 >
# [('연구', 512), ('개발', 149), ('사무실', 133), ('사업장', 82), ('제공', 75), ('연구소', 69), ('학술', 65), ('결과', 63), ('경제', 47), ('문화', 44), ('교육', 42), ('관련', 39), ('경영', 36), ('과학', 35), ('조사', 35), ('문화재', 33), ('용역', 32), ('대상', 32), ('의뢰', 31), ('인문', 31)]
#
# < 거주 복지시설 운영업 >
# [('노인', 2753), ('시설', 2055), ('요양', 1938), ('복지', 1168), ('입소', 932), ('시켜', 780), ('운영', 619), ('서비스', 606), ('대상', 538), ('요양원', 529), ('질환', 522), ('성', 497), ('는', 467), ('장애', 402), ('제공', 369), ('앓', 352), ('인', 332), ('보호', 328), ('치료', 261), ('숙식', 258)]
#
# < 기타 사업 지원 서비스업 >
# [('사업장', 1235), ('고객', 1104), ('서비스', 805), ('대행', 692), ('대상', 688), ('포장', 621), ('행사', 606), ('복사', 560), ('사무실', 547), ('이벤트', 414), ('의뢰', 402), ('지원', 345), ('요구', 342), ('기획', 310), ('일반인', 306), ('요청', 305), ('전시', 202), ('사업', 196), ('업무', 187), ('영업장', 175)]
#
# < 사업시설 유지ㆍ관리 서비스업 >
# [('시설', 834), ('관리', 793), ('고객', 550), ('유지', 480), ('사업', 431), ('의뢰', 283), ('사업장', 230), ('서비스', 169), ('시설물', 109), ('유지관리', 107), ('건물', 106), ('대상', 75), ('사무실', 63), ('요청', 50), ('요구', 42), ('청소', 41), ('경비', 38), ('보수', 36), ('빌딩', 35), ('입주', 34)]
#
# < 기타 종이 및 판지 제품 제조업 >
# [('종이', 290), ('제조', 194), ('절단', 104), ('가공', 89), ('재단', 87), ('원지', 72), ('사업장', 63), ('원단', 53), ('펄프', 50), ('제작', 49), ('입고', 46), ('용지', 43), ('인쇄', 42), ('화장지', 41), ('봉투', 39), ('문구', 37), ('스티커', 35), ('인', 33), ('물티슈', 33), ('제조업', 32)]
#
# < 1차 철강 제조업 >
# [('절단', 617), ('가공', 305), ('철판', 244), ('제조', 233), ('철', 222), ('파이프', 217), ('입고', 194), ('철강', 191), ('스텐', 145), ('용접', 141), ('금속', 105), ('레스', 103), ('강관', 102), ('사업장', 97), ('배관', 75), ('코일', 75), ('철강재', 73), ('철근', 67), ('절곡', 65), ('부품', 62)]
#
# < 기타 전기장비 제조업 >
# [('제조', 148), ('조립', 109), ('전기', 103), ('사업장', 73), ('부품', 63), ('장비', 53), ('가공', 44), ('장치', 38), ('절단', 33), ('용접', 28), ('철', 27), ('제작', 25), ('용접기', 25), ('신호', 24), ('기계', 23), ('입고', 22), ('초음파', 22), ('철판', 16), ('PCB', 15), ('제조업', 15)]
#
# < 영화, 비디오물, 방송 프로그램 제작 및 배급업 >
# [('제작', 938), ('사업장', 483), ('영화', 434), ('영상', 397), ('방송', 274), ('고객', 272), ('광고', 241), ('요청', 216), ('의뢰', 208), ('프로그램', 199), ('비디오', 192), ('사무실', 177), ('대상', 136), ('사업자', 115), ('물', 114), ('상영', 111), ('영화관', 105), ('영상물', 101), ('서비스', 89), ('시설', 81)]
#
# < 산업용 기계 및 장비 임대업 >
# [('임대', 1095), ('사업장', 701), ('건설', 505), ('대상', 364), ('장비', 362), ('고객', 348), ('산업', 312), ('사용자', 296), ('기계', 268), ('대여', 199), ('요청', 157), ('영업장', 130), ('복사기', 128), ('현장', 126), ('자재', 125), ('렌탈', 119), ('관련', 113), ('임대업', 104), ('카드', 89), ('의뢰', 85)]
#
# < 컴퓨터 및 통신장비 수리업 >
# [('수리', 1675), ('컴퓨터', 1300), ('고객', 782), ('사업장', 488), ('의뢰', 437), ('대상', 329), ('서비스', 291), ('매장', 259), ('요청', 214), ('일반인', 202), ('일반', 142), ('소비자', 102), ('통신', 97), ('유지', 94), ('영업장', 88), ('핸드폰', 84), ('기기', 83), ('장비', 81), ('S', 76), ('A', 74)]
#
# < 낙농제품 및 식용 빙과류 제조업 >
# [('제조', 30), ('치즈', 23), ('우유', 15), ('원유', 14), ('아이스크림', 12), ('가공', 11), ('발효', 9), ('혼합', 8), ('원료', 8), ('사업장', 8), ('요구르트', 8), ('유제품', 7), ('시설', 7), ('갖추', 7), ('살균', 6), ('제조업', 6), ('유산균', 6), ('액상', 5), ('탈지분유', 5), ('배합', 4)]
#
# < 기타 보건업 >
# [('대상', 718), ('치료', 498), ('상담', 453), ('일반인', 357), ('심리', 313), ('언어', 290), ('사업장', 267), ('아동', 263), ('교정', 216), ('센터', 213), ('서비스', 182), ('영업장', 172), ('고객', 158), ('장애', 141), ('심리치료', 136), ('발달', 130), ('지압', 113), ('미술', 99), ('재활', 79), ('운동', 70)]
#
# < 자동차 판매업 >
# [('자동차', 2137), ('중고', 1147), ('대상', 1124), ('판매', 976), ('매매', 941), ('일반', 802), ('고객', 794), ('사업장', 779), ('중고차', 571), ('일반인', 393), ('소비자', 393), ('매장', 297), ('수출', 199), ('영업', 193), ('소매', 173), ('신차', 154), ('영업장', 145), ('사원', 129), ('배', 121), ('이용', 116)]
#
# < 골판지, 종이 상자 및 종이 용기 제조업 >
# [('골판지', 634), ('종이', 627), ('제조', 354), ('상자', 340), ('박스', 337), ('재단', 228), ('절단', 222), ('원지', 142), ('가공', 120), ('인', 118), ('쇄', 117), ('접합', 107), ('포장', 101), ('입고', 101), ('사업장', 97), ('원단', 78), ('접착', 76), ('판지', 72), ('인쇄', 70), ('제작', 61)]
#
# < 그 외 기타 전문, 과학 및 기술 서비스업 >
# [('사업장', 210), ('고객', 184), ('번역', 148), ('사무실', 147), ('서비스', 133), ('의뢰', 119), ('대상', 115), ('연예인', 87), ('통역', 87), ('매니저', 62), ('중개', 52), ('관리', 50), ('인', 49), ('트', 43), ('요청', 43), ('먼', 40), ('인증', 39), ('대리', 34), ('권', 34), ('회원권', 34)]
#
# < 공영 우편업 >
# [('우체국', 642), ('우편', 613), ('우편물', 562), ('배달', 333), ('대상', 291), ('서비스', 265), ('수집', 259), ('일반인', 178), ('분배', 153), ('고객', 138), ('택배', 123), ('업무', 121), ('일반', 117), ('접수', 95), ('취급', 80), ('금융', 77), ('수신', 75), ('취급소', 74), ('자금', 63), ('대중', 58)]
#
# < 측정, 시험, 항해, 제어 및 기타 정밀 기기 제조업; 광학 기기 제외 >
# [('조립', 551), ('자동', 512), ('제조', 494), ('화', 335), ('부품', 328), ('기계', 302), ('사업장', 258), ('가공', 238), ('설계', 198), ('장비', 191), ('산업', 179), ('장치', 179), ('제작', 174), ('제어', 170), ('기기', 168), ('철', 162), ('측정', 120), ('설비', 119), ('입고', 116), ('검사', 114)]
#
# < 의료용 기기 제조업 >
# [('치과', 583), ('제조', 470), ('기공', 303), ('사업장', 267), ('조립', 251), ('기기', 245), ('의료', 238), ('소', 225), ('치아', 210), ('기', 191), ('제작', 181), ('의뢰', 172), ('가공', 171), ('보철', 159), ('안경테', 134), ('공소', 132), ('의치', 122), ('보철물', 110), ('부품', 109), ('틀니', 108)]
#
# < 기타 금융업 >
# [('대상', 478), ('사업장', 347), ('고객', 302), ('금융', 280), ('일반인', 225), ('대부', 206), ('대출', 202), ('대', 180), ('부업', 177), ('사무실', 162), ('일반', 146), ('할부', 145), ('자금', 131), ('금융업', 121), ('신용카드', 106), ('서비스', 104), ('카드', 96), ('여신', 90), ('담보', 78), ('기업', 64)]
#
# < 전기업 >
# [('전기', 476), ('태양광', 389), ('생산', 339), ('사업장', 214), ('발전', 176), ('공급', 128), ('이용', 116), ('판매', 105), ('태양열', 97), ('태양', 89), ('전력', 85), ('전업', 80), ('발전소', 79), ('한전', 76), ('발', 74), ('에너지', 68), ('태양력', 65), ('에너지원', 56), ('현장', 45), ('빛', 42)]
#
# < 자동차 차체 및 트레일러 제조업 >
# [('제조', 106), ('사업장', 96), ('특장차', 82), ('제작', 78), ('철판', 77), ('자동차', 76), ('절단', 66), ('고객', 49), ('캠핑카', 42), ('용접', 39), ('가공', 35), ('조립', 34), ('차량', 34), ('부품', 33), ('철', 32), ('차체', 29), ('입고', 27), ('요청', 25), ('탑', 25), ('차', 25)]
#
# < 가정용 기기 제조업 >
# [('조립', 200), ('제조', 198), ('전기', 121), ('부품', 111), ('사업장', 82), ('기기', 79), ('가공', 72), ('입고', 69), ('가정용', 63), ('플라스틱', 63), ('매트', 49), ('절단', 48), ('기', 44), ('미용', 39), ('철판', 37), ('철', 37), ('스텐', 34), ('제조업', 33), ('히터', 30), ('용접', 29)]
#
# < 경비, 경호 및 탐정업 >
# [('경비', 337), ('서비스', 250), ('고객', 179), ('보안', 151), ('사업장', 132), ('시스템', 108), ('아파트', 107), ('경호', 106), ('경비실', 94), ('시설', 92), ('요구', 81), ('관리', 80), ('사업', 64), ('입주민', 60), ('요청', 56), ('경보', 56), ('보호', 54), ('순찰', 51), ('장치', 48), ('의뢰', 47)]
#
# < 알코올 음료 제조업 >
# [('제조', 143), ('발효', 123), ('쌀', 97), ('막걸리', 88), ('탁주', 60), ('약주', 41), ('누룩', 33), ('사업장', 32), ('제조업', 31), ('시켜', 26), ('판매', 23), ('찹쌀', 22), ('맥주', 20), ('양조장', 20), ('보리', 18), ('숙성', 17), ('밀가루', 16), ('곡식', 15), ('발효주', 13), ('밀', 12)]
#
# < 통신 및 방송장비 제조업 >
# [('조립', 263), ('부품', 234), ('제조', 211), ('통신', 203), ('장비', 163), ('사업장', 95), ('가공', 91), ('입고', 88), ('PCB', 83), ('카메라', 75), ('방송', 67), ('CCTV', 63), ('휴대폰', 61), ('기기', 56), ('무선', 51), ('알루미늄', 45), ('검사', 44), ('핸드폰', 42), ('모듈', 40), ('자재', 39)]
#
# < 시설물 유지관리 공사업 >
# [('고객', 346), ('시설물', 278), ('공사', 253), ('현장', 221), ('보수', 218), ('유지', 212), ('관리', 128), ('사업장', 127), ('요청', 127), ('의뢰', 122), ('요구', 122), ('건설', 118), ('유지관리', 91), ('건물', 78), ('시설', 71), ('사업', 57), ('공', 30), ('설치', 29), ('방수', 29), ('건축', 27)]
#
# < 기초 화학물질 제조업 >
# [('제조', 91), ('혼합', 56), ('원료', 47), ('화학', 36), ('입고', 35), ('투입', 34), ('가스', 33), ('배합', 32), ('산업', 30), ('사업장', 28), ('반응', 26), ('원재료', 25), ('안료', 23), ('질소', 22), ('가공', 21), ('황산', 20), ('물질', 20), ('처리', 19), ('압축', 17), ('약품', 16)]
#
# < 영상 및 음향 기기 제조업 >
# [('조립', 99), ('제조', 86), ('부품', 85), ('기기', 64), ('음향', 53), ('사업장', 44), ('스피커', 41), ('영상', 28), ('입고', 26), ('가공', 24), ('TV', 23), ('플라스틱', 19), ('오디오', 17), ('알루미늄', 14), ('PCB', 14), ('앰프', 14), ('안테나', 13), ('방송', 13), ('이어폰', 12), ('자재', 12)]
#
# < 인형, 장난감 및 오락용품 제조업 >
# [('제조', 77), ('인형', 75), ('사업장', 41), ('제작', 34), ('완구', 33), ('장난감', 32), ('플라스틱', 31), ('조립', 30), ('제조업', 23), ('봉제', 19), ('용품', 16), ('재단', 15), ('교구', 15), ('가공', 15), ('고객', 13), ('원단', 13), ('드론', 12), ('오락', 12), ('판매', 12), ('모형', 11)]
#
# < 기타 정보 서비스업 >
# [('정보', 259), ('제공', 211), ('온라인', 176), ('사업장', 124), ('서비스', 81), ('사무실', 73), ('뉴스', 71), ('인터넷', 59), ('컴퓨터', 54), ('고객', 52), ('된', 43), ('데이터베이스', 41), ('가공', 41), ('수록', 41), ('취재', 36), ('파일', 34), ('대상', 32), ('기사', 32), ('의뢰', 27), ('영상', 27)]
#
# < 사회 및 산업정책 행정 >
# [('행정', 295), ('관리', 173), ('교육', 150), ('지원', 146), ('서비스', 142), ('농업', 140), ('대상', 125), ('관련', 84), ('농민', 75), ('기술', 71), ('인', 69), ('상담소', 63), ('상담', 60), ('농산물', 49), ('교육청', 44), ('농림', 34), ('센터', 33), ('사업장', 32), ('업무', 32), ('기관', 30)]
#
# < 유리 및 유리제품 제조업 >
# [('유리', 516), ('절단', 149), ('제조', 147), ('가공', 144), ('판유리', 141), ('사업장', 83), ('재단', 59), ('조립', 52), ('제작', 50), ('입고', 45), ('강화', 44), ('고객', 40), ('층', 38), ('복', 36), ('원판', 28), ('거울', 27), ('수족관', 26), ('제품', 25), ('섬유', 24), ('구입', 22)]
#
# < 화학섬유 제조업 >
# [('섬유', 16), ('폴리에스터', 13), ('합성섬유', 12), ('제조', 11), ('사업장', 9), ('제직', 8), ('폴리', 7), ('나일론', 7), ('원료', 6), ('방사', 6), ('원사', 5), ('아크릴', 5), ('가공', 5), ('제조업', 5), ('폴리에스테르', 5), ('입고', 4), ('PET', 4), ('투입', 4), ('건조', 4), ('원단', 4)]
#
# < 방적 및 가공사 제조업 >
# [('원사', 233), ('연사', 224), ('제조', 110), ('가공', 97), ('섬유', 90), ('실', 73), ('폴리', 61), ('가공사', 59), ('합사', 51), ('폴리에스테르', 49), ('가연', 45), ('사업장', 43), ('입고', 38), ('임가공', 34), ('정경', 34), ('나일론', 26), ('아서', 24), ('기계', 23), ('화학', 23), ('꼬', 22)]
#
# < 소화물 전문 운송업 >
# [('택배', 1891), ('서비스', 1011), ('고객', 831), ('사업장', 665), ('배달', 542), ('운송', 356), ('요청', 341), ('소화물', 330), ('대상', 323), ('의뢰', 291), ('일반인', 217), ('화물', 203), ('퀵', 192), ('수집', 161), ('대행', 129), ('일반', 126), ('배송', 116), ('물품', 107), ('사무실', 105), ('영업장', 104)]
#
# < 서적, 잡지 및 기타 인쇄물 출판업 >
# [('출판', 783), ('사업장', 551), ('발행', 377), ('서적', 351), ('신문', 312), ('대상', 293), ('사무실', 284), ('원고', 212), ('출판사', 211), ('편집', 186), ('일반인', 161), ('고객', 149), ('간행물', 148), ('출판업', 138), ('정기', 126), ('의뢰', 117), ('일반', 110), ('잡지', 95), ('제작', 91), ('책', 85)]
#
# < 신탁업 및 집합 투자업 >
# [('투자', 176), ('사업장', 82), ('금융', 72), ('고객', 39), ('기타', 35), ('대상', 34), ('운용', 32), ('자산', 32), ('회사', 25), ('사무실', 25), ('펀드', 24), ('자산운용', 23), ('자금', 23), ('기업', 22), ('창업', 20), ('금융업', 13), ('집합', 12), ('모집', 12), ('사모', 11), ('벤처', 11)]
#
# < 시계 및 시계 부품 제조업 >
# [('시계', 45), ('제조', 24), ('조립', 22), ('부품', 19), ('사업장', 9), ('벽시계', 6), ('손목시계', 6), ('잡화', 4), ('제조업', 4), ('주문', 3), ('케이스', 3), ('스텐', 3), ('나무', 3), ('가공', 3), ('플라스틱', 3), ('생산', 3), ('전자시계', 3), ('타임스위치', 3), ('부속품', 2), ('황동', 2)]
#
# < 무형 재산권 임대업 >
# [('권', 21), ('사업장', 9), ('임대', 9), ('특허', 8), ('재산', 7), ('무형', 6), ('고객', 5), ('사무실', 4), ('상표', 4), ('산업', 4), ('사용자', 4), ('임대업', 3), ('관련', 3), ('기술', 3), ('사용', 3), ('관리', 2), ('컨설팅', 2), ('대상', 2), ('로열티', 2), ('사용료', 2)]
#
# < 폐기물 처리업 >
# [('폐기물', 427), ('처리', 337), ('건설', 143), ('사업장', 120), ('수집', 83), ('운반', 67), ('소각', 64), ('지정', 57), ('생활', 47), ('수거', 44), ('건축', 44), ('시설', 41), ('쓰레기', 40), ('관련', 39), ('중간', 39), ('현장', 31), ('고객', 31), ('매립', 31), ('음식물', 28), ('파쇄', 26)]
#
# < 보험업 >
# [('보험', 2733), ('대상', 1088), ('생명', 831), ('일반', 544), ('회사', 528), ('손해', 476), ('고객', 447), ('일반인', 389), ('대중', 340), ('화재', 246), ('보험업', 226), ('판매', 200), ('사업장', 179), ('운영', 179), ('보증', 163), ('서비스', 162), ('업무', 159), ('계약', 150), ('지점', 122), ('영업소', 121)]
#
# < 절연선 및 케이블 제조업 >
# [('케이블', 209), ('전선', 201), ('조립', 146), ('제조', 128), ('가공', 88), ('절단', 85), ('절연', 82), ('부품', 58), ('하네스', 57), ('입고', 48), ('코드', 45), ('PVC', 38), ('구리', 36), ('전기', 35), ('금속', 34), ('선', 34), ('동선', 32), ('절연선', 31), ('피복', 29), ('통신', 26)]
#
# < 그 외 기타 운송장비 제조업 >
# [('제조', 31), ('절단', 27), ('부품', 25), ('조립', 24), ('사업장', 22), ('자전거', 21), ('용접', 16), ('철판', 15), ('가공', 12), ('바퀴', 12), ('오토바이', 11), ('철', 11), ('알루미늄', 9), ('고객', 8), ('입고', 8), ('운반', 8), ('유모차', 7), ('휠체어', 7), ('파이프', 6), ('금속', 6)]
#
# < 하수, 폐수 및 분뇨 처리업 >
# [('처리', 415), ('하수', 261), ('분뇨', 222), ('수집', 154), ('폐수', 144), ('시설', 124), ('정화조', 112), ('운반', 112), ('청소', 90), ('사업장', 88), ('처리장', 56), ('이용', 55), ('고객', 54), ('관리', 48), ('수거', 47), ('서비스', 39), ('산업', 35), ('축산', 32), ('운영', 31), ('정화', 31)]
#
# < 운동 및 경기용구 제조업 >
# [('제조', 108), ('낚시', 75), ('절단', 57), ('조립', 53), ('사업장', 47), ('기구', 44), ('용품', 44), ('운동', 40), ('가공', 40), ('철', 31), ('장비', 30), ('용접', 29), ('제작', 26), ('재단', 25), ('대', 22), ('목재', 22), ('놀이', 21), ('입고', 18), ('성형', 17), ('고객', 17)]
#
# < 자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업 >
# [('인터넷', 295), ('서비스', 202), ('정보', 189), ('사업장', 175), ('제공', 127), ('사무실', 97), ('고객', 71), ('신문', 60), ('자료', 58), ('매개', 55), ('뉴스', 52), ('온라인', 52), ('처리', 49), ('웹', 48), ('이용', 43), ('기사', 42), ('대상', 40), ('컴퓨터', 39), ('호스팅', 37), ('의뢰', 36)]
#
# < 임업 >
# [('숲', 51), ('가꾸기', 49), ('산림', 48), ('임업', 43), ('서비스', 43), ('관련', 26), ('현장', 23), ('벌목', 23), ('고객', 22), ('계약', 22), ('사업', 18), ('의뢰', 18), ('사업장', 16), ('나무', 16), ('병충해', 14), ('수수료', 13), ('영림', 12), ('산림조합', 12), ('요청', 11), ('의하', 11)]
#
# < 텔레비전 방송업 >
# [('방송', 244), ('프로그램', 107), ('유선', 98), ('제작', 61), ('사업장', 55), ('공급', 48), ('송출', 47), ('서비스', 29), ('제공', 28), ('인터넷', 25), ('케이블', 25), ('방송국', 22), ('고객', 20), ('위성', 17), ('지상파', 15), ('종합', 15), ('사무실', 14), ('은', 13), ('TV', 13), ('일반', 12)]
#
# < 환경 정화 및 복원업 >
# [('정화', 13), ('바다', 11), ('해양', 9), ('사업장', 8), ('토양', 8), ('이용', 8), ('선박', 8), ('고객', 7), ('환경정화', 7), ('오염', 6), ('수거', 5), ('지하수', 4), ('된', 4), ('복원', 4), ('현장', 4), ('의뢰', 4), ('환경', 4), ('화학', 3), ('기계', 3), ('폐기물', 3)]
#
# < 작물 재배업 >
# [('재배', 357), ('시설', 100), ('버섯', 98), ('사업장', 79), ('판매', 74), ('작물', 70), ('생산', 46), ('노지', 46), ('채소', 45), ('농장', 44), ('종자', 33), ('법인', 31), ('조합', 28), ('종균', 28), ('갖추', 27), ('하우스', 25), ('영농', 24), ('콩나물', 22), ('농업', 21), ('화훼', 20)]
#
# < 조경관리 및 유지 서비스업 >
# [('조경', 140), ('관리', 137), ('사업장', 107), ('고객', 82), ('계약', 82), ('유지', 72), ('식재', 55), ('수수료', 54), ('조경식', 53), ('재', 50), ('현장', 45), ('요청', 42), ('의뢰', 39), ('조경수', 30), ('서비스', 26), ('나무', 22), ('요구', 21), ('유지관리', 20), ('공사', 11), ('골프장', 11)]
#
# < 시장 조사 및 여론 조사업 >
# [('조사', 121), ('시장', 61), ('여론', 60), ('고객', 36), ('사업장', 29), ('자료', 28), ('요청', 24), ('의뢰', 21), ('사무실', 19), ('결과', 13), ('제공', 13), ('리서치', 13), ('분석', 11), ('수집', 8), ('대상', 8), ('업체', 8), ('사업', 7), ('서비스', 7), ('조', 6), ('마케팅', 6)]
#
# < 편조 원단 제조업 >
# [('원단', 169), ('편조', 111), ('원사', 101), ('편직', 87), ('제조', 84), ('니트', 50), ('실', 26), ('기계', 24), ('사업장', 24), ('섬유', 22), ('임가공', 21), ('입고', 18), ('의류', 18), ('이용', 12), ('폴리', 11), ('직조', 11), ('공장', 10), ('의뢰', 10), ('방법', 9), ('편조기', 8)]
#
# < 동물용 사료 및 조제식품 제조업 >
# [('사료', 213), ('제조', 119), ('배합', 82), ('동물', 62), ('사업장', 47), ('간식', 39), ('원료', 34), ('옥수수', 31), ('단미사료', 29), ('보조', 28), ('투입', 26), ('혼합', 24), ('분쇄', 24), ('조사료', 21), ('생산', 18), ('애견', 18), ('발효', 18), ('입고', 17), ('첨가제', 16), ('가공', 16)]
#
# < 양식어업 및 어업관련 서비스업 >
# [('양식', 75), ('양식장', 36), ('해면', 23), ('이용', 22), ('해수', 21), ('광어', 20), ('수산물', 16), ('어업', 13), ('서비스', 12), ('육상', 11), ('어촌계', 11), ('종묘', 10), ('장어', 10), ('판매', 9), ('출하', 9), ('정리', 9), ('사업장', 9), ('양식업', 8), ('어장', 8), ('전복', 7)]
#
# < 편조의복 제조업 >
# [('편조', 140), ('니트', 133), ('제조', 132), ('스웨터', 95), ('실', 67), ('의류', 65), ('원단', 63), ('편직', 56), ('사업장', 51), ('원사', 46), ('재단', 33), ('공장', 32), ('임가공', 25), ('봉제', 25), ('재봉', 17), ('여성', 17), ('제작', 17), ('제조업', 17), ('기계', 16), ('주문', 15)]
#
# < 기타 전문 서비스업 >
# [('지원', 79), ('연구', 64), ('협력', 59), ('산학', 58), ('서비스', 42), ('단', 40), ('사무', 31), ('개발', 28), ('교육', 21), ('사업', 20), ('대상', 19), ('관리', 17), ('사무실', 17), ('업무', 16), ('사업장', 16), ('행정', 16), ('학교', 14), ('대학', 11), ('관련', 10), ('사업체', 9)]
#
# < 신발 및 신발 부분품 제조업 >
# [('신발', 230), ('제조', 218), ('구두', 207), ('가죽', 205), ('재단', 179), ('갑피', 97), ('재봉', 91), ('고무', 67), ('사업장', 64), ('합성', 50), ('피혁', 46), ('밑창', 44), ('화', 42), ('부분품', 41), ('접착', 33), ('여성', 33), ('원단', 32), ('제작', 30), ('가공', 29), ('입고', 25)]
#
# < 사법 및 공공 질서 행정 >
# [('치안', 711), ('서비스', 666), ('행정', 525), ('공공질서', 410), ('화재', 348), ('진압', 294), ('구조', 285), ('파출소', 282), ('안전', 229), ('소방서', 211), ('응급', 207), ('경찰서', 202), ('대상', 195), ('주민', 157), ('시민', 157), ('소방', 141), ('센터', 122), ('지구대', 109), ('업무', 91), ('활동', 79)]
#
# < 폐기물 수집, 운반업 >
# [('폐기물', 781), ('수집', 621), ('운반', 580), ('차량', 206), ('지정', 202), ('이용', 182), ('사업장', 160), ('건설', 157), ('생활', 128), ('현장', 114), ('처리', 110), ('외', 102), ('수거', 84), ('쓰레기', 79), ('운반업', 76), ('고객', 61), ('의뢰', 52), ('산업', 48), ('관련', 48), ('음식물', 42)]
#
# < 항공기, 우주선 및 부품 제조업 >
# [('항공기', 41), ('부품', 39), ('가공', 31), ('제조', 28), ('알루미늄', 28), ('드론', 24), ('사업장', 18), ('입고', 15), ('제작', 14), ('조립', 13), ('절단', 11), ('철', 9), ('항공', 8), ('소재', 8), ('무인', 7), ('성형', 6), ('기계', 6), ('장치', 6), ('설계', 5), ('절삭', 5)]
#
# < 전기 통신업 >
# [('통신', 256), ('유선', 150), ('서비스', 142), ('사업장', 90), ('고객', 80), ('인터넷', 74), ('통신업', 74), ('대상', 73), ('전화', 66), ('시설', 58), ('이용', 44), ('무선', 43), ('관리', 29), ('사무실', 28), ('회선', 27), ('정보', 26), ('설비', 25), ('요청', 24), ('일반인', 22), ('설치', 22)]
#
# < 의약품 제조업 >
# [('제조', 41), ('혼합', 28), ('원료', 27), ('한약', 26), ('조제', 23), ('의약품', 22), ('사업장', 21), ('과립', 16), ('입고', 16), ('배합', 12), ('약재료', 11), ('투입', 11), ('한약재', 11), ('칭량', 10), ('원재료', 8), ('고객', 8), ('나트륨', 7), ('식품', 7), ('가공', 7), ('선별', 7)]
#
# < 작물재배 및 축산 관련 서비스업 >
# [('서비스', 59), ('선별', 44), ('지원', 37), ('관리', 36), ('작물', 33), ('사업장', 31), ('농업', 28), ('농산물', 27), ('재배', 27), ('출하', 25), ('공사', 22), ('시설', 22), ('농업용수', 22), ('대상', 20), ('건조', 19), ('농민', 18), ('계약', 18), ('공급', 18), ('포장', 17), ('감귤', 15)]
#
# < 증기, 냉ㆍ온수 및 공기 조절 공급업 >
# [('공급', 18), ('급', 15), ('증기', 15), ('생산', 11), ('열공', 8), ('열', 7), ('배관', 7), ('온수', 7), ('냉온', 6), ('공기', 6), ('시설', 6), ('사업장', 5), ('조절', 5), ('증기공', 5), ('가스', 5), ('스팀', 4), ('사용자', 4), ('전기', 4), ('LNG', 3), ('고객', 3)]
#
# < 수도업 >
# [('공급', 141), ('생활용수', 86), ('정수', 80), ('시설', 49), ('취수', 43), ('상수도', 33), ('수도', 31), ('물', 29), ('정수장', 28), ('관리', 23), ('수요자', 20), ('용수', 19), ('수돗물', 17), ('업소', 17), ('대상', 16), ('행정', 15), ('사업장', 14), ('처리', 13), ('상하수도', 13), ('가정', 12)]
#
# < 연료용 가스 제조 및 배관공급업 >
# [('가스', 87), ('공급', 43), ('도시', 32), ('배관', 27), ('사업장', 20), ('연료', 17), ('시설', 13), ('산업', 11), ('제조', 10), ('가정', 9), ('대상', 9), ('고객', 8), ('배관공', 8), ('급', 8), ('LNG', 6), ('사용자', 6), ('의하', 6), ('수요자', 5), ('서비스', 5), ('천연가스', 5)]
#
# < 철도장비 제조업 >
# [('철도', 52), ('부품', 47), ('차량', 42), ('제조', 27), ('가공', 22), ('조립', 20), ('철판', 14), ('철', 13), ('용접', 13), ('장치', 13), ('입고', 13), ('사업장', 12), ('절단', 10), ('구입', 7), ('신호', 7), ('원재료', 7), ('주차', 7), ('재료', 6), ('기계', 6), ('전동차', 6)]
#
# < 사진장비 및 광학 기기 제조업 >
# [('광학', 76), ('렌즈', 66), ('제조', 59), ('가공', 43), ('카메라', 42), ('조립', 38), ('부품', 37), ('기기', 35), ('사업장', 33), ('장비', 18), ('알루미늄', 16), ('연마', 15), ('제조업', 14), ('설계', 13), ('외주', 12), ('코팅', 12), ('입고', 12), ('유리', 12), ('현미경', 10), ('플라스틱', 10)]
#
# < 악기 제조업 >
# [('제조', 41), ('악기', 21), ('사업장', 18), ('기타', 15), ('국악기', 14), ('부품', 14), ('제작', 13), ('조립', 11), ('가공', 10), ('절단', 10), ('나무', 8), ('목재', 8), ('오카리나', 6), ('북', 6), ('고객', 6), ('플라스틱', 6), ('바이올린', 5), ('장구', 5), ('피아노', 5), ('전통', 4)]
#
# < 코크스 및 연탄 제조업 >
# [('연탄', 10), ('무연탄', 8), ('석탄', 7), ('제조', 6), ('사업장', 3), ('코크스', 3), ('성형', 3), ('물', 3), ('생산', 3), ('압축', 2), ('건조', 2), ('가공품', 2), ('기계', 2), ('작업', 2), ('배합', 2), ('성형탄', 2), ('참숯', 2), ('원탄', 2), ('삼겹살', 1), ('납품', 1)]
#
# < 일차전지 및 축전지 제조업 >
# [('제조', 34), ('배터리', 31), ('전지', 30), ('차', 21), ('리튬', 18), ('조립', 17), ('축전지', 14), ('사업장', 12), ('이온', 12), ('입고', 12), ('부품', 8), ('납', 8), ('전극', 7), ('재료', 7), ('가공', 6), ('팩', 6), ('리', 6), ('연료전지', 5), ('밧데리', 5), ('생산', 5)]
#
# < 축산업 >
# [('사육', 175), ('돼지', 74), ('농장', 51), ('사업장', 49), ('닭', 47), ('양', 42), ('양계장', 34), ('생산', 29), ('돈', 29), ('판매', 28), ('번식', 24), ('부화', 21), ('시설', 19), ('갖추', 19), ('양돈업', 19), ('병아리', 18), ('축사', 17), ('한우', 17), ('계란', 17), ('굼벵이', 14)]
#
# < 무기 및 총포탄 제조업 >
# [('가공', 15), ('부품', 10), ('입고', 10), ('철', 7), ('조립', 6), ('제조', 6), ('알루미늄', 5), ('검사', 5), ('금속', 5), ('방산', 5), ('무기', 3), ('스틸', 3), ('원자재', 3), ('SCM', 2), ('총기', 2), ('방위', 2), ('산업', 2), ('총', 2), ('들어가', 2), ('는', 2)]
#
# < 어로 어업 >
# [('포획', 6), ('원양', 5), ('참치', 4), ('어류', 4), ('해', 3), ('어획', 3), ('물고기', 3), ('연근', 3), ('공동', 3), ('채취', 3), ('양어업', 2), ('해역', 2), ('오징어', 2), ('근해', 2), ('원양어', 1), ('선', 1), ('이용', 1), ('수산물', 1), ('명태', 1), ('독항선', 1)]
#
# < 수의업 >
# [('동물', 2071), ('병원', 902), ('치료', 700), ('대상', 603), ('예방', 309), ('질병', 283), ('서비스', 273), ('진료', 244), ('애완', 241), ('수의업', 77), ('고객', 75), ('수술', 58), ('축산', 57), ('제공', 54), ('애견', 49), ('가축', 47), ('중절', 47), ('접종', 41), ('애완견', 41), ('사업장', 40)]
#
# < 의료용품 및 기타 의약 관련제품 제조업 >
# [('제조', 55), ('의료', 38), ('가공', 22), ('사업장', 20), ('원단', 15), ('기기', 14), ('입고', 12), ('용품', 12), ('포장', 8), ('원료', 8), ('재단', 7), ('관련', 6), ('치과', 6), ('거즈', 6), ('접착제', 6), ('진단', 6), ('원재료', 6), ('밴드', 6), ('병원', 5), ('붕대', 5)]
#
# < 자동차용 엔진 및 자동차 제조업 >
# [('엔진', 7), ('차체', 6), ('조립', 5), ('자동차', 5), ('승용차', 4), ('차', 4), ('사업장', 4), ('부품', 4), ('프레스', 4), ('소형', 3), ('전기', 3), ('입고', 3), ('제조', 3), ('소재', 3), ('미션', 3), ('판넬', 2), ('차량', 2), ('코일', 2), ('알루미늄', 2), ('구입', 2)]
#
# < 석유 정제품 제조업 >
# [('폐유', 28), ('윤활유', 27), ('정제', 27), ('제조', 18), ('원유', 12), ('원료', 12), ('오일', 11), ('투입', 10), ('기유', 10), ('혼합', 9), ('입고', 8), ('사업장', 8), ('재생', 8), ('첨가제', 7), ('폐', 6), ('정제유', 6), ('배합', 5), ('처리', 5), ('그리스', 5), ('유기', 5)]
#
# < 기록매체 복제업 >
# [('복제', 15), ('매체', 11), ('사업장', 11), ('제작', 10), ('기록', 10), ('제조', 8), ('음반', 7), ('고객', 6), ('의뢰', 6), ('CD', 5), ('비디오', 5), ('복사', 5), ('쇄', 4), ('영상물', 3), ('영상', 3), ('복', 3), ('제업', 3), ('사무실', 3), ('인', 3), ('인쇄', 3)]
#
# < 파이프라인 운송업 >
# [('파이프라인', 3), ('운송', 2), ('원유', 1), ('정유', 1), ('저장', 1), ('는', 1), ('석유', 1), ('수송', 1), ('서비스', 1), ('유류', 1), ('장소', 1), ('경질유', 1), ('송유관', 1), ('이용', 1)]
#
# < 기초 의약 물질 및 생물학적 제제 제조업 >
# [('원료', 15), ('제조', 8), ('반응', 7), ('투입', 5), ('합성', 5), ('화학', 5), ('가공', 4), ('줄기세포', 4), ('제조업', 4), ('세포', 4), ('미생물', 3), ('혼합', 3), ('의약품', 3), ('연구', 3), ('의약', 3), ('개발', 3), ('정제', 3), ('화장품', 3), ('생물학', 3), ('톨루엔', 2)]
#
# < 비철금속 광업 >
# [('채굴', 6), ('광산', 4), ('기계', 3), ('이용', 3), ('금', 3), ('은', 3), ('고객', 2), ('의뢰', 1), ('철광석', 1), ('세하', 1), ('믹', 1), ('게르마늄', 1), ('체취', 1), ('동', 1), ('정광', 1), ('몰리브덴', 1), ('휘수연광', 1), ('채광', 1), ('조쇄', 1), ('비철', 1)]
#
# < 항공 여객 운송업 >
# [('운송', 27), ('정기', 25), ('항공', 18), ('노선', 16), ('일정', 15), ('항공사', 14), ('운행', 14), ('화물', 14), ('여객', 13), ('승객', 7), ('공항', 7), ('대상', 6), ('국내외', 5), ('항공기', 3), ('여행객', 3), ('국외', 3), ('사업장', 3), ('운송업', 3), ('고객', 2), ('운항', 2)]
#
# < 철 광업 >
# [('광산', 1), ('채굴', 1), ('철광', 1), ('생산', 1)]
#
# < 고등 교육기관 >
# [('교육', 430), ('대학원', 248), ('전문', 172), ('과정', 166), ('대학', 139), ('학생', 131), ('서비스', 123), ('대상', 119), ('대학교', 93), ('이수', 64), ('화', 63), ('된', 59), ('교과', 45), ('대학원생', 44), ('제공', 44), ('학위', 33), ('고도', 32), ('전공', 29), ('강의', 21), ('대학생', 20)]
#
# < 내륙 수상 및 항만 내 운송업 >
# [('운송', 17), ('유람선', 12), ('대상', 11), ('선박', 9), ('여객', 9), ('배', 9), ('관광객', 7), ('관광', 7), ('고객', 7), ('항만', 7), ('이용', 6), ('일반인', 6), ('해상', 6), ('낚시', 5), ('운영', 4), ('수상', 4), ('사업장', 3), ('수송', 3), ('싣', 3), ('사업', 2)]
#
# < 특수학교, 외국인학교 및 대안학교 >
# [('학교', 75), ('교육', 65), ('특수', 50), ('대상', 37), ('장애', 35), ('학생', 29), ('서비스', 24), ('대안', 14), ('인', 12), ('외국인', 10), ('초', 8), ('정신', 8), ('아동', 6), ('지체', 6), ('국제', 5), ('인가', 4), ('특수교육', 4), ('신체장애자', 4), ('장애아', 4), ('장애자', 4)]
#
# < 사회보장 행정 >
# [('고용', 35), ('지원', 22), ('행정', 21), ('실업', 20), ('센터', 18), ('취업', 13), ('서비스', 11), ('보장', 10), ('대상', 10), ('급여', 10), ('알선', 9), ('센타', 9), ('복지', 7), ('보상', 7), ('보험', 6), ('업무', 5), ('사무', 5), ('일자리', 5), ('노동', 5), ('일반인', 4)]
#
# < 항공 화물 운송업 >
# [('운송', 7), ('화물', 6), ('항공', 5), ('서비스', 4), ('사업장', 4), ('고객', 3), ('수출입', 2), ('의뢰', 2), ('화주', 2), ('항공기', 1), ('제공', 1), ('사무실', 1), ('의하', 1), ('운송업', 1), ('운송업자', 1), ('간', 1), ('해운', 1), ('주선', 1), ('알선', 1), ('국제', 1)]
#
# < 모피제품 제조업 >
# [('모피', 77), ('재단', 39), ('의류', 33), ('제조', 27), ('봉제', 16), ('천연', 15), ('원단', 15), ('사업장', 12), ('재봉', 10), ('여성', 9), ('입고', 7), ('가죽', 7), ('피', 7), ('임가공', 6), ('제품', 6), ('밍크', 6), ('인조모', 6), ('가공', 6), ('코트', 5), ('공장', 4)]
#
# < 철도 운송업 >
# [('철도', 92), ('운송', 82), ('화물', 32), ('도시', 28), ('간', 28), ('여객', 23), ('승객', 23), ('차량', 18), ('이용', 17), ('대상', 8), ('기차역', 8), ('서비스', 7), ('운송업', 6), ('일반인', 5), ('고객', 4), ('역', 4), ('수송', 3), ('철도역', 3), ('역사', 2), ('운행', 2)]
#
# < 자동차 재제조 부품 제조업 >
# [('부품', 23), ('자동차', 22), ('제조', 16), ('재', 13), ('조립', 6), ('엔진', 5), ('중고', 5), ('제조업', 4), ('세척', 4), ('분해', 3), ('수리', 3), ('검사', 2), ('금속', 2), ('알터', 2), ('가공', 2), ('철판', 2), ('사업장', 2), ('의뢰', 2), ('범퍼', 1), ('함', 1)]
#
# < 광업 지원 서비스업 >
# [('사업장', 3), ('자원', 2), ('유전', 2), ('개발', 2), ('광물', 2), ('에너지', 1), ('운영', 1), ('관련', 1), ('서비스업', 1), ('수수료', 1), ('또는', 1), ('계약', 1), ('의거', 1), ('원유', 1), ('지원', 1), ('탐사', 1), ('서비스', 1), ('해외', 1), ('아프리카', 1), ('금', 1)]
#
# < 재보험업 >
# [('보험', 4), ('재보험', 2), ('사간', 1), ('계약', 1), ('의거', 1), ('서비스', 1), ('사무실', 1), ('대상', 1), ('생명', 1)]
#
# < 외무 및 국방 행정 >
# [('병무청', 4), ('병무', 4), ('행정', 4), ('서비스', 3), ('민방위', 3), ('교육', 3), ('시민', 2), ('생활', 2), ('안전', 2), ('체험', 2), ('모병', 1), ('징병', 1), ('업무', 1), ('병역', 1), ('관련', 1), ('해', 1), ('공군', 1), ('민방위대', 1), ('국가', 1), ('방위', 1)]
#
# < 라디오 방송업 >
# [('방송', 31), ('라디오', 25), ('방송국', 8), ('송출', 8), ('프로그램', 5), ('제작', 5), ('청취자', 3), ('대상', 3), ('사업장', 3), ('서비스', 3), ('기독교', 3), ('제공', 3), ('불교', 3), ('영어', 2), ('광고', 2), ('서대문구', 1), ('구민', 1), ('통해', 1), ('일반인', 1), ('지상파', 1)]
#
# < 마그네틱 및 광학 매체 제조업 >
# [('산업', 2), ('마그네', 1), ('틱', 1), ('사용자', 1), ('요청', 1), ('재단', 1), ('제작', 1), ('홀로그램', 1), ('시트', 1), ('테이프', 1), ('제조업', 1), ('통신', 1), ('방송', 1), ('장비', 1), ('영상', 1), ('음향', 1), ('기기', 1), ('폴리카보네이트', 1), ('본딩', 1), ('글루', 1)]
#
# < 석탄 광업 >
# [('무연탄', 1), ('발파', 1), ('생산', 1)]
#
# < 담배 제조업 >
# [('담배', 4), ('차세대', 2), ('제조', 2), ('투입', 2), ('잎담배', 1), ('판', 1), ('상엽', 1), ('가공', 1), ('궐련', 1), ('상품', 1), ('향료', 1), ('재료', 1), ('정제', 1), ('혼합', 1), ('출하', 1), ('액상', 1), ('잎', 1), ('잎줄기', 1), ('원료', 1), ('슬러리', 1)]

# %% [markdown]
# ## <b>5.0 인코딩</b>

# %%
X_train = pd.read_csv('./data/mecab/tokenized_train.csv', encoding='CP949')

y_train = X_train[['digit_1', 'digit_2', 'digit_3']]
X_train = X_train['text']

logger.info("log info")

# %%
X_test = pd.read_csv('./data/mecab/tokenized_test.csv', encoding='CP949')
X_test = X_test['text']

logger.info("log info")

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

threshold = 1 # 등장 빈도 수의 threshold
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)

# 전체 단어 개수 중 빈도수 0 인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)

logger.info("log info")
# Out:
# 단어 집합(vocabulary)의 크기 : 35701
# 등장 빈도가 0번 이하인 희귀 단어의 수: 0
# 단어 집합에서 희귀 단어의 비율: 0.0
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 0.0
# 단어 집합의 크기 : 35702

# %%
tokenizer = Tokenizer(vocab_size)
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)

logger.info("log info")

# %%
X_test = tokenizer.texts_to_sequences(X_test)

logger.info("log info")

# %%
# Tokenizer 객체에 담긴 어휘 분석 정보가 현재 폴더의 tokenizer.pickle에 저장

with open('./data/mecab/tokenizer.pickle', 'wb') as handle:
     pickle.dump(tokenizer, handle)

logger.info("log info")

# %% [markdown]
# ## <b>6.0 패딩</b>

# %%
# max_len 결정

print('리뷰의 최대 길이 :',max(len(word) for word in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))

plt.hist([len(word) for word in X_train], bins=100)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

def below_threshold_len(max_len, nested_list):
    count = 0
    for sentence in nested_list:
        if(len(sentence) <= max_len):
            count = count + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (count / len(nested_list))*100))
    
max_len = 10
below_threshold_len(max_len, X_train)

logger.info("log info")
# Out:
# 리뷰의 최대 길이 : 27
# 리뷰의 평균 길이 : 6.153836
# 전체 샘플 중 길이가 10 이하인 샘플의 비율: 98.0321

# %%
# max_len 에 맞게 데이터셋 패딩

X_train = pad_sequences(X_train, maxlen=max_len)

X_test = pad_sequences(X_test, maxlen=max_len)

logger.info("log info")

# %%
# stratify split을 위해 개수가 1이라 나눌 수 없는 케이스 탐색

print(y_train.groupby(['digit_2'])['digit_2'].count().sort_values())

print(y_train.groupby(['digit_3'])['digit_3'].count().sort_values())

logger.info("log info")
# Out:
# digit_2
# 5          1
# 8          3
# 12         3
# 6          7
# 39        29
#        ...
# 96     56210
# 46     76835
# 49     90486
# 47    162202
# 56    173459
# Name: digit_2, Length: 74, dtype: int64
# digit_3
# 51          1
# 61          1
# 652         2
# 120         3
# 495         3
#         ...
# 492     39176
# 961     43040
# 493     49115
# 562     49756
# 561    123703
# Name: digit_3, Length: 225, dtype: int64

# %%
condition = y_train['digit_2']==5
y_train[condition]

logger.info("log info")

# %%
condition = y_train['digit_3'] == 61
y_train[condition]

logger.info("log info")

# %%
condition = y_train['digit_3'] == 51
y_train[condition]

logger.info("log info")

# %%
temp_436664 = y_train.iloc[[436664]]
temp_436664

logger.info("log info")

# %%
temp_52203 = y_train.iloc[[52203]]
temp_52203

logger.info("log info")

# %%
y_train.drop(y_train.index[436664], inplace=True)
y_train.drop(y_train.index[52203], inplace=True)

logger.info("log info")

# %%
X_train = pd.DataFrame(X_train)

X_train.iloc[[436664, 52203]]

temp_436664_x = X_train.iloc[[436664]]

temp_52203_x = X_train.iloc[[52203]]

X_train.drop(X_train.index[436664], inplace=True)
X_train.drop(X_train.index[52203], inplace=True)

X_train = np.array(X_train)

logger.info("log info")

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size= 0.2, stratify=y_train, random_state=34)

logger.info("log info")

# %%
print(len(X_train), len(X_valid), len(y_train), len(y_valid))

logger.info("log info")
# Out:
# 799998 200000 799998 200000

# %%
X_train = pd.DataFrame(X_train)

X_train = pd.concat([X_train, temp_436664_x, temp_52203_x])

X_train.reset_index(inplace=True, drop=True)

logger.info("log info")

# %%
X_train

logger.info("log info")

# %%
X_train = np.array(X_train)

logger.info("log info")

# %%
y_train = pd.concat([y_train, temp_436664, temp_52203])

y_train.reset_index(inplace=True, drop=True)

y_train

logger.info("log info")

# %%
# 데이터 셋 저장

pd.DataFrame(X_train).to_csv('./data/mecab/X_train.csv', encoding='CP949', index=False)
pd.DataFrame(X_valid).to_csv('./data/mecab/X_valid.csv', encoding='CP949', index=False)
pd.DataFrame(X_test).to_csv('./data/mecab/X_test.csv', encoding='CP949', index=False)
y_train.to_csv('./data/mecab/y_train.csv', encoding='CP949', index=False)
y_valid.to_csv('./data/mecab/y_valid.csv', encoding='CP949', index=False)

print(len(X_train), len(X_valid), len(y_train), len(y_valid), len(X_test))

logger.info("log info")
# Out:
# 800000 200000 800000 200000 100000

# %% [markdown]
# # LSTM

# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import numpy as np
import re               # Regular Expression
import pickle           # 토큰화된 단어목록의 인덱스를 저장, 불러오기 위해 사용
from tqdm import tqdm   # 진행상황 Progress Bar를 위한 tqdm library

# 토크나이징/인코딩 관련 라이브러리
from eunjeon import Mecab
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn import preprocessing

# 모델링 관련 라이브러리
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 그래프 관련 라이브러리
import matplotlib.pyplot as plt
import platform

# 한글 폰트 설정
if (platform.system() == 'Windows'):
    plt.rc('font', family='Malgun Gothic')
else:
    plt.rc('font', family='AppleGothic')

# 음수(-)가 깨지는 현상 방지
plt.rcParams['axes.unicode_minus'] = False 

logger.info("log info")

# %% [markdown]
# 데이터 불러오기

# %%
# 전처리 및 분할된 데이터셋 불러오기

X_train = np.array(pd.read_csv('./data/mecab/X_train.csv'))
y_train_1 = pd.DataFrame(pd.read_csv('./data/mecab/y_train.csv')['digit_1'])
y_train_2 = pd.DataFrame(pd.read_csv('./data/mecab/y_train.csv')['digit_2'].astype(object))
y_train_3 = pd.DataFrame(pd.read_csv('./data/mecab/y_train.csv')['digit_3'].astype(object))

X_valid = np.array(pd.read_csv('./data/mecab/X_valid.csv'))
y_valid_1 =  pd.DataFrame(pd.read_csv('./data/mecab/y_valid.csv')['digit_1'])
y_valid_2 =  pd.DataFrame(pd.read_csv('./data/mecab/y_valid.csv')['digit_2'].astype(object))
y_valid_3 =  pd.DataFrame(pd.read_csv('./data/mecab/y_valid.csv')['digit_3'].astype(object))

X_test = np.array(pd.read_csv('./data/mecab/X_test.csv'))


# 저장된 Tokenizer 객체를 불러오는 부분

with open('./data/mecab/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

logger.info("log info")

# %%
# 한국표준산업분류 딕셔너리 불러오기

with open('./data/dictionary/digit_1_dict.pickle', 'rb') as handle:
    digit_1_dict = pickle.load(handle)

with open('./data/dictionary/digit_2_dict.pickle', 'rb') as handle:
    digit_2_dict = pickle.load(handle)

with open('./data/dictionary/digit_3_dict.pickle', 'rb') as handle:
    digit_3_dict = pickle.load(handle)

# 레이블 인코딩을 위한 산업분류 리스트, 데이터 프레임 만들기

digit_1_list = list(digit_1_dict.keys())
digit_1_df = pd.DataFrame([], columns=['digit_1'], index=[0])
for i in range(0, len(digit_1_dict)):
    digit_1_df.loc[i, 'digit_1'] = digit_1_list[i]

digit_2_list = list(digit_2_dict.keys())
digit_2_df = pd.DataFrame([], columns=['digit_2'], index=[0])
for i in range(0, len(digit_2_dict)):
    digit_2_df.loc[i, 'digit_2'] = digit_2_list[i]

digit_3_list = list(digit_3_dict.keys())
digit_3_df = pd.DataFrame([], columns=['digit_3'], index=[0])
for i in range(0, len(digit_3_dict)):
    digit_3_df.loc[i, 'digit_3'] = digit_3_list[i]

logger.info("log info")

# %% [markdown]
# ### 인코딩

# %%
# 대분류 원-핫 인코딩

ohe1 = preprocessing.OneHotEncoder(sparse=False, dtype=int)
ohe1.fit(digit_1_df)

y_train_1 = ohe1.transform(y_train_1)
y_valid_1 = ohe1.transform(y_valid_1)

# ohe1 객체에 담긴 인코딩 정보가 ohe1.pickle에 저장
with open('./data/mecab/ohe1.pickle', 'wb') as handle:
    pickle.dump(ohe1, handle)


# 중분류 원-핫 인코딩

ohe2 = preprocessing.OneHotEncoder(sparse=False, dtype=int)
ohe2.fit(digit_2_df)

y_train_2 = ohe2.transform(y_train_2)
y_valid_2 = ohe2.transform(y_valid_2)

# ohe2 객체에 담긴 인코딩 정보가 ohe2.pickle에 저장
with open('./data/mecab/ohe2.pickle', 'wb') as handle:
    pickle.dump(ohe2, handle)


# 소분류 원-핫 인코딩

ohe3 = preprocessing.OneHotEncoder(sparse=False, dtype=int)
ohe3.fit(digit_3_df)

y_train_3 = ohe3.transform(y_train_3)
y_valid_3 = ohe3.transform(y_valid_3)

# ohe3 객체에 담긴 인코딩 정보가 ohe3.pickle에 저장
with open('./data/mecab/ohe3.pickle', 'wb') as handle:
    pickle.dump(ohe3, handle)

logger.info("log info")

# %% [markdown]
# ## 대분류

# %%
embedding_dim = len(X_train[0])
hidden_units = len(X_train[0])
vocab_size = 35721

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(len(y_train_1[0]), activation='softmax'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('./data/model/mecab_d1_ed{}_hu{}_sftmx_cc.h5'.format(embedding_dim, hidden_units), monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train_1, epochs=20, callbacks=[es, mc], batch_size=100, validation_data=(X_valid, y_valid_1))


# 그래프 생성

y_test_loss = history.history['val_loss']
y_train_loss = history.history['loss']

x_len = np.arange(len(y_test_loss))

plt.plot (x_len, y_test_loss, marker=',', c='red', label='Testset_loss')
plt.plot(x_len, y_train_loss, marker=',', c='blue', label='Trainset_loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

logger.info("log info")
# Out:
# Epoch 1/20
# 8000/8000 [==============================] - 93s 11ms/step - loss: 0.3314 - acc: 0.9132 - val_loss: 0.1256 - val_acc: 0.9673
#
# Epoch 00001: val_acc improved from -inf to 0.96730, saving model to mecab_d1_ed10_hu10_sftmx_cc.h5
# Epoch 2/20
# 8000/8000 [==============================] - 88s 11ms/step - loss: 0.1066 - acc: 0.9718 - val_loss: 0.1106 - val_acc: 0.9703
#
# Epoch 00002: val_acc improved from 0.96730 to 0.97027, saving model to mecab_d1_ed10_hu10_sftmx_cc.h5
# Epoch 3/20
# 8000/8000 [==============================] - 89s 11ms/step - loss: 0.0912 - acc: 0.9754 - val_loss: 0.1067 - val_acc: 0.9710
#
# Epoch 00003: val_acc improved from 0.97027 to 0.97102, saving model to mecab_d1_ed10_hu10_sftmx_cc.h5
# Epoch 4/20
# 8000/8000 [==============================] - 86s 11ms/step - loss: 0.0829 - acc: 0.9773 - val_loss: 0.1054 - val_acc: 0.9712
#
# Epoch 00004: val_acc improved from 0.97102 to 0.97124, saving model to mecab_d1_ed10_hu10_sftmx_cc.h5
# Epoch 5/20
# 8000/8000 [==============================] - 88s 11ms/step - loss: 0.0772 - acc: 0.9786 - val_loss: 0.1027 - val_acc: 0.9721
#
# Epoch 00005: val_acc improved from 0.97124 to 0.97211, saving model to mecab_d1_ed10_hu10_sftmx_cc.h5
# Epoch 6/20
# 8000/8000 [==============================] - 88s 11ms/step - loss: 0.0731 - acc: 0.9795 - val_loss: 0.1033 - val_acc: 0.9721
#
# Epoch 00006: val_acc did not improve from 0.97211
# Epoch 7/20
# 8000/8000 [==============================] - 87s 11ms/step - loss: 0.0700 - acc: 0.9803 - val_loss: 0.1034 - val_acc: 0.9721
#
# Epoch 00007: val_acc did not improve from 0.97211
# Epoch 8/20
# 8000/8000 [==============================] - 92s 11ms/step - loss: 0.0676 - acc: 0.9810 - val_loss: 0.1034 - val_acc: 0.9718
#
# Epoch 00008: val_acc did not improve from 0.97211
# Epoch 9/20
# 8000/8000 [==============================] - 94s 12ms/step - loss: 0.0656 - acc: 0.9814 - val_loss: 0.1038 - val_acc: 0.9719
#
# Epoch 00009: val_acc did not improve from 0.97211
# Epoch 00009: early stopping

# %%
loaded_model = load_model('./data/model/mecab_d1_ed{}_hu{}_sftmx_cc.h5'.format(embedding_dim, hidden_units))
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_valid, y_valid_1)[1]))

logger.info("log info")
# Out:
# 6250/6250 [==============================] - 17s 3ms/step - loss: 0.1027 - acc: 0.9721
#
#  테스트 정확도: 0.9721

# %% [markdown]
# ## 중분류

# %%
embedding_dim = len(X_train[0])
hidden_units = len(X_train[0])
vocab_size = 35721

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(len(y_train_2[0]), activation='softmax'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
mc = ModelCheckpoint('./data/model/mecab_d2_ed{}_hu{}_sftmx_cc.h5'.format(embedding_dim, hidden_units), monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train_2, epochs=20, callbacks=[es, mc], batch_size=100, validation_data=(X_valid, y_valid_2))


y_test_loss = history.history['val_loss']
y_train_loss = history.history['loss']

x_len = np.arange(len(y_test_loss))

plt.plot (x_len, y_test_loss, marker=',', c='red', label='Testset_loss')
plt.plot(x_len, y_train_loss, marker=',', c='blue', label='Trainset_loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

logger.info("log info")
# Out:
# Epoch 1/20
# 8000/8000 [==============================] - 97s 12ms/step - loss: 0.8917 - acc: 0.7889 - val_loss: 0.4049 - val_acc: 0.9019
#
# Epoch 00001: val_acc improved from -inf to 0.90192, saving model to ./data/model\mecab_d2_ed10_hu10_sftmx_cc.h5
# Epoch 2/20
# 8000/8000 [==============================] - 95s 12ms/step - loss: 0.3274 - acc: 0.9187 - val_loss: 0.3074 - val_acc: 0.9232
#
# Epoch 00002: val_acc improved from 0.90192 to 0.92325, saving model to ./data/model\mecab_d2_ed10_hu10_sftmx_cc.h5
# Epoch 3/20
# 8000/8000 [==============================] - 97s 12ms/step - loss: 0.2627 - acc: 0.9327 - val_loss: 0.2823 - val_acc: 0.9278
#
# Epoch 00003: val_acc improved from 0.92325 to 0.92783, saving model to ./data/model\mecab_d2_ed10_hu10_sftmx_cc.h5
# Epoch 4/20
# 8000/8000 [==============================] - 93s 12ms/step - loss: 0.2359 - acc: 0.9388 - val_loss: 0.2745 - val_acc: 0.9300
#
# Epoch 00004: val_acc improved from 0.92783 to 0.93001, saving model to ./data/model\mecab_d2_ed10_hu10_sftmx_cc.h5
# Epoch 5/20
# 8000/8000 [==============================] - 100s 12ms/step - loss: 0.2211 - acc: 0.9417 - val_loss: 0.2694 - val_acc: 0.9305
#
# Epoch 00005: val_acc improved from 0.93001 to 0.93055, saving model to ./data/model\mecab_d2_ed10_hu10_sftmx_cc.h5
# Epoch 6/20
# 8000/8000 [==============================] - 105s 13ms/step - loss: 0.2112 - acc: 0.9440 - val_loss: 0.2669 - val_acc: 0.9308
#
# Epoch 00006: val_acc improved from 0.93055 to 0.93081, saving model to ./data/model\mecab_d2_ed10_hu10_sftmx_cc.h5
# Epoch 7/20
# 8000/8000 [==============================] - 94s 12ms/step - loss: 0.2042 - acc: 0.9455 - val_loss: 0.2660 - val_acc: 0.9311
#
# Epoch 00007: val_acc improved from 0.93081 to 0.93108, saving model to ./data/model\mecab_d2_ed10_hu10_sftmx_cc.h5
# Epoch 8/20
# 8000/8000 [==============================] - 106s 13ms/step - loss: 0.1986 - acc: 0.9465 - val_loss: 0.2662 - val_acc: 0.9312
#
# Epoch 00008: val_acc improved from 0.93108 to 0.93125, saving model to ./data/model\mecab_d2_ed10_hu10_sftmx_cc.h5
# Epoch 9/20
# 8000/8000 [==============================] - 102s 13ms/step - loss: 0.1944 - acc: 0.9477 - val_loss: 0.2652 - val_acc: 0.9316
#
# Epoch 00009: val_acc improved from 0.93125 to 0.93162, saving model to ./data/model\mecab_d2_ed10_hu10_sftmx_cc.h5
# Epoch 10/20
# 8000/8000 [==============================] - 105s 13ms/step - loss: 0.1907 - acc: 0.9485 - val_loss: 0.2656 - val_acc: 0.9317
#
# Epoch 00010: val_acc improved from 0.93162 to 0.93173, saving model to ./data/model\mecab_d2_ed10_hu10_sftmx_cc.h5
# Epoch 11/20
# 8000/8000 [==============================] - 100s 13ms/step - loss: 0.1877 - acc: 0.9489 - val_loss: 0.2659 - val_acc: 0.9311
#
# Epoch 00011: val_acc did not improve from 0.93173
# Epoch 00011: early stopping

# %%
loaded_model = load_model('./data/model/mecab_d2_ed{}_hu{}_sftmx_cc.h5'.format(embedding_dim, hidden_units))
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_valid, y_valid_2)[1]))

logger.info("log info")
# Out:
# 6250/6250 [==============================] - 21s 3ms/step - loss: 0.2656 - acc: 0.9317: 0s - loss: 0.2657 - acc:
#
#  테스트 정확도: 0.9317

# %% [markdown]
# ## 소분류

# %%
vocab_size = 35703
embedding_dim = len(X_train[0])
hidden_units = len(X_train[0])

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(232, activation='softmax'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
mc = ModelCheckpoint('./data/model/mecab_d3_ed{}_hu{}_sftmx_cc.h5'.format(embedding_dim, hidden_units), monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train_3, epochs=20, callbacks=[es, mc], batch_size=100, validation_data=(X_valid, y_valid_3))

y_test_loss = history.history['val_loss']
y_train_loss = history.history['loss']

x_len = np.arange(len(y_test_loss))

plt.plot (x_len, y_test_loss, marker=',', c='red', label='Testset_loss')
plt.plot(x_len, y_train_loss, marker=',', c='blue', label='Trainset_loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

logger.info("log info")
# Out:
# Epoch 1/20
# 8000/8000 [==============================] - 111s 14ms/step - loss: 1.9345 - acc: 0.5476 - val_loss: 0.9060 - val_acc: 0.7969
#
# Epoch 00001: val_acc improved from -inf to 0.79693, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 2/20
# 8000/8000 [==============================] - 100s 13ms/step - loss: 0.7066 - acc: 0.8368 - val_loss: 0.6177 - val_acc: 0.8563
#
# Epoch 00002: val_acc improved from 0.79693 to 0.85629, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 3/20
# 8000/8000 [==============================] - 104s 13ms/step - loss: 0.5360 - acc: 0.8737 - val_loss: 0.5349 - val_acc: 0.8741
#
# Epoch 00003: val_acc improved from 0.85629 to 0.87413, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 4/20
# 8000/8000 [==============================] - 100s 13ms/step - loss: 0.4668 - acc: 0.8884 - val_loss: 0.4987 - val_acc: 0.8819
#
# Epoch 00004: val_acc improved from 0.87413 to 0.88187, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 5/20
# 8000/8000 [==============================] - 101s 13ms/step - loss: 0.4295 - acc: 0.8965 - val_loss: 0.4789 - val_acc: 0.8862
#
# Epoch 00005: val_acc improved from 0.88187 to 0.88624, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 6/20
# 8000/8000 [==============================] - 103s 13ms/step - loss: 0.4058 - acc: 0.9014 - val_loss: 0.4687 - val_acc: 0.8883oss: 0.4059 -
#
# Epoch 00006: val_acc improved from 0.88624 to 0.88827, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 7/20
# 8000/8000 [==============================] - 107s 13ms/step - loss: 0.3891 - acc: 0.9049 - val_loss: 0.4616 - val_acc: 0.8897
#
# Epoch 00007: val_acc improved from 0.88827 to 0.88974, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 8/20
# 8000/8000 [==============================] - 97s 12ms/step - loss: 0.3764 - acc: 0.9075 - val_loss: 0.4546 - val_acc: 0.8914
#
# Epoch 00008: val_acc improved from 0.88974 to 0.89144, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 9/20
# 8000/8000 [==============================] - 82s 10ms/step - loss: 0.3666 - acc: 0.9096 - val_loss: 0.4521 - val_acc: 0.8915
#
# Epoch 00009: val_acc improved from 0.89144 to 0.89148, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 10/20
# 8000/8000 [==============================] - 97s 12ms/step - loss: 0.3585 - acc: 0.9112 - val_loss: 0.4490 - val_acc: 0.8919
#
# Epoch 00010: val_acc improved from 0.89148 to 0.89192, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 11/20
# 8000/8000 [==============================] - 96s 12ms/step - loss: 0.3521 - acc: 0.9124 - val_loss: 0.4474 - val_acc: 0.8930
#
# Epoch 00011: val_acc improved from 0.89192 to 0.89301, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 12/20
# 8000/8000 [==============================] - 97s 12ms/step - loss: 0.3466 - acc: 0.9135 - val_loss: 0.4441 - val_acc: 0.8934
#
# Epoch 00012: val_acc improved from 0.89301 to 0.89344, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 13/20
# 8000/8000 [==============================] - 112s 14ms/step - loss: 0.3418 - acc: 0.9147 - val_loss: 0.4417 - val_acc: 0.8936
#
# Epoch 00013: val_acc improved from 0.89344 to 0.89361, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 14/20
# 8000/8000 [==============================] - 115s 14ms/step - loss: 0.3375 - acc: 0.9157 - val_loss: 0.4433 - val_acc: 0.8935
#
# Epoch 00014: val_acc did not improve from 0.89361
# Epoch 15/20
# 8000/8000 [==============================] - 108s 13ms/step - loss: 0.3338 - acc: 0.9163 - val_loss: 0.4412 - val_acc: 0.8941
#
# Epoch 00015: val_acc improved from 0.89361 to 0.89411, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 16/20
# 8000/8000 [==============================] - 113s 14ms/step - loss: 0.3304 - acc: 0.9170 - val_loss: 0.4418 - val_acc: 0.8941
#
# Epoch 00016: val_acc improved from 0.89411 to 0.89413, saving model to ./data/model\mecab_d3_ed10_hu10_sftmx_cc.h5
# Epoch 17/20
#  499/8000 [>.............................] - ETA: 1:32 - loss: 0.3177 - acc: 0.9201
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-c5d56cb0ceea> in <module>
#      12
#      13 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
# ---> 14 history = model.fit(X_train, y_train_3, epochs=20, callbacks=[es, mc], batch_size=100, validation_data=(X_valid, y_valid_3))
#      15
#      16 y_test_loss = history.history['val_loss']
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1176                 _r=1):
#    1177               callbacks.on_train_batch_begin(step)
# -> 1178               tmp_logs = self.train_function(iterator)
#    1179               if data_handler.should_sync:
#    1180                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
loaded_model = load_model('./data/model/mecab_d3_ed{}_hu{}_sftmx_cc.h5'.format(embedding_dim, hidden_units))
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_valid, y_valid_3)[1]))

logger.info("log info")
# Out:
# 6250/6250 [==============================] - 24s 4ms/step - loss: 0.4418 - acc: 0.8941: 3s - loss: 0.4432 -  - ETA: 2s - loss: 0.4418 - E - ETA: 0s - loss: 0.4421 -
#
#  테스트 정확도: 0.8941

# %% [markdown]
# ## 최종 예측 모델 결합, 답안 제출

# %%
X_test = np.array(pd.read_csv('./data/mecab/X_test.csv'))

logger.info("log info")

# %%
# 대분류/중분류/소분류 예측 모델 불러오기, 불러온 모델로 test data 예측

test_data = np.array(pd.read_csv('./data/mecab/test_data.csv'))

loaded_model_1 = load_model('./data/model/mecab_d1_ed{}_hu{}_sftmx_cc.h5'.format(embedding_dim, hidden_units))
y_test_1_predicted = loaded_model_1.predict(test_data)

loaded_model_2 = load_model('./data/model/mecab_d2_ed{}_hu{}_sftmx_cc.h5'.format(embedding_dim, hidden_units))
y_test_2_predicted = loaded_model_2.predict(test_data)

loaded_model_3 = load_model('./data/model/mecab_d3_ed{}_hu{}_sftmx_cc.h5'.format(embedding_dim, hidden_units))
y_test_3_predicted = loaded_model_3.predict(test_data)

logger.info("log info")

# %%
# 인코딩된 예측값 원래 형태로 원상 복구

temp_list_1 = []
temp_list_2 = []
temp_list_3 = []

for i in tqdm(range(0, len(y_test_1_predicted))):
    temp_list_1.append(ohe1.inverse_transform([y_test_1_predicted[i]])[0][0])
    temp_list_2.append(ohe2.inverse_transform([y_test_2_predicted[i]])[0][0])
    temp_list_3.append(ohe3.inverse_transform([y_test_3_predicted[i]])[0][0])

logger.info("log info")
# Out:
# 100%|██████████| 100000/100000 [00:42<00:00, 2364.13it/s]

# %%
# 답안 작성용 파일에 대분류/중분류/소분류 예측 컬럼 삽입 후 csv 파일로 저장

test_data = pd.read_csv('./data/test.csv')

test_data['digit_1'] = temp_list_1
test_data['digit_2'] = temp_list_2
test_data['digit_3'] = temp_list_3

test_data.to_csv('./data/output/답안 작성용 파일.csv', encoding='CP949', index=False)

logger.info("log info")

# %%
test_data

logger.info("log info")
# Out:
#            AI_id digit_1  digit_2  digit_3  text_obj   text_mthd text_deal
# 0      id_000001       I       56      561   치킨전문점에서    고객의주문에의해      치킨판매
# 1      id_000002       G       46      466      산업공구   다른 소매업자에게    철물 수공구
# 2      id_000003       S       94      949       절에서    신도을 대상으로    불교단체운영
# 3      id_000004       C       30      302     영업장에서       고객요구로     자동차튜닝
# 4      id_000005       I       56      562  실내포장마차에서   접객시설을 갖추고   소주,맥주제공
# ...          ...     ...      ...      ...       ...         ...       ...
# 99995  id_099996       G       47      472     사업장에서     일반인대상으로      버섯농장
# 99996  id_099997       Q       86      862     한의원에서     외래환자위주고        치료
# 99997  id_099998       G       47      478    일반점포에서       소비자에게      그림판매
# 99998  id_099999       R       90      902     사업장에서  일반인.학생대상으로    학습공간제공
# 99999  id_100000       L       68      682     사업장에서    대리현대아파트를        관리
#
# [100000 rows x 7 columns]

# %%
# 결과값 검정 용이를 위해 산업분류 사전과 매핑한 csv 저장

translated_data = test_data.copy()
translated_data['digit_1'] = translated_data['digit_1'].replace(digit_1_dict)
translated_data['digit_2'] = translated_data['digit_2'].replace(digit_2_dict)
translated_data['digit_3'] = translated_data['digit_3'].replace(digit_3_dict)

translated_data.to_csv('./data/output/final_translated.csv', encoding='CP949', index=False)

logger.info("log info")

# %%
translated_data

logger.info("log info")
# Out:
#            AI_id                          digit_1             digit_2  \
# 0      id_000001                 숙박 및 음식점업(55~56)           음식점 및 주점업
# 1      id_000002                  도매 및 소매업(45~47)         도매 및 상품 중개업
# 2      id_000003  협회 및 단체, 수리 및 기타 개인 서비스업(94~96)             협회 및 단체
# 3      id_000004                       제조업(10~34)      자동차 및 트레일러 제조업
# 4      id_000005                 숙박 및 음식점업(55~56)           음식점 및 주점업
# ...          ...                              ...                 ...
# 99995  id_099996                  도매 및 소매업(45~47)         소매업; 자동차 제외
# 99996  id_099997           보건업 및 사회복지 서비스업(86~87)                 보건업
# 99997  id_099998                  도매 및 소매업(45~47)         소매업; 자동차 제외
# 99998  id_099999       예술, 스포츠 및 여가관련 서비스업(90~91)  창작, 예술 및 여가관련 서비스업
# 99999  id_100000                         부동산업(68)                부동산업
#
#                        digit_3  text_obj   text_mthd text_deal
# 0                         음식점업   치킨전문점에서    고객의주문에의해      치킨판매
# 1         건축 자재, 철물 및 난방장치 도매업      산업공구   다른 소매업자에게    철물 수공구
# 2                   기타 협회 및 단체       절에서    신도을 대상으로    불교단체운영
# 3              자동차 및 모터사이클 수리업     영업장에서       고객요구로     자동차튜닝
# 4               주점 및 비알코올 음료점업  실내포장마차에서   접객시설을 갖추고   소주,맥주제공
# ...                        ...       ...         ...       ...
# 99995           음ㆍ식료품 및 담배 소매업     사업장에서     일반인대상으로      버섯농장
# 99996                       의원     한의원에서     외래환자위주고        치료
# 99997             기타 상품 전문 소매업    일반점포에서       소비자에게      그림판매
# 99998  도서관, 사적지 및 유사 여가관련 서비스업     사업장에서  일반인.학생대상으로    학습공간제공
# 99999               부동산관련 서비스업     사업장에서    대리현대아파트를        관리
#
# [100000 rows x 7 columns]

# %% [markdown]
# ## 예측기

# %% [markdown]
# ### 대분류 예측기

# %% [markdown]
# ### 중분류 예측기

# %% [markdown]
# ### 소분류 예측기

# %%
mecab = Mecab()
loaded_model = load_model('./data/model/digit3_ed200_hu128_ep10_bs128_sftmx_cc.h5')
max_len = 15
stopwords = pd.read_csv('./data/stopwords/stopwords_concat.csv')


def sentiment_predict2(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  print(new_sentence)
  new_sentence = mecab.morphs(new_sentence) # 토큰화
  print(new_sentence)
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  print(new_sentence)
  encoded = tokenizer.texts_to_sequences(["{}".format(new_sentence)]) # 정수 인코딩
  print(encoded)
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  print(pad_new)
  label = loaded_model.predict(pad_new) # 예측
  print(label)
  print(le3.inverse_transform([label.argmax()])[0])
  print(digit_3_dict[le3.inverse_transform([label.argmax()])[0]])

# %%
sentiment_predict2('정비회사에서|자동차의전반적인|정비 종합수리서비스')
# Out:
# 정비회사에서자동차의전반적인정비 종합수리서비스
# ['정비', '회사', '에서', '자동차', '의', '전반', '적', '인', '정비', '종합', '수리', '서비스']
# ['정비', '회사', '에서', '자동차', '의', '전반', '적', '인', '정비', '종합', '수리', '서비스']
# [[271, 291, 43, 2169, 175, 271, 228, 46, 2]]
# [[   0    0    0    0    0    0  271  291   43 2169  175  271  228   46
#      2]]
# [[2.25543495e-08 6.05824141e-07 1.46671744e-10 1.06609705e-05
#   7.70816674e-11 1.70350845e-08 1.28942315e-10 1.73955748e-08
#   2.46597381e-10 1.65171571e-10 2.27767916e-10 3.23220062e-10
#   1.34238731e-10 1.91093894e-11 5.29234256e-09 2.25108465e-09
#   1.76460874e-10 2.92087021e-09 1.63499308e-07 2.07227679e-10
#   4.81583350e-11 1.70529315e-08 4.16814459e-08 2.74717887e-11
#   7.91270249e-09 1.07565179e-09 1.90920557e-10 1.01880504e-09
#   1.30524966e-10 1.16911991e-09 2.71794809e-09 1.13763790e-11
#   4.21847973e-10 1.15860023e-12 2.39433307e-10 3.19270010e-09
#   1.26816024e-09 6.26243875e-08 7.20114857e-09 2.93753466e-10
#   6.30222132e-08 5.38868399e-08 8.70925376e-09 3.78718461e-08
#   1.62408498e-09 8.93497365e-09 2.00720418e-08 5.21093557e-10
#   5.81940398e-08 9.94232405e-11 1.21807426e-08 6.75403600e-09
#   9.36299815e-10 8.86387284e-08 3.03010984e-11 2.43996752e-08
#   1.44285423e-07 4.39454118e-09 3.63428421e-09 1.82373061e-10
#   1.48256527e-08 9.70457670e-09 1.29363436e-08 2.05949169e-09
#   1.07549427e-08 2.25847618e-10 2.17355620e-07 1.14018563e-08
#   2.04364081e-08 1.23159072e-09 6.64715283e-10 8.40685317e-08
#   2.47907583e-09 1.39627798e-09 3.37591558e-07 4.40306778e-08
#   3.29800143e-09 4.87539520e-09 1.02367359e-07 1.45151169e-09
#   7.41960826e-10 1.97739464e-11 1.34646072e-08 2.65417306e-08
#   1.79632469e-08 1.08604709e-07 3.29283210e-07 5.82979141e-08
#   1.39060990e-06 1.35980520e-06 8.80266455e-08 7.06179870e-09
#   2.94563534e-07 3.11874864e-08 1.94100780e-09 6.23210705e-10
#   9.77347838e-08 8.41772263e-10 5.14611509e-09 2.35932486e-04
#   8.89598378e-12 1.48987811e-09 1.29962305e-10 5.57715474e-09
#   5.19301189e-08 4.76754167e-07 2.11686128e-07 9.56613803e-07
#   7.57039686e-07 1.41709279e-05 2.14863417e-06 2.30283194e-06
#   7.11678524e-07 4.50450784e-07 1.52889716e-05 5.90622076e-05
#   1.12956250e-05 1.91373488e-07 2.55096893e-05 2.33708178e-07
#   4.77080789e-07 1.70547281e-07 1.52948108e-08 3.55487515e-08
#   3.53651401e-08 1.15726211e-08 1.06032201e-06 1.34786816e-07
#   7.15281701e-08 3.76693379e-08 1.22285748e-09 8.87496132e-10
#   1.82676061e-07 4.20082955e-07 4.31623306e-08 7.45912303e-07
#   1.19887877e-08 6.06807093e-09 4.66863270e-07 7.08789366e-06
#   1.18879334e-05 6.33032127e-10 5.53302561e-05 8.42190744e-08
#   3.72041009e-10 6.83992667e-08 3.46391698e-06 5.44585164e-05
#   1.01840196e-05 2.11162501e-07 1.20238708e-08 4.41481340e-09
#   1.17110843e-09 9.40598779e-11 1.47458559e-10 1.05052737e-10
#   3.05413650e-08 5.06388230e-11 5.30116466e-08 7.60851204e-09
#   3.35160905e-07 4.42285408e-09 5.37935652e-09 1.36493782e-07
#   2.18376613e-07 3.43132598e-07 3.73320199e-06 1.59943383e-07
#   3.36823591e-09 2.51984920e-06 2.19312496e-05 1.48741506e-07
#   6.62514276e-06 3.59506942e-07 3.32033245e-09 7.53844205e-08
#   2.60341149e-09 1.17599697e-09 2.16033216e-11 1.59192908e-08
#   3.05648520e-08 8.88173929e-07 1.86690002e-07 1.11371214e-07
#   3.85266894e-08 6.40045386e-08 8.06049485e-08 4.86850076e-05
#   8.87730675e-06 3.24440883e-08 1.58491252e-06 5.31772514e-07
#   1.57377747e-06 7.80436130e-06 7.84889489e-05 5.58207125e-09
#   3.94108461e-08 1.36232126e-09 7.10169534e-10 1.92166667e-07
#   1.99142369e-09 8.00856299e-07 7.65058630e-08 1.23589683e-13
#   4.61996302e-10 3.12353615e-11 7.34024841e-10 1.68174405e-10
#   6.06783175e-08 1.36098366e-09 1.25428317e-08 1.39640912e-08
#   2.38951259e-07 2.30874386e-09 2.20516370e-08 2.44273810e-08
#   8.30725888e-09 1.95809502e-08 9.18612841e-07 1.19948379e-06
#   1.35423846e-07 9.84161017e-11 5.23206211e-07 5.97140615e-06
#   9.99229789e-01 3.86275533e-05 7.81020475e-08 2.25563304e-06
#   1.36316541e-10 1.16865323e-10 1.87009047e-10 9.78075468e-11]]
# 952
# 자동차 및 모터사이클 수리업

# %%
mecab = Mecab()
loaded_model = load_model('./data/model/digit2_ed200_hu128_ep10_bs128_sftmx_cc.h5')
max_len = 15
stopwords = pd.read_csv('./data/stopwords/stopwords_concat.csv')


def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  print(new_sentence)
  new_sentence = mecab.morphs(new_sentence) # 토큰화
  print(new_sentence)
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  print(new_sentence)
  encoded = tokenizer.texts_to_sequences(["{}".format(new_sentence)]) # 정수 인코딩
  print(encoded)
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  print(pad_new)
  label = loaded_model.predict(pad_new) # 예측
  print(label)
  print(le2.inverse_transform([label.argmax()])[0])
  print(digit_2_dict[le2.inverse_transform([label.argmax()])[0]])

# %%
sentiment_predict('영어학원|일반학생대상|영어교육')
# Out:
# 영어학원일반학생대상영어교육
# ['영어', '학원', '일반', '학생', '대상', '영어', '교육']
# ['영어', '학원', '일반', '학생', '대상', '영어', '교육']
# [[106, 30, 10, 38, 1, 106, 28]]
# [[  0   0   0   0   0   0   0   0 106  30  10  38   1 106  28]]
# [[3.3901244e-09 2.0897637e-08 3.8126666e-09 3.0675029e-10 2.2629222e-10
#   7.9605428e-08 3.2770386e-10 8.7994927e-08 7.0510360e-08 2.0747966e-10
#   2.8677161e-07 4.2352216e-08 2.1015593e-08 6.9544690e-08 1.5907085e-09
#   7.6828748e-08 1.1855049e-10 3.5715878e-08 2.3497962e-07 2.0660003e-08
#   3.3980680e-07 8.5391652e-11 4.7124776e-10 4.9496984e-09 2.7503464e-07
#   1.2095218e-09 3.9833288e-09 6.8410988e-09 2.5822013e-09 3.7302346e-08
#   2.2491537e-07 3.1255757e-07 4.7099481e-12 5.2456600e-10 2.8596964e-10
#   2.7771394e-08 7.6750064e-09 1.4437527e-06 1.7732052e-07 8.7860883e-09
#   2.1529750e-06 2.5718451e-05 3.7065444e-09 8.7804473e-08 8.3038493e-10
#   5.5193863e-09 1.8413728e-07 5.3079219e-07 3.3821743e-07 6.4629234e-07
#   3.9017416e-09 2.1560042e-07 1.5189957e-07 2.1014881e-07 1.7168924e-08
#   9.9406627e-10 1.2042550e-09 2.0148060e-07 7.4903039e-07 2.8469060e-07
#   2.7044985e-07 1.1377908e-06 9.7706099e-08 9.9672013e-07 1.5887036e-06
#   1.8836000e-07 9.9992013e-01 2.6954335e-06 1.3587302e-05 3.0651347e-06
#   6.3035873e-06 8.3682844e-06 1.1801167e-06 4.9148039e-06 1.1289615e-11
#   1.9101776e-11 1.7773800e-11]]
# 85
# 교육 서비스업

# %%
loaded_model = load_model('./best_model2.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test_3)[1]))
# Out:
# 6250/6250 [==============================] - 51s 8ms/step - loss: 13.4765 - acc: 0.0036
#
#  테스트 정확도: 0.0036

# %%
# 저장된 Tokenizer 객체를 불러오는 부분

with open('./data/mecab/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
tokenizer.word_index
# Out:
# {"'����'": 1,
#  "'���'": 2,
#  "'��'": 3,
#  "'������'": 4,
#  "'�����'": 5,
#  "'�ϲ�'": 6,
#  "'�ü�'": 7,
#  "'�ǹ�'": 8,
#  "'�һ���'": 9,
#  "'�ϲ���'": 10,
#  "'�ҹ�'": 11,
#  "'��û'": 12,
#  "'ȭ��'": 13,
#  "'��ǰ'": 14,
#  "'�ƿ�'": 15,
#  "'ȭ���ڵ���'": 16,
#  "'�ε���'": 17,
#  "'�߰�'": 18,
#  "'�°�'": 19,
#  "'�����ý�'": 20,
#  "'�繫��'": 21,
#  "'�п�'": 22,
#  "'�ڵ���'": 23,
#  "'ŀ��'": 24,
#  "'�л�'": 25,
#  "'�ҹž���'": 26,
#  "'ü��'": 27,
#  "'��ȸ'": 28,
#  "'ȱ��'": 29,
#  "'�̿��'": 30,
#  "'ȯ��'": 31,
#  "'��ʈ'": 32,
#  "'ö��'": 33,
#  "'��ġ'": 34,
#  "'�ܷ�'": 35,
#  "'�\ueff5'": 36,
#  "'ġ��'": 37,
#  "'�̿�'": 38,
#  "'����ʈ'": 39,
#  "'�ǽ�'": 40,
#  "'�ĸ�'": 41,
#  "'��ü'": 42,
#  "'�ѽ�'": 43,
#  "'�䱸'": 44,
#  "'��������'": 45,
#  "'��ź'": 46,
#  "'�ֹ�'": 47,
#  "'�ǰ�'": 48,
#  "'��ȭ'": 49,
#  "'ġų'": 50,
#  "'�\u2d76��'": 51,
#  "'�ǿ�'": 52,
#  "'�뷡��'": 53,
#  "'���ķ�ǰ'": 54,
#  "'ȸ��'": 55,
#  "'�ĵ�'": 56,
#  "'�\uee30��'": 57,
#  "'ö'": 58,
#  "'�ݼ�'": 59,
#  "'ȭ��ǰ'": 60,
#  "'�ǻ�'": 61,
#  "'�߹�'": 62,
#  "'��ź��'": 63,
#  "'�ְ�'": 64,
#  "'��ǻ��'": 65,
#  "'�ӵ�'": 66,
#  "'�ǳ�'": 67,
#  "'�\u0530�'": 68,
#  "'�ķ�ǰ'": 69,
#  "'��ÿ'": 70,
#  "'�뷡'": 71,
#  "'�븮'": 72,
#  "'�н�'": 73,
#  "'ŀʈ'": 74,
#  "'�ƶ�'": 75,
#  "'�ұ���'": 76,
#  "'���ü'": 77,
#  "'�߰���'": 78,
#  "'�˼�'": 79,
#  "'�ַ�'": 80,
#  "'��ö'": 81,
#  "'���\u05f8���'": 82,
#  "'�ҹž�'": 83,
#  "'�ǿƴ�'": 84,
#  "'�ö�ƽ'": 85,
#  "'�湮'": 86,
#  "'ī��'": 87,
#  "'�౹'": 88,
#  "'���ҹ�'": 89,
#  "'ŀ�ǽ�'": 90,
#  "'�κ�'": 91,
#  "'��ȣ��'": 92,
#  "'�ӹ�'": 93,
#  "'ư��'": 94,
#  "'�ұ�'": 95,
#  "'��ȱ'": 96,
#  "'�ڱ�'": 97,
#  "'���깰'": 98,
#  "'�̼�'": 99,
#  "'����ǰ'": 100,
#  "'�ΰ�'": 101,
#  "'ī��ÿ'": 102,
#  "'��ũ'": 103,
#  "'����ʈ����'": 104,
#  "'���ͳ�'": 105,
#  "'�ڸ�'": 106,
#  "'ó��'": 107,
#  "'�ð�'": 108,
#  "'��ȣ'": 109,
#  "'�μ�'": 110,
#  "'ȣ��'": 111,
#  "'�̸�'": 112,
#  "'ä��'": 113,
#  "'��ŷ�'": 114,
#  "'�籸��'": 115,
#  "'�˷�̴�'": 116,
#  "'ȭ'": 117,
#  "'�ι�'": 118,
#  "'�б�'": 119,
#  "'�\u07b4���'": 120,
#  "'�ź�'": 121,
#  "'�۸�'": 122,
#  "'�ǿ�ǰ'": 123,
#  "'�ƿ���'": 124,
#  "'�ŷ�'": 125,
#  "'ȸ'": 126,
#  "'ÿ�̾�'": 127,
#  "'��ȭ��'": 128,
#  "'�ѿ�'": 129,
#  "'�ʵ�'": 130,
#  "'���\U0007debe�'": 131,
#  "'�������'": 132,
#  "'�繫'": 133,
#  "'�߱�'": 134,
#  "'��깰'": 135,
#  "'�ȱ�'": 136,
#  "'�ڵ�'": 137,
#  "'�±ǵ�'": 138,
#  "'�η�'": 139,
#  "'�ù�'": 140,
#  "'�ÿ�'": 141,
#  "'�丮'": 142,
#  "'�뿩'": 143,
#  "'�¶���'": 144,
#  "'û��'": 145,
#  "'�м�'": 146,
#  "'pc'": 147,
#  "'�籸'": 148,
#  "'�о�'": 149,
#  "'�ƽ�'": 150,
#  "'â��'": 151,
#  "'į����'": 152,
#  "'��â'": 153,
#  "'�կ�'": 154,
#  "'�и�'": 155,
#  "'��ġ��'": 156,
#  "'������ǰ'": 157,
#  "'�븮��'": 158,
#  "'��ũ��'": 159,
#  "'�ý���'": 160,
#  "'���ϸ�'": 161,
#  "'���ֹ�'": 162,
#  "'�ļ�'": 163,
#  "'ÿ��'": 164,
#  "'�濵'": 165,
#  "'�ͱݼ�'": 166,
#  "'ȫ��'": 167,
#  "'�ҽ�'": 168,
#  "'�ⱸ'": 169,
#  "'�ݵ�ü'": 170,
#  "'�ŵ�'": 171,
#  "'�ǽ��縮'": 172,
#  "'��ȹ'": 173,
#  "'�˻�'": 174,
#  "'�ٸ���'": 175,
#  "'��ä'": 176,
#  "'���ž�'": 177,
#  "'�ؼ�'": 178,
#  "'ũ��'": 179,
#  "'ö����'": 180,
#  "'ȥ��'": 181,
#  "'«��'": 182,
#  "'�ּ�'": 183,
#  "'âȣ'": 184,
#  "'": 185,
#  "'�ӿ�'": 186,
#  "'�ǽ���'": 187,
#  "'���۸���'": 188,
#  "'ƽ����'": 189,
#  "'�۾�'": 190,
#  "'����ŀ��'": 191,
#  "'�\ued7f'": 192,
#  "'û�ҳ�'": 193,
#  "'���\u0e70'": 194,
#  "'���α\u05f7�'": 195,
#  "'�ſ���'": 196,
#  "'���ϼ�'": 197,
#  "'�ʵ��л�'": 198,
#  "'�ǽ�����'": 199,
#  "'�\uee30����'": 200,
#  "'ȣ����'": 201,
#  "'�ӱ���'": 202,
#  "'�\u07bd�'": 203,
#  "'�ڹ�'": 204,
#  "'�ǿ\uee70'": 205,
#  "'��\ueff5'": 206,
#  "'����û'": 207,
#  "'��ũ��ʈ'": 208,
#  "'�ǹ���'": 209,
#  "'�ʿ�'": 210,
#  "'�ֹ���'": 211,
#  "'��ȯ'": 212,
#  "'��ġ�\uec33'": 213,
#  "'�ѱ�'": 214,
#  "'ȭ����'": 215,
#  "'�ȱ���'": 216,
#  "'�\uee70'": 217,
#  "'�õ�'": 218,
#  "'ħ��'": 219,
#  "'���б�'": 220,
#  "'�մ�'": 221,
#  "'�ܹ���'": 222,
#  "'��\u2e70'": 223,
#  "'�ѹ�'": 224,
#  "'ƚ��'": 225,
#  "'���屹'": 226,
#  "'����ȸ'": 227,
#  "'�ѻ�'": 228,
#  "'ü����'": 229,
#  "'��ѱ�'": 230,
#  "'�뼭��'": 231,
#  "'�ϻ���'": 232,
#  "'���̽�'": 233,
#  "'�ø�ʈ'": 234,
#  "'���̽�ũ��'": 235,
#  "'õ��'": 236,
#  "'�\u05f8�'": 237,
#  "'�ｺ'": 238,
#  "'�\uef7a'": 239,
#  "'�ʸ�'": 240,
#  "'�輱'": 241,
#  "'ħ'": 242,
#  "'�λ�'": 243,
#  "'�ۼ�'": 244,
#  "'�\uec33'": 245,
#  "'�ֺ����'": 246,
#  "'�ͻ�'": 247,
#  "'�̺�'": 248,
#  "'ī����'": 249,
#  "'û����'": 250,
#  "'�䰡'": 251,
#  "'�ӵ��'": 252,
#  "'cnc'": 253,
#  "'�߽�'": 254,
#  "'�ƶ���'": 255,
#  "'�ü���'": 256,
#  "'�鵵'": 257,
#  "'���̺�'": 258,
#  "'�լ�'": 259,
#  "'�ø�'": 260,
#  "'��۾���'": 261,
#  "'�ܱ���'": 262,
#  "'ǥ��'": 263,
#  "'�ǵ�'": 264,
#  "'����콺'": 265,
#  "'�ε����'": 266,
#  "'�ѱ���'": 267,
#  "'�ڽ�'": 268,
#  "'�ٹ�'": 269,
#  "'pvc'": 270,
#  "'�뱹'": 271,
#  "'led'": 272,
#  "'ʈ'": 273,
#  "'�һ�'": 274,
#  "'���ÿ�'": 275,
#  "'���κ���'": 276,
#  "'������ġ'": 277,
#  "'�н���'": 278,
#  "'�¾籤'": 279,
#  "'�߾���'": 280,
#  "'���ž���'": 281,
#  "'pcb'": 282,
#  "'ƽ'": 283,
#  "'�۱�'": 284,
#  "'��ó��'": 285,
#  "'�̳�'": 286,
#  "'�뷮'": 287,
#  "'�ʶ��\u05fd�'": 288,
#  "'�ʹ�'": 289,
#  "'���л�'": 290,
#  "'�꽺'": 291,
#  "'�뿪'": 292,
#  "'�ſ�'": 293,
#  "'õ'": 294,
#  "'����ũ'": 295,
#  "'�ҹ���'": 296,
#  "'����������'": 297,
#  "'s'": 298,
#  "'�ƿ��'": 299,
#  "'�i̇�'": 300,
#  "'�쵿'": 301,
#  "'�ӵ���'": 302,
#  "'�ķ��̵�'": 303,
#  "'�̱�'": 304,
#  "'��ī��'": 305,
#  "'�ռ�����'": 306,
#  "'�ʊ���'": 307,
#  "'���⸧'": 308,
#  "'�±�'": 309,
#  "'å'": 310,
#  "'�ֿ�'": 311,
#  "'�̹\u07fc�'": 312,
#  "'ĳ'": 313,
#  "'���ǽ�'": 314,
#  "'¥���'": 315,
#  "'ó����'": 316,
#  "'�簡'": 317,
#  "'��ü��'": 318,
#  "'�ĺ�'": 319,
#  "'ĳ�־�'": 320,
#  "'�ɸ�'": 321,
#  "'�ｺŭ��'": 322,
#  "'ƣ��'": 323,
#  "'�ƶ�����'": 324,
#  "'�̿���'": 325,
#  "'�߱���'": 326,
#  "'�����ĵ�'": 327,
#  "'ȳ��'": 328,
#  "'���ູ'": 329,
#  "'��ʈ��'": 330,
#  "'���ö�'": 331,
#  "'�����ͼ\uee35'": 332,
#  "'�����ܰ�'": 333,
#  "'�ǻΰ�'": 334,
#  "'�ľ�ÿ'": 335,
#  "'�帵ũ'": 336,
#  "'�����\uec33'": 337,
#  "'�μ\u2e70'": 338,
#  "'�۾���'": 339,
#  "'lpg'": 340,
#  "'�ܰ�'": 341,
#  "'¥��'": 342,
#  "'�μ��'": 343,
#  "'��ƿ'": 344,
#  "'�ϻ�'": 345,
#  "'�ܵ�'": 346,
#  "'�ؿ�'": 347,
#  "'�ҵ�'": 348,
#  "'�ý�'": 349,
#  "'��¡��'": 350,
#  "'���ɸ�'": 351,
#  "'��ż'": 352,
#  "'��ũ������'": 353,
#  "'��ƽ'": 354,
#  "'ħ����'": 355,
#  "'�а�'": 356,
#  "'ź��'": 357,
#  "'�����б�'": 358,
#  "'�ڼ�'": 359,
#  "'���⽺'": 360,
#  "'�⸧'": 361,
#  "'�κ�ǰ'": 362,
#  "'���ڱ�'": 363,
#  "'ÿ'": 364,
#  "'�ѿ���'": 365,
#  "'�̺����i̇�'": 366,
#  "'���ġų'": 367,
#  "'�縻'": 368,
#  "'�θ�'": 369,
#  "'�ֽ�'": 370,
#  "'��ų'": 371,
#  "'�̽�'": 372,
#  "'�ϼ�'": 373,
#  "'cctv'": 374,
#  "'��ô'": 375,
#  "'ǰ'": 376,
#  "'�δ��\uec33'": 377,
#  "'ȸȭ'": 378,
#  "'��۾�'": 379,
#  "'�ͽ�'": 380,
#  "'ī'": 381,
#  "'�ع�'": 382,
#  "'�ٵ�'": 383,
#  "'�ｎ'": 384,
#  "'�ڿ�'": 385,
#  "'ġ'": 386,
#  "'�ǹž�'": 387,
#  "'ʋ'": 388,
#  "'pp'": 389,
#  "'ũ����'": 390,
#  "'���ϼ���'": 391,
#  "'��\uec78��'": 392,
#  "'�а���'": 393,
#  "'�ű�'": 394,
#  "'���տ�'": 395,
#  "'���ǰ'": 396,
#  "'�ػ깰'": 397,
#  "'���\uec33'": 398,
#  "'ź����'": 399,
#  "'�ϰ�'": 400,
#  "'�뱸'": 401,
#  "'�з�'": 402,
#  "'�ޱ�'": 403,
#  "'å��'": 404,
#  "'��û��'": 405,
#  "'�ó���'": 406,
#  "'�ŷ�ó'": 407,
#  "'ʈ��'": 408,
#  "'�ͽ콺'": 409,
#  "'�ҹż�'": 410,
#  "'���θ�'": 411,
#  "'�����л�'": 412,
#  "'�佺ʈ'": 413,
#  "'ŀư'": 414,
#  "'a'": 415,
#  "'�ٴ�'": 416,
#  "'�ڷ�'": 417,
#  "'��ȸ��'": 418,
#  "'�ܱ�'": 419,
#  "'�ҿư�'": 420,
#  "'������ũ'": 421,
#  "'��ȿ'": 422,
#  "'�ҹ�ǰ'": 423,
#  "'p'": 424,
#  "'�ν�'": 425,
#  "'�ݰ�'": 426,
#  "'�ҿ�'": 427,
#  "'�ƴ�'": 428,
#  "'�ռ�'": 429,
#  "'�խ�'": 430,
#  "'�ι�����'": 431,
#  "'��ȭ�丮'": 432,
#  "'�˹̴�'": 433,
#  "'�ľ�'": 434,
#  "'�ݼ���'": 435,
#  "'��ȱ��'": 436,
#  "'���κ�'": 437,
#  "'��ÿ�'": 438,
#  "'�\uee6c'": 439,
#  "'��ȱ��ǰ'": 440,
#  "'�̺�ʈ'": 441,
#  "'���̾�'": 442,
#  "'���˹�'": 443,
#  "'�̻���'": 444,
#  "'��ġ����'": 445,
#  "'ư����'": 446,
#  "'�ȸ�'": 447,
#  "'�\u05fc�����'": 448,
#  "'�ܶ�'": 449,
#  "'�\uef2d'": 450,
#  "'�ع���'": 451,
#  "'���ǹ�'": 452,
#  "'�ż�'": 453,
#  "'��ű'": 454,
#  "'��ʃ���'": 455,
#  "'���ھ�'": 456,
#  "'û'": 457,
#  "'����ΰ�'": 458,
#  "'�µ�'": 459,
#  "'�ʒ�'": 460,
#  "'�ڵ��'": 461,
#  "'�尩'": 462,
#  "'���ⱸ��'": 463,
#  "'�ձ\u2d75'": 464,
#  "'�ξ�'": 465,
#  "'pe'": 466,
#  "'ŭ��'": 467,
#  "'m'": 468,
#  "'���ƺ�'": 469,
#  "'�ܺ�'": 470,
#  "'â'": 471,
#  "'���ӹ�'": 472,
#  "'���������\u05f8�'": 473,
#  "'��ŷ'": 474,
#  "'�̻�'": 475,
#  "'���п�'": 476,
#  "'�ֺ�'": 477,
#  "'ô'": 478,
#  "'õ�ֱ�'": 479,
#  "'mdf'": 480,
#  "'��쳪'": 481,
#  "'�̹߰�'": 482,
#  "'���ǻ�'": 483,
#  "'�ͱ���'": 484,
#  "'�߹��'": 485,
#  "'��å'": 486,
#  "'�ϱ�'": 487,
#  "'��ʽ���'": 488,
#  "'ģ�\U00075d78�'": 489,
#  "'ī�\u07b6�'": 490,
#  "'��ÿ��'": 491,
#  "'�ο�'": 492,
#  "'�α�'": 493,
#  "'tv'": 494,
#  "'�嵥��'": 495,
#  "'�繫���'": 496,
#  "'�ؾ�'": 497,
#  "'�μ�ǰ'": 498,
#  "'ķ��'": 499,
#  "'w'": 500,
#  "'�÷�'": 501,
#  "'�峭��'": 502,
#  "'ȭ����ǰ'": 503,
#  "'���̼�'": 504,
#  "'ż��'": 505,
#  "'�ް�'": 506,
#  "'�ε�'": 507,
#  "'���ܱ�'": 508,
#  "'ĩ'": 509,
#  "'�ž�'": 510,
#  "'�纹'": 511,
#  "'���i̇�ƽ'": 512,
#  "'���\uee35'": 513,
#  "'�ζ�'": 514,
#  "'�խ�ʈ'": 515,
#  "'�÷綱'": 516,
#  "'�\ued7f��'": 517,
#  "'�ڰ�'": 518,
#  "'�õ���'": 519,
#  "'���ǽ���'": 520,
#  "'�����̳�'": 521,
#  "'�ʊ�'": 522,
#  "'abs'": 523,
#  "'����ġ'": 524,
#  "'�\U000748b1��'": 525,
#  "'ǰ��'": 526,
#  "'�跮'": 527,
#  "'�ܸ���'": 528,
#  "'��ƽŀ'": 529,
#  "'�췰'": 530,
#  "'��ī'": 531,
#  "'�ӽ�'": 532,
#  "'�λ깰'": 533,
#  "'�\uee23��'": 534,
#  "'mct'": 535,
#  "'ʃ��'": 536,
#  "'sus'": 537,
#  "'�ߵ�����'": 538,
#  "'��꺹'": 539,
#  "'c'": 540,
#  "'�ߵ\uec73��'": 541,
#  "'��ĺ�'": 542,
#  "'�˵�'": 543,
#  "'���ڸ�'": 544,
#  "'���ķ�'": 545,
#  "'��ʋ'": 546,
#  "'�ó�'": 547,
#  "'�߷�'": 548,
#  "'�ŀ�'": 549,
#  "'�ܼ�'": 550,
#  "'�����ݰ�'": 551,
#  "'ǳ��'": 552,
#  "'�ֵ���'": 553,
#  "'ȩ������'": 554,
#  "'�㰡'": 555,
#  "'�౸'": 556,
#  "'���ι�'": 557,
#  "'�غ�'": 558,
#  "'���μ�'": 559,
#  "'��ǳ��'": 560,
#  "'�ᳪ��'": 561,
#  "'��ű�'": 562,
#  "'���ĺ�'": 563,
#  "'�д�'": 564,
#  "'��ǥ'": 565,
#  "'�ڴٸ�'": 566,
#  "'�뵿'": 567,
#  "'�ߵ�'": 568,
#  "'���\u07bc�'": 569,
#  "'�ʹ��'": 570,
#  "'�߾�'": 571,
#  "'â����'": 572,
#  "'�\u07fb�'": 573,
#  "'��ħ'": 574,
#  "'���ǿ�'": 575,
#  "'�뵿����'": 576,
#  "'�ʰ�'": 577,
#  "'ű��'": 578,
#  "'���ӱ�'": 579,
#  "'ǻ��'": 580,
#  "'���\u0378�'": 581,
#  "'���̿ø�'": 582,
#  "'ĵ'": 583,
#  "'�����ڽ�'": 584,
#  "'��繫��'": 585,
#  "'�ٷ�'": 586,
#  "'�¿���'": 587,
#  "'ķ'": 588,
#  "'�̷�'": 589,
#  "'�ٴ���'": 590,
#  "'����깰'": 591,
#  "'�÷�ʈ'": 592,
#  "'�\u0379̳�'": 593,
#  "'ģ��'": 594,
#  "'���ǳ�'": 595,
#  "'�ߴ�'": 596,
#  "'ʈ����'": 597,
#  "'ic'": 598,
#  "'�ɾ�'": 599,
#  "'ȧ'": 600,
#  "'��ⱸ'": 601,
#  "'�\u07b2ٹ�'": 602,
#  "'lcd'": 603,
#  "'ű'": 604,
#  "'�ϼ���'": 605,
#  "'h'": 606,
#  "'�ٷ���'": 607,
#  "'��ȥ'": 608,
#  "'�ᳪ����'": 609,
#  "'�װ�'": 610,
#  "'��õ'": 611,
#  "'�\u05f7���'": 612,
#  "'�\u2d75'": 613,
#  "'d'": 614,
#  "'�\u2d76'": 615,
#  "'�帱'": 616,
#  "'����ʈ��'": 617,
#  "'�\ued7fȭ'": 618,
#  "'�ͼ�'": 619,
#  "'��ݼ�'": 620,
#  "'�濪'": 621,
#  "'�þ�'": 622,
#  "'�ްլ�'": 623,
#  "'õ����'": 624,
#  "'�븮����'": 625,
#  "'�ҹӹ�'": 626,
#  "'ü'": 627,
#  "'õ�ͽ�'": 628,
#  "'�ձ�'": 629,
#  "'�ٸ�'": 630,
#  "'������ʈ'": 631,
#  "'�ȷ�'": 632,
#  "'�߸�'": 633,
#  "'�ѷ�'": 634,
#  "'�췹ź'": 635,
#  "'ĭ����'": 636,
#  "'���۶�'": 637,
#  "'�����ε�'": 638,
#  "'�ı�'": 639,
#  "'�ػ�'": 640,
#  "'���ڿ�'": 641,
#  "'ģȯ��'": 642,
#  "'�ߺ�����'": 643,
#  "'÷����'": 644,
#  "'�ڹ���'": 645,
#  "'�°���'": 646,
#  "'�й�'": 647,
#  "'���з�'": 648,
#  "'ȩ'": 649,
#  "'t'": 650,
#  "'ŭ����'": 651,
#  "'�ƿ�����'": 652,
#  "'�����ұ���'": 653,
#  "'�¾翭'": 654,
#  "'��ŀʈ'": 655,
#  "'�̵�'": 656,
#  "'�ٺ�ť'": 657,
#  "'�ҹ漭'": 658,
#  "'�ſ�ī��'": 659,
#  "'���ఴ'": 660,
#  "'ĳ����'": 661,
#  "'it'": 662,
#  "'���̾�ʈ'": 663,
#  "'�ּ���'": 664,
#  "'�ö�ʈ'": 665,
#  "'�ֿͽ�'": 666,
#  "'�ݷ�'": 667,
#  "'��һ���'": 668,
#  "'�۹�'": 669,
#  "'����ũ��'": 670,
#  "'�巹��'": 671,
#  "'ó'": 672,
#  "'�δ�'": 673,
#  "'���ұ���'": 674,
#  "'ȭ���'": 675,
#  "'����ü'": 676,
#  "'�ھ�'": 677,
#  "'�ϲݹ�'": 678,
#  "'���߰�'": 679,
#  "'�ǹż�'": 680,
#  "'pet'": 681,
#  "'�濵��'": 682,
#  "'���̵�'": 683,
#  "'�÷���'": 684,
#  "'�ź����'": 685,
#  "'��ȭå'": 686,
#  "'į'": 687,
#  "'��ű��'": 688,
#  "'�ҹż���'": 689,
#  "'��ó'": 690,
#  "'į��'": 691,
#  "'����ÿ'": 692,
#  "'�ķ�'": 693,
#  "'�ܿ���'": 694,
#  "'���尴'": 695,
#  "'�⽺'": 696,
#  "'�����̾�'": 697,
#  "'�¸�'": 698,
#  "'ŷ'": 699,
#  "'�ķ�ʈ'": 700,
#  "'���帶��'": 701,
#  "'���尡��'": 702,
#  "'�ҹ��'": 703,
#  "'�̼�ǰ'": 704,
#  "'�ų�'": 705,
#  "'ű����'": 706,
#  "'���ʋ'": 707,
#  "'�̴�'": 708,
#  "'�ڻ�'": 709,
#  "'ŀ����'": 710,
#  "'�\u05fd�ʈ'": 711,
#  "'ȿ��'": 712,
#  "'�����ʒ�'": 713,
#  "'����ö'": 714,
#  "'��â����'": 715,
#  "'��ǰ��'": 716,
#  "'�����̵�ġų'": 717,
#  "'ǫ��'": 718,
#  "'�巳'": 719,
#  "'�ɸ�ġ��'": 720,
#  "'��ȯ��'": 721,
#  "'âʋ'": 722,
#  "'�ڰ���'": 723,
#  "'���̷�'": 724,
#  "'�\u07b4�'": 725,
#  "'���͵�'": 726,
#  "'�ٽø�'": 727,
#  "'�ⱓ'": 728,
#  "'��ȹ��'": 729,
#  "'�ֿϰ�'": 730,
#  "'ȣ�̽�ʈ'": 731,
#  "'al'": 732,
#  "'�ʒθ�'": 733,
#  "'��붱'": 734,
#  "'�ȳ�'": 735,
#  "'����κ�'": 736,
#  "'������ƿ��'": 737,
#  "'�ǽù�'": 738,
#  "'�ŀ���'": 739,
#  "'�丶��'": 740,
#  "'��ƣ��'": 741,
#  "'ŀ'": 742,
#  "'�װ���'": 743,
#  "'�¾�'": 744,
#  "'�ܼ�ʈ'": 745,
#  "'«'": 746,
#  "'ȱ����'": 747,
#  "'�ź���'": 748,
#  "'��\uec21'": 749,
#  "'��ȳ'": 750,
#  "'���ؼ�'": 751,
#  "'�\u05fb�'": 752,
#  "'�뵿��'": 753,
#  "'���÷���'": 754,
#  "'�η�ġ��'": 755,
#  "'���۹�'": 756,
#  "'��ô��'": 757,
#  "'ǥ����'": 758,
#  "'�缺'": 759,
#  "'���̹�'": 760,
#  "'ǯ'": 761,
#  "'ä'": 762,
#  "'�ϸ�'": 763,
#  "'ȯ'": 764,
#  "'�ð���'": 765,
#  "'��ƽ��'": 766,
#  "'����ħ'": 767,
#  "'���ڿ���'": 768,
#  "'���̿�'": 769,
#  "'�ҷ�'": 770,
#  "'��ö��'": 771,
#  "'�긲'": 772,
#  "'ȭȯ'": 773,
#  "'�ó�����'": 774,
#  "'�˷�'": 775,
#  "'ʋ��'": 776,
#  "'nc'": 777,
#  "'����ȸ��'": 778,
#  "'ô��'": 779,
#  "'��ä��'": 780,
#  "'�õ���ǰ'": 781,
#  "'��ʈ��ũ'": 782,
#  "'��ʈ����'": 783,
#  "'�ӱ�'": 784,
#  "'�䱸��ʈ'": 785,
#  "'���̴�'": 786,
#  "'�۰�'": 787,
#  "'ǫ'": 788,
#  "'�\u05f6���'": 789,
#  "'¥'": 790,
#  "'�빫'": 791,
#  "'�\u07fcұ��'": 792,
#  "'���α\u05f7���'": 793,
#  "'�쿩��'": 794,
#  "'���ұ�'": 795,
#  "'���÷�'": 796,
#  "'�ʱ�'": 797,
#  "'�ݹ�'": 798,
#  "'ž'": 799,
#  "'���ΰ���'": 800,
#  "'�ڳ�'": 801,
#  "'��ħ��'": 802,
#  "'���峭'": 803,
#  "'�ݶ�'": 804,
#  "'��ȣȸ'": 805,
#  "'�ѵ�'": 806,
#  "'ȯǳ��'": 807,
#  "'�ӽô�'": 808,
#  "'�漮'": 809,
#  "'�¿�'": 810,
#  "'�ٹ�ȭ'": 811,
#  "'�\u07fc�'": 812,
#  "'�г�'": 813,
#  "'�ַ��'": 814,
#  "'ž��'": 815,
#  "'ȩ�м�'": 816,
#  "'����ȭ'": 817,
#  "'���콺'": 818,
#  "'�ſ���������'": 819,
#  "'���ε�'": 820,
#  "'�ӹ�ī��'": 821,
#  "'b'": 822,
#  "'�־߰�'": 823,
#  "'���۾�'": 824,
#  "'�ܿ�'": 825,
#  "'pb'": 826,
#  "'�\u07bdļ�'": 827,
#  "'�ŀ��'": 828,
#  "'�е�'": 829,
#  "'�\u05ff�'": 830,
#  "'���׳�'": 831,
#  "'���ż�'": 832,
#  "'���빮'": 833,
#  "'����ŀ'": 834,
#  "'�\u07b9�'": 835,
#  "'���ı�'": 836,
#  "'�\u2d75��'": 837,
#  "'�ƿ\ufdff'": 838,
#  "'�뼱'": 839,
#  "'oem'": 840,
#  "'�湮��'": 841,
#  "'�帵ũ��'": 842,
#  "'�ش�'": 843,
#  "'�̵���'": 844,
#  "'�ű�ܰ�'": 845,
#  "'ȫ����'": 846,
#  "'�ν���'": 847,
#  "'��ø'": 848,
#  "'���ҵ���'": 849,
#  "'�̹�'": 850,
#  "'�ϳ\u05fd�'": 851,
#  "'��ʈī'": 852,
#  "'���繫��'": 853,
#  "'�ӹ���'": 854,
#  "'smt'": 855,
#  "'�߲�ġ'": 856,
#  "'ȸ����'": 857,
#  "'�\u05f6�'": 858,
#  "'���ð�'": 859,
#  "'�ż纹'": 860,
#  "'�թ�'": 861,
#  "'��ǫ��'": 862,
#  "'�߿�'": 863,
#  "'�\u2e70'": 864,
#  "'�뱸��'": 865,
#  "'�ٶ�'": 866,
#  "'�纹��'": 867,
#  "'¡��'": 868,
#  "'��ƽ����'": 869,
#  "'�鼳��'": 870,
#  "'plc'": 871,
#  "'�̿밴'": 872,
#  "'�ǳ���'": 873,
#  "'�п�ǰ'": 874,
#  "'�\u07b8�'": 875,
#  "'�κ�����'": 876,
#  "'ź'": 877,
#  "'�ص�'": 878,
#  "'�����̵�'": 879,
#  "'�ٹ�����'": 880,
#  "'���ϻ�'": 881,
#  "'ż'": 882,
#  "'�ͳ�'": 883,
#  "'���ǵ�'": 884,
#  "'����ϰ���'": 885,
#  "'ȳ'": 886,
#  "'�̼���'": 887,
#  "'ʈ���̴�'": 888,
#  "'��δ�'": 889,
#  "'�ֻ�'": 890,
#  "'���̼���'": 891,
#  "'�л���'": 892,
#  "'��¦'": 893,
#  "'�輱��'": 894,
#  "'�\u05f7�'": 895,
#  "'ȸ�谨��'": 896,
#  "'����ź'": 897,
#  "'��ٸ�'": 898,
#  "'��ǫ'": 899,
#  "'���������'": 900,
#  "'ǻ'": 901,
#  "'as'": 902,
#  "'�ǿ�����'": 903,
#  "'�ͽ�¡'": 904,
#  "'���ޱ�'": 905,
#  "'����ȣ��'": 906,
#  "'�ñ�'": 907,
#  "'���丮'": 908,
#  "'�ȱ��'": 909,
#  "'�ը�'": 910,
#  "'üũ'": 911,
#  "'�ƽ���ʈ'": 912,
#  "'�系'": 913,
#  "'�ٹ���'": 914,
#  "'�ι���'": 915,
#  "'¡'": 916,
#  "'�ƹ���'": 917,
#  "'���㰡'": 918,
#  "'��輳��'": 919,
#  "'���������ʷ�'": 920,
#  "'�ϵ���'": 921,
#  "'frp'": 922,
#  "'�跮��'": 923,
#  "'���̳�'": 924,
#  "'�¼�'": 925,
#  "'��ž�'": 926,
#  "'��ȥ��'": 927,
#  "'ż����'": 928,
#  "'�����ŭ����'": 929,
#  "'�״ͻ�'": 930,
#  "'���纣��'": 931,
#  "'��ݾ�'": 932,
#  "'�ϵ����'": 933,
#  "'�ݿ�'": 934,
#  "'���尩'": 935,
#  "'ȱ'": 936,
#  "'�߿���'": 937,
#  "'�\u05f8���'": 938,
#  "'�ϲ��ǿ�ǰ'": 939,
#  "'�����ü�'": 940,
#  "'�ɽ�'": 941,
#  "'�߽���'": 942,
#  "'ȭ�չ�'": 943,
#  "'���ӵ�'": 944,
#  "'�ջ�'": 945,
#  "'e'": 946,
#  "'�ÿ���'": 947,
#  "'�ե�'": 948,
#  "'�귱ġ'": 949,
#  "'�뵵'": 950,
#  "'���̾ƹ��'": 951,
#  "'���⼱'": 952,
#  "'�ɰ�'": 953,
#  "'�ɷ�'": 954,
#  "'�ʼҹ�'": 955,
#  "'��⸧'": 956,
#  "'�縮'": 957,
#  "'�ݹ���'": 958,
#  "'ȩ�÷���'": 959,
#  "'���뱸'": 960,
#  "'����ä'": 961,
#  "'��ÿŷ'": 962,
#  "'�ɴٹ�'": 963,
#  "'�չ���'": 964,
#  "'���ڷ�'": 965,
#  "'���ڵ�'": 966,
#  "'�̹̿�'": 967,
#  "'�ҽ���'": 968,
#  "'�㺸'": 969,
#  "'ƽÿ��'": 970,
#  "'�峻'": 971,
#  "'���а���'": 972,
#  "'��\u07bc�'": 973,
#  "'�극��ũ'": 974,
#  "'�\u07b9б���'": 975,
#  "'cd'": 976,
#  "'��ȱ���'": 977,
#  "'�ڵ��ǹű�'": 978,
#  "'���κ��\uec33'": 979,
#  "'�ŵ���'": 980,
#  "'�ܽ�'": 981,
#  "'�˵���'": 982,
#  "'����ű'": 983,
#  "'�ݵ�'": 984,
#  "'�̼�����'": 985,
#  "'�밡��'": 986,
#  "'ƽ��'": 987,
#  "'���ű��'": 988,
#  "'���\uec73��'": 989,
#  "'pt'": 990,
#  "'�ٳѱ�'": 991,
#  "'���ٱ�'": 992,
#  "'ȣ'": 993,
#  "'�溸'": 994,
#  "'ư�깰'": 995,
#  "'��â��'": 996,
#  "'��ŀ'": 997,
#  "'÷��'": 998,
#  "'�ᱹ��'": 999,
#  "'�˹�'": 1000,
#  ...}

# %%
mecab = Mecab()
loaded_model = load_model('./ed200_hu128_ep10_bs128_sftmx_cc.h5')
max_len = 15
stopwords = pd.read_csv('./data/stopwords/stopwords.csv')
stopwords = list(stopwords['stopwords'])


def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  print(new_sentence)
  new_sentence = mecab.morphs(new_sentence) # 토큰화
  print(new_sentence)
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  print(new_sentence)
  encoded = tokenizer.texts_to_sequences(["{}".format(new_sentence)]) # 정수 인코딩
  print(encoded)
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  print(pad_new)
  label = loaded_model.predict(pad_new) # 예측
  print(label)
  print(le1.inverse_transform([label.argmax()])[0])
  print(digit_1_dict[le1.inverse_transform([label.argmax()])[0]])

# %%
sentiment_predict("카센터에서|자동차부분정비|타이어오일교환")
# Out:
# 카센터에서자동차부분정비타이어오일교환
# ['카센터', '에서', '자동차', '부분', '정비', '타이어', '오', '일', '교환']
# ['카센터', '에서', '자동차', '부분', '정비', '타이어', '오', '일', '교환']
# [[607, 40, 210, 264, 257, 931]]
# [[  0   0   0   0   0   0   0   0   0 607  40 210 264 257 931]]
# [[4.1274594e-05 5.7865927e-06 5.8053585e-04 1.6885963e-07 6.4396788e-04
#   6.3920606e-06 1.3797742e-05 9.4412053e-06 1.1517714e-06 7.4284566e-05
#   2.0624391e-06 2.2640058e-06 3.1059209e-04 4.9767538e-04 5.8264245e-04
#   1.5870976e-03 9.9255306e-01 3.3423206e-05 3.0544442e-03]]
# Q
# 보건업 및 사회복지 서비스업(86~87)

# %%
# y_test_1_predicted = pd.DataFrame(loaded_model.predict(X_test))
