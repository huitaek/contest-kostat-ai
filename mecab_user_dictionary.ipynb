# %% [markdown]
# # mecab 사용자 사전 추가기

# %%
import pandas as pd

# %% [markdown]
# * 일반적인 고유명사 추가
#
#         대우,,,,NNP,*,F,대우,*,*,*,*
#         구글,,,,NNP,*,T,구글,*,*,*,*
#
# * 인명 추가
#
#         까비,,,,NNP,인명,F,까비,*,*,*,*
#
# * 지명 추가
#
#         세종,,,,NNP,지명,T,세종,*,*,*,*
#         세종시,,,,NNP,지명,F,세종시,Compound,*,*,세종/NNP/지명+시/NNG/*

# %%
with open("C:/mecab/user-dic/custom.csv", 'r', encoding='utf-8') as f: 
    file_data = f.readlines()
file_data
# Out:
# []

# %%
file_data.append('입고,,,,NNG,*,F,입고,*,*,*,*,*\n')
file_data.append('사용자,,,,NNG,*,F,사용자,*,*,*,*,*\n')
file_data.append('아동화,,,,NNG,*,F,아동화,*,*,*,*,*\n')
file_data.append('도소매,,,,NNG,*,F,도소매,*,*,*,*,*\n')
file_data.append('가정용,,,,NNG,*,T,가정용,*,*,*,*,*\n')
file_data.append('발포,,,,NNG,*,F,발포,*,*,*,*,*\n')
file_data.append('성형,,,,NNG,*,T,성형,*,*,*,*,*\n')
file_data.append('손님,,,,NNG,*,T,손님,*,*,*,*,*\n')
file_data.append('화물자동차,,,,NNG,*,F,화물자동차,*,*,*,*,*\n')
file_data.append('재가,,,,NNG,*,F,재가,*,*,*,*,*\n')
file_data.append('식음료품,,,,NNG,*,T,식음료품,*,*,*,*,*\n')
file_data.append('카센타,,,,NNG,*,F,카센타,*,*,*,*,*\n')
file_data.append('화장품,,,,NNG,*,T,화장품,*,*,*,*,*\n')
file_data.append('할부,,,,NNG,*,F,할부,*,*,*,*,*\n')
file_data.append('뽑기,,,,NNG,*,F,뽑기,*,*,*,*,*\n')
file_data.append('다문화,,,,NNG,*,F,다문화,*,*,*,*,*\n')
file_data.append('AS,,,,NNG,*,F,AS,*,*,*,*,*\n')
file_data.append('네일샵,,,,NNG,*,T,네일샵,*,*,*,*,*\n')
file_data.append('도소매,,,,NNG,*,F,도소매,*,*,*,*,*\n')
file_data.append('컷트,,,,NNG,*,F,컷트,*,*,*,*,*\n')
file_data.append('파렛트,,,,NNG,*,F,파렛트,*,*,*,*,*\n')
file_data.append('퍼머,,,,NNG,*,F,퍼머,*,*,*,*,*\n')
file_data.append('비알콜,,,,NNG,*,T,비알콜,*,*,*,*,*\n')
file_data.append('충전소,,,,NNG,*,F,충전소,*,*,*,*,*\n')
file_data.append('태권도,,,,NNG,*,F,태권도,*,*,*,*,*\n')
with open("C:/mecab/user-dic/custom.csv", 'w', encoding='utf-8') as f: 
    for line in file_data: 
        f.write(line)

# %%
with open("C:/mecab/user-dic/nnp.csv", 'r', encoding='utf-8') as f: 
    file_data = f.readlines()
file_data
# Out:
# ['입고,,,,NNG,*,F,입고,*,*,*,*,*\n',
#  '사용자,,,,NNG,*,F,사용자,*,*,*,*,*\n',
#  '아동화,,,,NNG,*,F,아동화,*,*,*,*,*\n',
#  '도소매,,,,NNG,*,F,도소매,*,*,*,*,*\n',
#  '가정용,,,,NNG,*,T,가정용,*,*,*,*,*\n',
#  '발포,,,,NNG,*,F,발포,*,*,*,*,*\n',
#  '성형,,,,NNG,*,T,성형,*,*,*,*,*\n',
#  '손님,,,,NNG,*,T,손님,*,*,*,*,*\n',
#  '화물자동차,,,,NNG,*,F,화물자동차,*,*,*,*,*\n',
#  '재가,,,,NNG,*,F,재가,*,*,*,*,*\n',
#  '식음료품,,,,NNG,*,T,식음료품,*,*,*,*,*\n',
#  '카센타,,,,NNG,*,F,카센타,*,*,*,*,*\n',
#  '화장품,,,,NNG,*,T,화장품,*,*,*,*,*\n',
#  '할부,,,,NNG,*,F,할부,*,*,*,*,*\n',
#  '뽑기,,,,NNG,*,F,뽑기,*,*,*,*,*\n',
#  '다문화,,,,NNG,*,F,다문화,*,*,*,*,*\n',
#  'AS,,,,NNG,*,F,AS,*,*,*,*,*\n',
#  '네일샵,,,,NNG,*,T,네일샵,*,*,*,*,*\n',
#  '도소매,,,,NNG,*,F,도소매,*,*,*,*,*\n',
#  '컷트,,,,NNG,*,F,컷트,*,*,*,*,*\n',
#  '파렛트,,,,NNG,*,F,파렛트,*,*,*,*,*\n',
#  '퍼머,,,,NNG,*,F,퍼머,*,*,*,*,*\n',
#  '비알콜,,,,NNG,*,T,비알콜,*,*,*,*,*\n',
#  '충전소,,,,NNG,*,F,충전소,*,*,*,*,*\n',
#  '태권도,,,,NNG,*,F,태권도,*,*,*,*,*\n',
#  '입고,,,0,NNG,*,F,입고,*,*,*,*,*\n',
#  '사용자,,,0,NNG,*,F,사용자,*,*,*,*,*\n',
#  '아동화,,,0,NNG,*,F,아동화,*,*,*,*,*\n',
#  '도소매,,,0,NNG,*,F,도소매,*,*,*,*,*\n',
#  '가정용,,,0,NNG,*,T,가정용,*,*,*,*,*\n',
#  '발포,,,0,NNG,*,F,발포,*,*,*,*,*\n',
#  '성형,,,0,NNG,*,T,성형,*,*,*,*,*\n',
#  '손님,,,0,NNG,*,T,손님,*,*,*,*,*\n',
#  '화물자동차,,,0,NNG,*,F,화물자동차,*,*,*,*,*\n',
#  '재가,,,0,NNG,*,F,재가,*,*,*,*,*\n',
#  '식음료품,,,0,NNG,*,T,식음료품,*,*,*,*,*\n',
#  '카센타,,,0,NNG,*,F,카센타,*,*,*,*,*\n',
#  '화장품,,,0,NNG,*,T,화장품,*,*,*,*,*\n',
#  '할부,,,0,NNG,*,F,할부,*,*,*,*,*\n',
#  '뽑기,,,0,NNG,*,F,뽑기,*,*,*,*,*\n',
#  '다문화,,,0,NNG,*,F,다문화,*,*,*,*,*\n',
#  'AS,,,0,NNG,*,F,AS,*,*,*,*,*\n',
#  '네일샵,,,0,NNG,*,T,네일샵,*,*,*,*,*\n',
#  '도소매,,,0,NNG,*,F,도소매,*,*,*,*,*\n',
#  '컷트,,,0,NNG,*,F,컷트,*,*,*,*,*\n',
#  '파렛트,,,0,NNG,*,F,파렛트,*,*,*,*,*\n',
#  '퍼머,,,0,NNG,*,F,퍼머,*,*,*,*,*\n',
#  '비알콜,,,0,NNG,*,T,비알콜,*,*,*,*,*\n',
#  '충전소,,,0,NNG,*,F,충전소,*,*,*,*,*\n',
#  '태권도,,,0,NNG,*,F,태권도,*,*,*,*,*\n']

# %%
with open("C:/mecab/mecab-ko-dic/user-custom.csv", 'r', encoding='utf-8') as f: 
    file_data = f.readlines()
file_data
# Out:
# ['입고,1780,3533,3137,NNG,*,F,입고,*,*,*,*,*\n',
#  '사용자,1780,3533,2954,NNG,*,F,사용자,*,*,*,*,*\n',
#  '아동화,1780,3533,2639,NNG,*,F,아동화,*,*,*,*,*\n',
#  '도소매,1780,3533,2469,NNG,*,F,도소매,*,*,*,*,*\n',
#  '가정용,1780,3534,4099,NNG,*,T,가정용,*,*,*,*,*\n',
#  '발포,1780,3533,2455,NNG,*,F,발포,*,*,*,*,*\n',
#  '성형,1780,3534,1532,NNG,*,T,성형,*,*,*,*,*\n',
#  '손님,1780,3534,1471,NNG,*,T,손님,*,*,*,*,*\n',
#  '화물자동차,1780,3533,2639,NNG,*,F,화물자동차,*,*,*,*,*\n',
#  '재가,1780,3533,2673,NNG,*,F,재가,*,*,*,*,*\n',
#  '식음료품,1780,3534,2639,NNG,*,T,식음료품,*,*,*,*,*\n',
#  '카센타,1780,3533,2613,NNG,*,F,카센타,*,*,*,*,*\n',
#  '화장품,1780,3534,2552,NNG,*,T,화장품,*,*,*,*,*\n',
#  '할부,1780,3533,2640,NNG,*,F,할부,*,*,*,*,*\n',
#  '뽑기,1780,3533,988,NNG,*,F,뽑기,*,*,*,*,*\n',
#  '다문화,1780,3533,819,NNG,*,F,다문화,*,*,*,*,*\n',
#  'AS,1780,3533,2639,NNG,*,F,AS,*,*,*,*,*\n',
#  '네일샵,1780,3534,2639,NNG,*,T,네일샵,*,*,*,*,*\n',
#  '도소매,1780,3533,2469,NNG,*,F,도소매,*,*,*,*,*\n',
#  '컷트,1780,3533,2639,NNG,*,F,컷트,*,*,*,*,*\n',
#  '파렛트,1780,3533,2639,NNG,*,F,파렛트,*,*,*,*,*\n',
#  '퍼머,1780,3533,2631,NNG,*,F,퍼머,*,*,*,*,*\n',
#  '비알콜,1780,3534,2639,NNG,*,T,비알콜,*,*,*,*,*\n',
#  '충전소,1780,3533,2634,NNG,*,F,충전소,*,*,*,*,*\n',
#  '태권도,1780,3533,2639,NNG,*,F,태권도,*,*,*,*,*\n',
#  '입고,1780,3533,3137,NNG,*,F,입고,*,*,*,*,*\n',
#  '사용자,1780,3533,2954,NNG,*,F,사용자,*,*,*,*,*\n',
#  '아동화,1780,3533,2639,NNG,*,F,아동화,*,*,*,*,*\n',
#  '도소매,1780,3533,2469,NNG,*,F,도소매,*,*,*,*,*\n',
#  '가정용,1780,3534,4099,NNG,*,T,가정용,*,*,*,*,*\n',
#  '발포,1780,3533,2455,NNG,*,F,발포,*,*,*,*,*\n',
#  '성형,1780,3534,1532,NNG,*,T,성형,*,*,*,*,*\n',
#  '손님,1780,3534,1471,NNG,*,T,손님,*,*,*,*,*\n',
#  '화물자동차,1780,3533,2639,NNG,*,F,화물자동차,*,*,*,*,*\n',
#  '재가,1780,3533,2673,NNG,*,F,재가,*,*,*,*,*\n',
#  '식음료품,1780,3534,2639,NNG,*,T,식음료품,*,*,*,*,*\n',
#  '카센타,1780,3533,2613,NNG,*,F,카센타,*,*,*,*,*\n',
#  '화장품,1780,3534,2552,NNG,*,T,화장품,*,*,*,*,*\n',
#  '할부,1780,3533,2640,NNG,*,F,할부,*,*,*,*,*\n',
#  '뽑기,1780,3533,988,NNG,*,F,뽑기,*,*,*,*,*\n',
#  '다문화,1780,3533,819,NNG,*,F,다문화,*,*,*,*,*\n',
#  'AS,1780,3533,2639,NNG,*,F,AS,*,*,*,*,*\n',
#  '네일샵,1780,3534,2639,NNG,*,T,네일샵,*,*,*,*,*\n',
#  '도소매,1780,3533,2469,NNG,*,F,도소매,*,*,*,*,*\n',
#  '컷트,1780,3533,2639,NNG,*,F,컷트,*,*,*,*,*\n',
#  '파렛트,1780,3533,2639,NNG,*,F,파렛트,*,*,*,*,*\n',
#  '퍼머,1780,3533,2631,NNG,*,F,퍼머,*,*,*,*,*\n',
#  '비알콜,1780,3534,2639,NNG,*,T,비알콜,*,*,*,*,*\n',
#  '충전소,1780,3533,2634,NNG,*,F,충전소,*,*,*,*,*\n',
#  '태권도,1780,3533,2639,NNG,*,F,태권도,*,*,*,*,*\n']

# %%
file_data[0]='입고,1780,3533,0,NNG,*,F,입고,*,*,*,*,*\n'
file_data[1]='사용자,1780,3533,0,NNG,*,F,사용자,*,*,*,*,*\n'
file_data[2]='아동화,1780,3533,0,NNG,*,F,아동화,*,*,*,*,*\n'
file_data[3]='도소매,1780,3533,0,NNG,*,F,도소매,*,*,*,*,*\n'
file_data[4]='가정용,1780,3534,0,NNG,*,T,가정용,*,*,*,*,*\n'
file_data[5]='발포,1780,3533,0,NNG,*,F,발포,*,*,*,*,*\n'
file_data[6]='성형,1780,3534,0,NNG,*,T,성형,*,*,*,*,*\n'
file_data[7]= '손님,1780,3534,0,NNG,*,T,손님,*,*,*,*,*\n'
file_data[8]= '화물자동차,1780,3533,0,NNG,*,F,화물자동차,*,*,*,*,*\n'
file_data[9]= '재가,1780,3533,0,NNG,*,F,재가,*,*,*,*,*\n'
file_data[10]= '식음료품,1780,3534,0,NNG,*,T,식음료품,*,*,*,*,*\n'
file_data[11]= '카센타,1780,3533,0,NNG,*,F,카센타,*,*,*,*,*\n'
file_data[12]= '화장품,1780,3534,0,NNG,*,T,화장품,*,*,*,*,*\n'
file_data[13]= '할부,1780,3533,0,NNG,*,F,할부,*,*,*,*,*\n'
file_data[14]= '뽑기,1780,3533,0,NNG,*,F,뽑기,*,*,*,*,*\n'
file_data[15]= '다문화,1780,3533,0,NNG,*,F,다문화,*,*,*,*,*\n'
file_data[16]= 'AS,1780,3533,0,NNG,*,F,AS,*,*,*,*,*\n'
file_data[17]= '네일샵,1780,3534,0,NNG,*,T,네일샵,*,*,*,*,*\n'
file_data[18]= '도소매,1780,3533,0,NNG,*,F,도소매,*,*,*,*,*\n'
file_data[19]= '컷트,1780,3533,0,NNG,*,F,컷트,*,*,*,*,*\n'
file_data[20]= '파렛트,1780,3533,0,NNG,*,F,파렛트,*,*,*,*,*\n'
file_data[21]= '퍼머,1780,3533,0,NNG,*,F,퍼머,*,*,*,*,*\n'
file_data[22]= '비알콜,1780,3534,0,NNG,*,T,비알콜,*,*,*,*,*\n'
file_data[23]= '충전소,1780,3533,0,NNG,*,F,충전소,*,*,*,*,*\n'
file_data[24]= '태권도,1780,3533,0,NNG,*,F,태권도,*,*,*,*,*\n'

with open("C:/mecab/mecab-ko-dic/user-custom.csv", 'w', encoding='utf-8') as f: 
    for line in file_data: 
        f.write(line)

# %% [markdown]
# .\tools\compile-win.ps1

# %%
df
# Out:
#    단어  좌문맥ID  우문맥ID  가중치(단어비용) 품사태그 의미분류 종성유무  타입 첫 품사 마지막 품사 표현
# 0  까비    NaN    NaN        NaN  NNP   인명    F  까비    *      *  *

# %%
df
# Out:
#    단어  좌문맥ID  우문맥ID  가중치(단어비용) 품사태그 의미분류 종성유무  타입 첫 품사 마지막 품사 표현
# 0  까비    NaN    NaN        NaN  NNP   인명    F  까비    *      *  *

# %%
df = pd.read_csv("C:/mecab/user-dic/nnp.csv", names=['단어', '좌문맥ID', '우문맥ID', '가중치(단어비용)', '품사태그', '의미분류', '종성유무', '타입', '첫 품사', '마지막 품사', '표현'], index_col=False)
user_dictionary = pd.read_csv("./data/user_dictionary.csv",encoding='CP949', names=['단어', '좌문맥ID', '우문맥ID', '가중치(단어비용)', '품사태그', '의미분류', '종성유무', '타입', '첫 품사', '마지막 품사', '표현'], index_col=False)[1:]

# %%
df
# Out:
#    단어  좌문맥ID  우문맥ID  가중치(단어비용) 품사태그 의미분류 종성유무  타입 첫 품사 마지막 품사 표현
# 0  까비    NaN    NaN        NaN  NNP   인명    F  까비    *      *  *

# %%
user_dictionary
# Out:
#        단어 좌문맥ID 우문맥ID 가중치(단어비용) 품사태그 의미분류 종성유무     타입 첫 품사 마지막 품사 표현
# 1      입고   NaN   NaN       NaN  NNG    *    F     입고    *      *  *
# 2     사용자   NaN   NaN       NaN  NNG    *    F    사용자    *      *  *
# 3     아동화   NaN   NaN       NaN  NNG    *    F    아동화    *      *  *
# 4     도소매   NaN   NaN       NaN  NNG    *    F    도소매    *      *  *
# 5     가정용   NaN   NaN       NaN  NNG    *    T    가정용    *      *  *
# 6      발포   NaN   NaN       NaN  NNG    *    F     발포    *      *  *
# 7      성형   NaN   NaN       NaN  NNG    *    T     성형    *      *  *
# 8      손님   NaN   NaN       NaN  NNG    *    T     손님    *      *  *
# 9   화물자동차   NaN   NaN       NaN  NNG    *    F  화물자동차    *      *  *
# 10     재가   NaN   NaN       NaN  NNG    *    F     재가    *      *  *
# 11   식음료품   NaN   NaN       NaN  NNG    *    T   식음료품    *      *  *
# 12    카센타   NaN   NaN       NaN  NNG    *    F    카센타    *      *  *
# 13    화장품   NaN   NaN       NaN  NNG    *    T    화장품    *      *  *
# 14     할부   NaN   NaN       NaN  NNG    *    F     할부    *      *  *
# 15     뽑기   NaN   NaN       NaN  NNG    *    F     뽑기    *      *  *
# 16    다문화   NaN   NaN       NaN  NNG    *    F    다문화    *      *  *
# 17     AS   NaN   NaN       NaN  NNG    *    F     AS    *      *  *
# 18    네일샵   NaN   NaN       NaN  NNG    *    T    네일샵    *      *  *
# 19    점술인   NaN   NaN       NaN  NNG    *    T    점술인    *      *  *
# 20    장애인   NaN   NaN       NaN  NNG    *    T    장애인    *      *  *
# 21    도소매   NaN   NaN       NaN  NNG    *    F    도소매    *      *  *
# 22     컷트   NaN   NaN       NaN  NNG    *    F     컷트    *      *  *
# 23    파렛트   NaN   NaN       NaN  NNG    *    F    파렛트    *      *  *
# 24     퍼머   NaN   NaN       NaN  NNG    *    F     퍼머    *      *  *
# 25    비알콜   NaN   NaN       NaN  NNG    *    T    비알콜    *      *  *
# 26    충전소   NaN   NaN       NaN  NNG    *    F    충전소    *      *  *
# 27    태권도   NaN   NaN       NaN  NNG    *    F    태권도    *      *  *

# %%
df = pd.concat([df, user_dictionary], axis=0)[1:]

# %%
df
# Out:
#        단어 좌문맥ID 우문맥ID 가중치(단어비용) 품사태그 의미분류 종성유무     타입 첫 품사 마지막 품사 표현
# 1      입고   NaN   NaN       NaN  NNG    *    F     입고    *      *  *
# 2     사용자   NaN   NaN       NaN  NNG    *    F    사용자    *      *  *
# 3     아동화   NaN   NaN       NaN  NNG    *    F    아동화    *      *  *
# 4     도소매   NaN   NaN       NaN  NNG    *    F    도소매    *      *  *
# 5     가정용   NaN   NaN       NaN  NNG    *    T    가정용    *      *  *
# 6      발포   NaN   NaN       NaN  NNG    *    F     발포    *      *  *
# 7      성형   NaN   NaN       NaN  NNG    *    T     성형    *      *  *
# 8      손님   NaN   NaN       NaN  NNG    *    T     손님    *      *  *
# 9   화물자동차   NaN   NaN       NaN  NNG    *    F  화물자동차    *      *  *
# 10     재가   NaN   NaN       NaN  NNG    *    F     재가    *      *  *
# 11   식음료품   NaN   NaN       NaN  NNG    *    T   식음료품    *      *  *
# 12    카센타   NaN   NaN       NaN  NNG    *    F    카센타    *      *  *
# 13    화장품   NaN   NaN       NaN  NNG    *    T    화장품    *      *  *
# 14     할부   NaN   NaN       NaN  NNG    *    F     할부    *      *  *
# 15     뽑기   NaN   NaN       NaN  NNG    *    F     뽑기    *      *  *
# 16    다문화   NaN   NaN       NaN  NNG    *    F    다문화    *      *  *
# 17     AS   NaN   NaN       NaN  NNG    *    F     AS    *      *  *
# 18    네일샵   NaN   NaN       NaN  NNG    *    T    네일샵    *      *  *
# 19    점술인   NaN   NaN       NaN  NNG    *    T    점술인    *      *  *
# 20    장애인   NaN   NaN       NaN  NNG    *    T    장애인    *      *  *
# 21    도소매   NaN   NaN       NaN  NNG    *    F    도소매    *      *  *
# 22     컷트   NaN   NaN       NaN  NNG    *    F     컷트    *      *  *
# 23    파렛트   NaN   NaN       NaN  NNG    *    F    파렛트    *      *  *
# 24     퍼머   NaN   NaN       NaN  NNG    *    F     퍼머    *      *  *
# 25    비알콜   NaN   NaN       NaN  NNG    *    T    비알콜    *      *  *
# 26    충전소   NaN   NaN       NaN  NNG    *    F    충전소    *      *  *
# 27    태권도   NaN   NaN       NaN  NNG    *    F    태권도    *      *  *

# %%
df.to_csv('C:/mecab/user-dic/nnp.csv', header=False, index=False)

# %% [markdown]
# ! 관리자 권한으로 Windows Powershell 실행
#
# executionPolicy : restricted인 경우
# PS C:\mecab> Set-ExecutionPolicy Unrestricted
#
# PS C:\Windows\system32> cd C:\mecab
#
# PS C:\mecab> .\tools\add-userdic-win.ps1
