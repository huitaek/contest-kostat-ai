# %%
# 범용 라이브러리
import pandas as pd
import numpy as np
from tqdm import tqdm   # 진행상황 Progress Bar를 위한 tqdm library
import re               # Regular Expression
import pickle           # 토큰화된 단어목록의 인덱스를 저장, 불러오기 위해 사용
from sklearn.model_selection import train_test_split

# 토크나이징, 인코딩 관련 라이브러리
from eunjeon import Mecab
from collections import Counter
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 그래프 관련 라이브러리
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import platform

# 한글 폰트 설정
if (platform.system() == 'Windows'):
    plt.rc('font', family='Malgun Gothic')
else:
    plt.rc('font', family='AppleGothic')

# 음수(-)가 깨지는 현상 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

# %%
# 한국표준산업분류 딕셔너리 생성

cat_dic = pd.read_excel('./data/한국표준산업분류(10차)_국문.xlsx').iloc[2:,0:6]
cat_dic.rename(columns={'개정 분류체계(제10차 기준)':'대분류', 'Unnamed: 1':'대분류명', 
                        'Unnamed: 2': '중분류', 'Unnamed: 3': '중분류명',
                        'Unnamed: 4': '소분류', 'Unnamed: 5': '소분류명'}, inplace=True)

digit_1_df = cat_dic[['대분류', '대분류명']].dropna().reset_index(drop=True) # 대분류 'A' ~ 'U'
digit_2_df = cat_dic[['중분류', '중분류명']].dropna().reset_index(drop=True) # 중분류 1 ~ 99
digit_3_df = cat_dic[['소분류', '소분류명']].dropna().reset_index(drop=True) # 소분류 11 ~ 990

digit_1_dict = {}
for i in tqdm(range(len(digit_1_df))):
    digit_1_dict[digit_1_df.iloc[i]['대분류']] = digit_1_df.iloc[i]['대분류명']

digit_2_dict = {}
for i in tqdm(range(len(digit_2_df))):
    digit_2_dict[int(digit_2_df.iloc[i]['중분류'])] = digit_2_df.iloc[i]['중분류명']

digit_3_dict = {}
for i in tqdm(range(len(digit_3_df))):
    digit_3_dict[int(digit_3_df.iloc[i]['소분류'])] = digit_3_df.iloc[i]['소분류명']
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 5392.46it/s]
# 100%|██████████| 77/77 [00:00<00:00, 3766.93it/s]
# 100%|██████████| 232/232 [00:00<00:00, 2509.01it/s]

# %%
train['text_obj'] = train['text_obj'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '') # [ㄱ - ㅎ, ㅏ - ㅣ, 가 - 핳] 제외 제거
train['text_mthd'] = train['text_mthd'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '') # [ㄱ - ㅎ, ㅏ - ㅣ, 가 - 핳] 제외 제거
train['text_deal'] = train['text_deal'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '') # [ㄱ - ㅎ, ㅏ - ㅣ, 가 - 핳] 제외 제거

test['text_obj'] = test['text_obj'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '')
test['text_mthd'] = test['text_mthd'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '')
test['text_deal'] = test['text_deal'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '')
# Out:
# <ipython-input-4-7dd7fb717b2d>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train['text_obj'] = train['text_obj'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '') # [ㄱ - ㅎ, ㅏ - ㅣ, 가 - 핳] 제외 제거
# <ipython-input-4-7dd7fb717b2d>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   train['text_mthd'] = train['text_mthd'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '') # [ㄱ - ㅎ, ㅏ - ㅣ, 가 - 핳] 제외 제거
# <ipython-input-4-7dd7fb717b2d>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   train['text_deal'] = train['text_deal'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '') # [ㄱ - ㅎ, ㅏ - ㅣ, 가 - 핳] 제외 제거
# <ipython-input-4-7dd7fb717b2d>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   test['text_obj'] = test['text_obj'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '')
# <ipython-input-4-7dd7fb717b2d>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   test['text_mthd'] = test['text_mthd'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '')
# <ipython-input-4-7dd7fb717b2d>:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   test['text_deal'] = test['text_deal'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','').str.replace('^ +', '')

# %%
print('Train 데이터 결측치 제거 전:', len(train))
train.fillna("",inplace=True)
print('Train 데이터 결측치 제거 후:', len(train))

print('Test 데이터 결측치 제거 전:', len(test))
test.fillna("", inplace=True)
print('Test 데이터 결측치 제거 후:', len(test))
# Out:
# Train 데이터 결측치 제거 전: 1000000
# Train 데이터 결측치 제거 후: 1000000
# Test 데이터 결측치 제거 전: 100000
# Test 데이터 결측치 제거 후: 100000

# %%
# # 불용어 사전 불러오기

# stopwords = pd.read_csv("./data/stopwords/stopwords_1.csv", encoding='CP949')
# stopwords = stopwords['stopwords']
# print(len(stopwords))

# stopwords_2 = pd.read_table("./data/stopwords/stopwords_2.txt", names=['stopwords', '품사', 'ratio'])
# stopwords_2 = stopwords_2['stopwords']
# print(len(stopwords_2))

# # 불용어 사전 병합

# stopwords = pd.concat([stopwords, stopwords_2], axis=0)
# stopwords.drop_duplicates(inplace=True)
# stopwords.reset_index(inplace=True, drop=True)
# print(len(stopwords))

# # 불용어 사전 csv로 저장, 불러오기

# stopwords.to_csv("./data/stopwords/stopwords_concat.csv", index=False) 
stopwords = pd.read_csv("./data/stopwords/stopwords_concat.csv") 
stopwords = list(stopwords)
stopwords
# Out:
# ['stopwords']

# %%
# train 데이터 토크나이징

mecab_train_text_obj = []
mecab_train_text_mthd = []
mecab_train_text_deal = []

mecab = Mecab()

for sentence in tqdm(train['text_obj']): # 진행상황 Progress Bar를 위한 tqdm library
    tokenized_sentence = mecab.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_train_text_obj.append(stopwords_removed_sentence)

for sentence in tqdm(train['text_mthd']): # 진행상황 Progress Bar를 위한 tqdm library
    tokenized_sentence = mecab.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_train_text_mthd.append(stopwords_removed_sentence)

for sentence in tqdm(train['text_deal']): # 진행상황 Progress Bar를 위한 tqdm library
    tokenized_sentence = mecab.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_train_text_deal.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 1000000/1000000 [00:30<00:00, 33110.76it/s]
# 100%|██████████| 1000000/1000000 [00:24<00:00, 40565.81it/s]
# 100%|██████████| 1000000/1000000 [00:25<00:00, 39729.37it/s]

# %%
mecab_train_text_mthd
# Out:
# [['자동차', '부분', '정비'],
#  ['일반인', '을', '대상', '으로'],
#  ['공업', '용', '고무', '를', '가지', '고'],
#  ['일반', '소비자', '에게'],
#  ['보호자', '의', '위탁', '을', '받', '아'],
#  ['절삭', '용접'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['가공', '하', '여'],
#  ['일반', '공공', '행정'],
#  ['고객', '의뢰', '를', '받', '아'],
#  ['입', '고', '가공'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '을', '대상', '으로'],
#  ['학생', '및', '일반', '대사', '으로'],
#  ['고객', '요청', '으로'],
#  ['운송', '화물'],
#  ['일반인', '에게'],
#  ['일반', '고객', '을', '대상'],
#  ['가루', '로', '분쇄', '하', '여', '떡', '을', '쪄서'],
#  [],
#  ['무도', '시설', '을', '갖추', '고'],
#  ['일반인', '대상', '으로', '소매'],
#  ['빙수', '아이스크림', '커피', '디저트', '제공'],
#  ['일반', '소비자', '에게'],
#  ['절단', '가공'],
#  ['직원', '들', '대상'],
#  ['일반인', '대상'],
#  ['재료', '구입', '세미', '앗', '세이'],
#  ['소비자', '를', '대상', '으로'],
#  ['가공', '업체', '가공', '의뢰', '하', '여', '완제품', '수출'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['기독교', '계통', '종교', '활동'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '에게'],
#  ['기독교', '계통', '의', '종교', '활동'],
#  [],
#  ['영업장', '에서'],
#  ['고객', '의', '요청', '으로'],
#  ['주문', '에', '의한', '절삭', '가공'],
#  ['시각전달', '매체'],
#  ['판매'],
#  [],
#  [],
#  ['주유', '시설', '을', '갖추', '고'],
#  ['유치', '부초', '등', '대상'],
#  ['도', '소매'],
#  ['의뢰', '요청', '받', '아'],
#  ['다른', '사업체', '의', '요청', '에', '의해'],
#  ['학생', '일반인', '대상', '으로'],
#  ['접객', '시설', '갖추', '고'],
#  ['주문', '에', '의해'],
#  ['접객', '시설', '없이'],
#  ['기독교', '계통', '종교', '활동'],
#  [],
#  ['일반인', '대상', '으로'],
#  ['고객', '의', '요청', '으로'],
#  ['의뢰인', '을', '대리', '하', '여'],
#  ['주민', '의', '편의', '를', '위해'],
#  ['산업', '사용', '자', '에게'],
#  ['고객', '의뢰', '로'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['토목'],
#  ['고객', '을', '대상', '으로'],
#  ['일반인', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['내원', '환자', '를', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['고객', '을', '대상'],
#  ['관련', '업체', '요구', '에', '의해'],
#  ['접객', '시설', '없이'],
#  ['고객', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['시설', '을', '갖추', '고'],
#  ['재단', '봉제', '하', '여'],
#  ['일반', '소비자', '에게'],
#  ['각종', '제품', '을'],
#  ['일반', '소비자', '에게', '소매'],
#  ['고객', '대상', '으로'],
#  ['일반인', '대상'],
#  ['두', '발미', '용', '서비스'],
#  ['일반인', '대상', '으로', '소매'],
#  ['노래', '기기', '시설', '을', '갖추', '고'],
#  ['지방', '행정', '사무', '를', '집행'],
#  ['일반', '소비자', '에게'],
#  ['염장', '세척', '엮', '걸이'],
#  ['다른', '소매업자', '에게', '대량', '도매'],
#  ['일반', '소비자', '에게'],
#  ['일반', '소비자', '에게'],
#  ['두', '발미', '용', '서비스'],
#  ['소매업자', '에게', '도매'],
#  ['일반', '소비자', '에게'],
#  ['아파트', '를', '위해'],
#  ['간판', '의뢰', '를', '받', '아'],
#  ['외래', '환자', '를', '위주', '로'],
#  ['산업', '사용', '자', '에게'],
#  ['고객', '의', '요청', '으로'],
#  ['조립', '하', '여'],
#  ['일반', '고객', '을', '대상', '으로'],
#  ['계약', '의', '대리'],
#  ['고객', '의뢰', '를', '받', '아'],
#  ['고객', '을', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['전문', '적', '으로', '수리'],
#  ['절단', '가공'],
#  ['가정', '용', '직물', '제품', '소매점'],
#  ['의뢰', '를', '받', '아서'],
#  ['접객', '요원', '및', '무도', '시설', '없이'],
#  ['게스트', '하우스', '대상', '으로'],
#  ['소매'],
#  ['일반인', '대상'],
#  ['고객', '에게'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '고객', '대상', '으로'],
#  ['일반', '고객', '대상'],
#  ['고객', '의뢰', '를', '받', '아'],
#  ['유치원', '대상'],
#  ['고객', '의', '요청', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반', '소비자', '에게'],
#  ['일반인', '들', '을', '대상', '으로'],
#  ['도매'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반', '일상', '대로'],
#  ['깎', '고', '연마', '해서'],
#  ['고객', '의', '요청', '으로'],
#  ['자동차', '부속품', '을', '갖추', '고'],
#  ['신자', '들', '대상', '으로'],
#  ['일반인', '에게'],
#  ['접객', '요원', '및', '무도', '시설', '없이'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['일반인', '대상'],
#  ['일반', '고객', '대상', '으로'],
#  ['혼합', '발효'],
#  ['비', '주거', '용'],
#  ['일반인', '대상', '으로'],
#  ['공연', '연주'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['일반', '소비자', '대상'],
#  ['일반인', '을', '대상', '으로'],
#  [],
#  ['일반', '학생', '들', '대상', '으로'],
#  ['고객', '요구', '에', '따라'],
#  ['일반인', '대상', '으로'],
#  ['교육', '서비스업'],
#  ['일반인', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  [],
#  ['사업장', '에서'],
#  ['디지털', '음원'],
#  [],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '대상'],
#  ['고객', '요구', '에', '따라'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '들', '대상', '으로'],
#  ['빌딩', '입주자', '위해'],
#  ['학생', '일반인', '대상', '으로', '체력', '단련', '서비스', '제공'],
#  ['신자', '들', '대상', '으로'],
#  ['부품', '조립'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상'],
#  ['학생', '들', '대상', '으로'],
#  ['고객', '의', '요청', '으로'],
#  ['접객', '시설', '갖추', '고'],
#  ['일반인', '을', '대상', '으로'],
#  ['교육', '서비스업'],
#  ['고객', '요청', '으로'],
#  ['학생', '대상'],
#  ['고객', '의', '요청', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['일반인', '대상', '으로'],
#  [],
#  ['소비자', '에게'],
#  ['사업장', '에서'],
#  ['예초기', '엔진', '톱'],
#  ['고객', '의', '요청', '으로'],
#  ['일반', '소비자', '대상', '으로'],
#  ['불교', '계통', '종교', '활동'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['소매업자', '에게', '도매'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['두', '발', '미용', '서비스', '제공'],
#  ['사업장', '에서'],
#  ['아파트', '를', '위해'],
#  ['출동'],
#  ['검선', '니', '드보', '강'],
#  [],
#  ['고개', '의', '요청', '에', '따라'],
#  ['초등학생', '에게'],
#  ['일반', '소비자', '에게', '소매'],
#  ['고객', '의', '요청', '으로'],
#  ['일반', '소비자', '에게'],
#  ['각종', '조물', '재료', '를', '조합', '직조', '및', '기타', '방법', '으로'],
#  ['학생', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['접객', '시설', '갖추', '고'],
#  ['고객', '의', '요청', '으로', '인해'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['일반인', '대상'],
#  ['고객', '의', '요청', '으로'],
#  ['일반', '소비자', '에게'],
#  ['일반', '소비자', '에게', '소매'],
#  ['사업장', '에서'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['도매'],
#  ['음식점', '에서'],
#  ['구두', '수선'],
#  ['소매업자', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['기계', '장비', '설치', '공사'],
#  ['학생', '들', '을', '대상', '으로'],
#  ['고객', '의', '요청', '으로'],
#  ['모터사이클', '수리'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['고객', '요구', '에', '따라'],
#  ['조립', '가공'],
#  ['고객', '요청', '에', '의거'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '에게'],
#  ['초음파', '세척기', '음식물', '처리', '기', '도매업'],
#  ['잉크', '충전', '소', '에서'],
#  ['계약', '및', '중개'],
#  ['설계', '절단'],
#  ['일반인', '을', '대상', '으로'],
#  ['입', '고', '압출'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['프레스', '가공'],
#  ['도매'],
#  ['관할', '교육청', '인가', '를', '받', '아'],
#  ['숙박', '시설', '을', '갖추', '고'],
#  ['두', '발미', '용', '서비스'],
#  ['육상', '화물', '수송', '차량'],
#  ['일반', '소비자', '에게'],
#  ['사업장', '에서'],
#  ['도정'],
#  ['일반인', '대상'],
#  ['접객', '시설', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반', '고객', '들', '에게'],
#  ['기계', '가공'],
#  ['고객', '대상'],
#  ['보육', '료'],
#  ['일반', '소비자', '에게', '소매'],
#  ['고객', '의', '요청', '으로'],
#  ['수중', '공사', '전문직', '수행'],
#  ['소비자', '를', '대상', '으로'],
#  [],
#  ['외래', '환자', '대상', '으로'],
#  ['계약', '에', '의해'],
#  ['고객', '을', '대상', '으로'],
#  ['초중', '고생', '대상', '으로'],
#  ['조리', '하', '여'],
#  ['일반인', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '을', '대상', '으로'],
#  ['일반인', '들', '에게'],
#  ['소비자', '를', '대상', '으로'],
#  ['음식점', '에서'],
#  ['사업장', '에서'],
#  ['일반', '고객', '을', '대상', '으로'],
#  [],
#  ['산업'],
#  ['사업장', '에서'],
#  ['의뢰', '받', '아'],
#  ['외래', '환자', '위주', '로'],
#  ['고객', '대상'],
#  ['고객', '의', '요청', '으로'],
#  ['중고생', '을', '대상', '으로'],
#  ['고객', '의', '요청', '으로'],
#  ['고객', '의뢰', '에', '따라'],
#  ['도서관', '에서'],
#  ['일반인', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['직원', '대상', '으로'],
#  ['의뢰인', '을', '대리', '하', '여'],
#  ['일반인', '들', '을', '대상', '으로'],
#  ['기독교', '종교', '활동'],
#  ['음식점', '에서'],
#  ['기업인', '등', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['음식물', '을', '조리', '하', '여'],
#  ['접객', '요원', '및', '무도', '시설', '없이'],
#  ['계약', '및', '중개'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '을', '대상', '으로'],
#  ['절삭', '용접', '하', '여'],
#  ['원자재', '입', '고', '프레스', '생산'],
#  ['일반', '소비자', '들', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['두', '발미', '용', '서비스'],
#  [],
#  ['일반인', '대상'],
#  ['재', '가', '요양', '서비스', '기관'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['양파', '마늘', '배추', '등', '임대', '로', '받', '고'],
#  [],
#  ['절단', '봉합', '하', '여'],
#  [],
#  ['일반인', '을', '대상', '으로'],
#  ['아파트', '를'],
#  ['소매업자', '에게', '도매'],
#  ['관할', '구청', '의', '지원', '을', '받', '아'],
#  ['떡집'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['일반', '고객', '대상', '으로'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['소매업자', '에게'],
#  ['노인', '환자', '대상'],
#  ['관할', '교육청', '인가', '를', '받', '아'],
#  ['일반', '고객', '을', '대상', '으로'],
#  ['고객', '요구', '에', '따라'],
#  ['일반인', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['학생', '위주', '로'],
#  [],
#  ['기획', '디자인', '외주', '가', '공후'],
#  ['바닷물', '을', '태양열', '에', '증발', '시켜'],
#  ['부동산', '에서'],
#  ['접객', '요원', '을', '두', '고'],
#  ['학생', '에게'],
#  ['일반인', '대상'],
#  ['일반', '소비자', '에게'],
#  ['고객', '의뢰', '로'],
#  ['일반인', '대상'],
#  [],
#  ['도시', '두송', '아파트', '를'],
#  ['일반인', '대상'],
#  ['일반인', '대상', '으로'],
#  ['접객', '시설', '갖추', '고'],
#  ['스티커', '옵', '셋'],
#  ['고객', '의', '요청', '으로'],
#  ['전자', '상거래'],
#  ['일반인', '을', '대상', '으로'],
#  ['납품', '도매'],
#  ['일반', '소비자', '에게', '소매'],
#  ['점포', '에서'],
#  ['화물', '운송업자', '와', '화주', '간', '에'],
#  ['밧데리'],
#  ['향초', '도매'],
#  ['의뢰', '요청', '에', '따라'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['각', '매장', '대상'],
#  ['마을', '주민', '대상'],
#  ['접객', '요원', '을', '두', '고'],
#  ['무도', '시설', '을', '갖추', '고'],
#  ['일반', '고객', '의', '의뢰', '를', '받', '아'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반', '소비자', '를', '대상', '으로', '소매'],
#  ['고객', '의', '요청', '으로'],
#  ['일반', '소비자', '에게', '소매'],
#  ['고객', '의', '요청', '으로'],
#  ['일반', '소비자', '에게'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['의뢰인', '을', '대리', '하', '여'],
#  ['절삭', '가공', '하', '여'],
#  ['일반', '소비자', '들', '에게'],
#  ['의뢰', '받', '아'],
#  ['사업장', '에서'],
#  ['중', '탕기', '를', '갖추', '고'],
#  ['검량', '검정'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '없이'],
#  ['일반인', '대상', '으로'],
#  ['소매업자', '에게', '도매'],
#  ['고객', '의', '요청', '으로'],
#  ['두', '발미', '용', '서비스', '제공'],
#  ['의뢰인', '을', '대리', '하', '여'],
#  ['각종', '주류'],
#  ['소매업자', '에게', '도매'],
#  ['고객', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['위탁', '개발'],
#  ['입주민', '을', '위하', '여'],
#  ['소매업자', '대상', '으로'],
#  ['아파트', '를'],
#  ['보호자', '로', '위탁', '받', '아'],
#  ['고객', '요구', '에', '따라'],
#  ['계약', '및', '중개', '등', '을', '통해', '수수료', '받', '음'],
#  ['일반인', '을', '대상', '으로'],
#  ['보험', '사업자', '를', '대리', '알선'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '요원', '및', '무도', '시설', '없이'],
#  ['가정', '이나', '사업체', '를', '방문', '하', '여'],
#  ['일반', '소비자', '에게'],
#  ['압출', '성형'],
#  ['계약', '및', '중개'],
#  ['일반인', '을', '대상', '으로'],
#  ['학생', '을', '대상', '으로'],
#  ['중학생', '을', '대상', '으로'],
#  ['주문', '들어오', '면'],
#  ['학생', '을', '대상', '으로'],
#  ['일반', '소비자', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['기독교', '계통', '종교', '활동'],
#  ['매장', '에서'],
#  ['일반인', '을', '대상', '으로'],
#  [],
#  ['일반인', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '을', '대상', '으로'],
#  ['조계사', '불교', '교육', '을', '위주', '로'],
#  ['계약', '에', '의거', '부동산', '중개'],
#  ['고객', '의', '요청', '에', '의해'],
#  ['접객', '시설', '을', '갖추', '고'],
#  [],
#  ['절단', '가공'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '의', '요청', '으로'],
#  ['소매'],
#  ['영업', '하', '여'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상'],
#  ['임대', '를', '통하', '여'],
#  ['일반', '소비자', '에게'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['일반', '소비자', '에게', '소매'],
#  ['고객', '을', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['계약', '의뢰', '에', '의해'],
#  ['원자재', '확보', '절단', '도면', '대로'],
#  ['학생', '위주', '로'],
#  ['고객', '요구', '에', '따라'],
#  ['일반인', '대상'],
#  ['감', '을', '깍', '아', '건조', '시켜'],
#  ['민족', '종교', '단체'],
#  ['일반', '인상', '대로'],
#  ['도매', '및', '소매업'],
#  ['일반인', '들', '에게'],
#  ['음식', '서비스'],
#  ['입반', '소비자', '에게'],
#  ['일반인', '을', '대상', '으로'],
#  ['소매'],
#  ['일반인', '을', '대상', '으로'],
#  ['금속', '제품', '이용'],
#  ['체인', '계약', '을', '체결', '하', '여'],
#  ['일반', '소비자', '에게'],
#  ['절단', '가공', '하', '여'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '소비자', '에게', '소매'],
#  ['절단', '가공'],
#  ['컷팅'],
#  ['매장', '에서'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '의뢰', '를', '받', '아서'],
#  ['승객', '운송'],
#  ['기독교', '계통', '의', '종교', '활동'],
#  ['고객', '의', '요청', '으로'],
#  ['일반', '소비자', '에게', '도매'],
#  ['매장', '에서'],
#  ['일반인', '을', '대상', '으로'],
#  ['접객', '시설', '갖추', '고'],
#  [],
#  ['일반', '신도', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['외래', '환자', '위주'],
#  ['고객', '의', '요청', '으로'],
#  ['의료', '용', '기기', '를'],
#  ['일반', '고객', '에게'],
#  ['소매'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['접객', '시설', '없이'],
#  ['해체', '선별', '및', '분쇄'],
#  ['무대', '시설', '과', '접객', '시설', '을', '갖추', '고'],
#  ['절단', '접하', '여'],
#  ['매장', '에서'],
#  ['고객', '을', '대상', '으로'],
#  ['일반', '소비자', '에게', '소매'],
#  ['전자', '상거래'],
#  ['일반인', '대상'],
#  ['고객', '의', '요청', '으로'],
#  ['소비자', '를', '대상', '으로'],
#  ['소비자', '를', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['외래', '환자', '를', '위주', '로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '고객', '대상'],
#  ['일반', '소비자', '에게'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['도매업자', '에게'],
#  ['공연'],
#  ['건조'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['소비자', '에게'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['의뢰', '받', '아'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['임대', '를', '통하', '여'],
#  ['일반인', '을', '대상', '으로'],
#  ['영업장', '에서', '사료', '를', '가지', '고'],
#  ['일반', '소비자', '에게'],
#  ['일반인', '을', '대상', '으로'],
#  ['소매'],
#  ['각종', '주류'],
#  ['산업', '사용', '자', '대상', '으로'],
#  ['고객', '의', '요구', '에', '의해'],
#  ['일반인', '대상', '으로'],
#  ['프레스', '가공'],
#  ['조립', '및', '용접'],
#  ['도정'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['의뢰', '요청', '으로'],
#  ['일반', '고객', '들', '에게'],
#  ['직원', '들', '에게'],
#  ['사무실', '이', '용자', '를', '위해'],
#  ['학생', '을', '대상', '으로'],
#  ['다른', '소매업자', '에게'],
#  ['다른', '업체', '에게', '도매'],
#  ['일반', '소비자', '들', '을', '대상', '으로'],
#  ['일반인', '대상', '으로'],
#  ['고객', '의', '요청', '으로'],
#  ['일반', '고객', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반', '수강', '생', '에게'],
#  ['가공', '업체', '가공', '의뢰', '후'],
#  ['일반인', '을', '대상', '으로'],
#  [],
#  ['일반', '소비자', '에게'],
#  ['계약', '에', '의해'],
#  ['일반인', '대상', '으로'],
#  ['금은방', '에서'],
#  ['일반인', '을', '대상', '으로'],
#  ['고객', '의뢰', '를', '받', '아'],
#  ['일반인', '대상'],
#  ['사업장', '에서'],
#  ['병원', '에서'],
#  ['오골계', '를', '발굴', '하', '여'],
#  ['인문', '계', '교육'],
#  ['원자재', '입', '고', '절단'],
#  ['다른', '소매', '자', '에게'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반', '소비자', '를', '대상', '으로', '소매', '미만'],
#  ['방', '과', '후강사', '에게'],
#  ['절곡', '절단', '용접'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['사업장', '에서'],
#  ['승무원', '관리'],
#  ['고객', '을', '대상'],
#  [],
#  ['고객', '의', '의뢰', '에', '따라'],
#  ['건물', '이나', '구조물'],
#  ['고객', '의', '요청', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['다른', '소매업자', '에게', '도매'],
#  [],
#  ['산업', '사용', '자', '에게'],
#  ['외래', '환자', '위주', '로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  [],
#  ['일반', '고객', '에게'],
#  ['소비자', '를', '대상', '으로'],
#  ['일반', '고객', '에게'],
#  ['입주자', '를', '위하', '여'],
#  ['일반', '소비자', '에게'],
#  ['장의사', '에서'],
#  ['고객', '의', '요구', '에', '따라'],
#  ['일반', '고객', '대상', '으로'],
#  ['일반', '소비자', '에게', '소매'],
#  ['고객', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['절단', '조립'],
#  ['일반', '학생', '대상'],
#  ['소비자', '를', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '의', '요구', '에', '따라'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['교육', '서비스업'],
#  ['주차장', '관리'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '의', '요청', '으로'],
#  ['바닷물', '을', '태양열', '에', '증발', '시켜'],
#  ['일반', '고객', '대상', '으로'],
#  ['중개', '대행', '서비스'],
#  ['방', '과', '후', '교사', '자격증'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['인문', '계', '교육'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상', '으로'],
#  ['일반인', '대상', '으로'],
#  ['일반인', '대상'],
#  ['매매', '임대', '서비스'],
#  ['일반', '소비자', '에게', '소매'],
#  ['고객', '의', '요청', '으로'],
#  ['고객', '의', '요청', '으로'],
#  ['수리', '하', '여'],
#  ['접객', '요원', '및', '무도', '시설', '없이'],
#  ['보호자', '의', '위탁', '을', '받', '아'],
#  ['일반', '수강', '생', '에게'],
#  ['두', '발미', '용', '서비스', '제공'],
#  ['사용', '자', '요청', '에', '따라'],
#  ['고객', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '을', '대상'],
#  ['전자', '상거래'],
#  ['학생', '을', '위주', '로'],
#  ['고객', '의', '요청', '으로'],
#  ['가공', '업체', '에', '가공', '염색', '의뢰', '하', '여', '완제품', '도매'],
#  ['부동산', '중개'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['고객', '의', '의뢰', '에', '의한'],
#  ['열람', '서비스'],
#  ['전자', '상거래', '방식', '으로'],
#  ['가열', '추출'],
#  ['소매업자', '에게', '도매'],
#  ['의뢰', '을', '받', '아'],
#  ['관리', '하', '는'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '대상', '금융', '서비스'],
#  ['고객', '의뢰', '로'],
#  ['일반', '소비자', '대상'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['생지', '입', '고', '가공', '염색', '기능', '성', '코팅', '외주'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['철물', '도매'],
#  ['고객', '의', '요청', '으로'],
#  ['일반', '소비자', '대상'],
#  ['일반', '소비자', '에게'],
#  ['건조', '및', '가공', '하', '여'],
#  ['재생', '가능', '한', '고물', '및', '스크랩', '을', '수집', '하', '여'],
#  ['빙수', '아이스크림', '커피', '디저트', '제공'],
#  ['학생', '들', '에게'],
#  ['고객', '대상'],
#  ['고객', '의', '요청', '으로'],
#  ['숙박', '시설', '을', '갖추', '고'],
#  ['중개'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['외래', '환자', '위주', '로'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['두', '발미', '용', '서비스', '제공'],
#  ['건설', '현장', '에'],
#  ['체인', '계약', '을', '체결', '하', '여'],
#  ['일반', '소비자', '에게', '소매'],
#  ['조립', '밴', '딩'],
#  ['일반', '소비자', '에게', '소매'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['금은방', '에서'],
#  [],
#  ['소비자', '에게', '소매'],
#  ['일반인', '대상'],
#  ['고객', '의', '요구', '에', '의해'],
#  ['보호자', '로', '위탁', '받', '아'],
#  ['자동차', '의', '특정', '부분', '을'],
#  ['외래', '환자', '를', '위주', '로', '의료', '활동'],
#  ['소매업자', '대상', '으로'],
#  ['체인', '계약', '을', '체결', '하', '여'],
#  ['사무실', '이', '용자', '를', '위해'],
#  ['일반인', '을', '대상', '으로'],
#  ['보호자', '로', '위탁', '받', '아'],
#  ['고객', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '을', '대상', '으로'],
#  ['교육', '기관'],
#  ['고객', '에게'],
#  [],
#  ['수수료', '받', '고'],
#  ['일반', '고객', '에게'],
#  ['일반인', '대상'],
#  ['일반인', '을', '대상', '으로'],
#  ['고객', '의', '요청', '으로'],
#  ['학생', '위', '주의'],
#  ['일반인', '대상'],
#  ['점포', '에서'],
#  ['일반인', '을', '대상', '으로'],
#  ['산업', '사용', '자', '에게'],
#  ['일반인', '대상', '으로'],
#  ['원사', '가공', '정경'],
#  ['고객', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['입', '고', '파이프', '시공'],
#  ['룸서비스', '없이'],
#  ['절삭', '용접', '하', '여'],
#  ['재단'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['조리', '하', '여'],
#  ['일반', '소비자', '에게', '소매'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을'],
#  ['고객', '의', '요청', '에', '따라', '배선', '을', '이용', '하', '여'],
#  ['일반인', '을', '대상', '으로'],
#  ['전자', '상거래'],
#  ['학생', '들', '을', '상대', '로'],
#  ['구직', '구인', '창업', '가'],
#  ['고객', '요청', '으로'],
#  ['일반', '소비자', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '의뢰', '를', '받', '아'],
#  ['중학생', '대상', '으로'],
#  ['접객', '요원', '없이'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '을', '대상'],
#  ['소재', '입', '고', '연마', '가공'],
#  ['기독교', '계통', '종교', '활동'],
#  ['접객', '요원', '없이'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상', '으로'],
#  ['소매'],
#  ['소매상', '에게'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['기계', '가공', '하', '여'],
#  ['학생'],
#  ['소재', '입', '고', '조립'],
#  ['사무실', '이', '용자', '를', '위해'],
#  ['일반인', '대상', '으로'],
#  ['차', '배합', '차', '배합'],
#  ['방', '과', '후', '교육', '콘텐츠'],
#  ['절단', '조립', '하', '여'],
#  ['입주자', '를', '위해'],
#  ['직조'],
#  ['일반', '소비자', '에게', '소매'],
#  ['학생'],
#  ['볼링장', '시설', '을', '갖추', '고'],
#  ['초중', '고생', '대상'],
#  ['일반인', '을', '대상', '으로'],
#  ['학생', '일반인', '등', '에게', '체력', '단련'],
#  ['일반인', '들', '에게'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반', '소비자', '에게'],
#  ['아파트', '입주자', '를', '위하', '여'],
#  ['산업', '환경'],
#  ['주문', '디자인'],
#  ['학생', '들', '을', '위주', '로', '교육'],
#  ['외가', '공'],
#  ['조립', '수지', '굳히', '는', '작업'],
#  ['주문'],
#  ['도매업자', '에게'],
#  ['일반', '고객', '대상', '으로'],
#  ['일반인', '에게'],
#  ['사용', '자', '에게'],
#  ['목재'],
#  ['고객', '을', '대상', '으로'],
#  ['재', '가', '요양', '서비스', '기관'],
#  ['시설', '을', '갖추', '고'],
#  ['절단', '가공'],
#  ['일반', '소비자', '대상'],
#  ['매장', '에서'],
#  ['부품', '입', '고', '조립'],
#  ['일반', '소비자', '에게', '소매'],
#  ['무도', '시설', '을', '갖추', '고'],
#  ['경영', '컨설팅'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['입', '고', '파이프', '시공'],
#  ['마을', '주민', '들', '을', '위주', '로', '진료'],
#  ['일반인', '을', '대상', '으로'],
#  ['건물', '주', '의', '요청'],
#  ['고객', '을', '대상', '으로'],
#  ['일반인', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['업체', '의뢰', '받', '아'],
#  ['계약', '및', '중개'],
#  ['학생', '대상'],
#  ['플라스틱', '재료', '구입', '재료', '투입', '사출', '후', '가공', '스프레이', '작업', '검사'],
#  ['일반인', '대상', '으로'],
#  ['도서관', '에서'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['각종', '지물', '류'],
#  ['방문', '복지', '서비스', '가', '필요', '한', '노인', '을', '대상', '으로'],
#  ['기독교', '계통', '의', '종교', '활동'],
#  ['일반인', '에게'],
#  ['고객', '의', '요청', '으로'],
#  ['의뢰', '을', '받', '아'],
#  [],
#  ['고객', '을', '대상', '으로'],
#  ['소비자', '에게'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['입', '고', '가공'],
#  ['부동산', '자문', '및', '중개업'],
#  ['일반인', '을', '대상', '으로'],
#  ['고객', '의', '요청', '으로'],
#  ['사용', '자', '요청', '으로'],
#  ['보빈', '을', '깎', '고', '코일', '에', '감', '아서', '코아', '끼움'],
#  ['일반인', '대상'],
#  ['일반인', '에게'],
#  ['일반인', '을', '대상'],
#  ['일반인', '을', '대상', '으로'],
#  ['직원', '들', '의', '권익', '보호', '실현'],
#  ['일반인', '에게'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['건어물'],
#  ['일반', '학생', '대상'],
#  ['고객', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '소비자', '르', '대상', '으로'],
#  ['불교', '계통', '종교', '활동'],
#  ['고객', '에게'],
#  ['고객', '의뢰', '를', '받', '아'],
#  ['학생', '을', '대상', '으로'],
#  ['중학생', '을', '대상', '으로'],
#  ['유아'],
#  ['일반', '소비자', '에게', '소매'],
#  ['일반인', '을', '대상', '으로'],
#  ['상가', '관리', '서비스'],
#  ['고객', '의', '요청', '으로'],
#  ['일반', '소비자', '에게'],
#  ['소매업자', '에게', '도매'],
#  ['도', '소매'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['밀링', '가공', '하', '여'],
#  ['일반', '소비자', '에게'],
#  [],
#  ['일반', '소비자', '에게'],
#  ['일반', '소비자', '에게'],
#  ['두', '발미', '용', '서비스', '제공'],
#  ['일반인', '을', '대상', '으로'],
#  ['유치원', '대상'],
#  ['운송', '자', '와', '화주', '간'],
#  ['보호자', '로', '위탁', '받', '아'],
#  ['철근', '으로'],
#  ['일반', '고객', '대상', '으로'],
#  ['가마', '에', '구워서'],
#  ['조리', '하', '여'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반', '고객', '대상', '으로'],
#  ['기독교', '계통', '종교', '활동'],
#  ['일반', '고객', '의', '의뢰', '를', '받', '아'],
#  ['일반인', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['계약', '의', '의거'],
#  ['학원', '에서'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '을', '대상', '으로'],
#  ['음식', '을', '조리', '하', '여'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['각', '대리점', '에', '냉장', '보관'],
#  ['일반', '소비자', '대상'],
#  ['일반인', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['판매', '대상', '에게'],
#  ['시설', '을', '갖추', '고'],
#  ['일반', '소비자', '에게'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '대상'],
#  ['일반', '소비자', '에게'],
#  [],
#  ['철물', '비전', '기식', '난방'],
#  ['소매'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['의뢰인', '을', '대리', '하', '여'],
#  ['채취', '및', '사석'],
#  ['일반인'],
#  ['수작업'],
#  ['고객', '의뢰', '받', '아'],
#  ['바닷물', '을', '태양열', '에', '증발', '시켜'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '에게'],
#  ['체인', '계약', '을', '위하', '여'],
#  ['학원', '에서'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['컨', '셔', '팅'],
#  ['원재료', '구입', '절단', '용접'],
#  ['고객', '의뢰', '를', '받', '아'],
#  ['시각', '장애', '인', '대상'],
#  ['일반', '소비자', '에게'],
#  ['수지', '혼합'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '에게'],
#  ['일반', '고객', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['방문', '고객', '대상'],
#  ['골프', '연습장'],
#  ['주문', '맡', '아'],
#  [],
#  [],
#  ['학생', '을', '대상', '으로'],
#  ['화물', '운송업자', '와', '화주', '간', '에'],
#  ['일반인', '대상', '으로'],
#  ['고객', '의', '요청', '으로'],
#  ['재단', '봉제', '하', '여'],
#  ['신도', '들', '대상'],
#  ['접객', '시설', '없이'],
#  ['일반인', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '의', '요청', '으로'],
#  ['관할', '지녁', '교육청', '의', '인가', '를', '받', '아'],
#  ['대한', '조계종', '종교', '활동'],
#  ['상가', '를', '대상', '으로'],
#  ['농', '경학', '연구', '를', '위해'],
#  ['일반인', '을', '대상', '으로'],
#  ['관련', '업체', '요구', '에', '의해'],
#  ['수거'],
#  ['학생', '일반인', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['소매업자', '에게'],
#  [],
#  ['일반인', '을', '대상', '으로'],
#  ['재생', '가능', '한', '고물', '수집'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['일반', '소비자', '에게'],
#  ['일반인', '을', '대상', '으로'],
#  ['고객', '대상'],
#  [],
#  ['농민', '을', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['철판'],
#  ['사출', '금형'],
#  ['건물', '구축물', '및', '구조물', '등'],
#  ['차량', '을', '구난', '견인'],
#  ['접객', '시설', '갖추', '고'],
#  ['정미소'],
#  ['고객', '요구', '에', '따라'],
#  ['관련', '업체', '요구', '에', '의해'],
#  ['중개'],
#  ['유치원', '등', '에'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['소개', '수수', '로', '받', '고'],
#  ['고객', '의', '요구', '에', '의해'],
#  ['시각', '장애', '인', '을', '대상', '으로', '로'],
#  ['일반인', '을', '대상', '으로'],
#  ['스크랩'],
#  ['소매업자', '에게', '도매'],
#  ['입주자', '를', '위해'],
#  ['학생', '들', '을', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상'],
#  ['재생', '가능', '한', '고물', '수집'],
#  ['중학생', '대상', '으로'],
#  ['종합', '스포츠센터', '에서'],
#  ['학생', '들', '대상', '으로'],
#  ['전사', '하', '여', '제작'],
#  ['고객', '을', '대상', '으로'],
#  ['아파트', '입주자', '를', '위하', '여'],
#  ['일반인', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['절단', '용접', '가공', '하', '여'],
#  ['국가', '안보', '관련'],
#  ['노인', '성', '질환', '을', '앓', '고', '있', '는', '노인', '을', '입원', '시켜'],
#  ['일반', '대상'],
#  ['소비자', '에게'],
#  ['접객', '시설', '없이'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['절단', '가공'],
#  ['접객', '시설', '갖추', '고'],
#  ['접객', '시설', '갖추', '고'],
#  ['학생', '일반인', '을', '대상', '으로'],
#  ['상가', '등', '에'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['재생', '가능', '한', '고물', '수집'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['도움', '이', '필요', '한', '사람', '에게'],
#  [],
#  ['관련', '업체', '의뢰', '로'],
#  ['전자', '상거래'],
#  ['일반인', '을', '대상', '으로'],
#  ['수집', '하', '여'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['두', '발미', '용', '서비스'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['일반', '고객', '대상'],
#  ['건설업자', '에게'],
#  ['후처리'],
#  ['고객', '요구', '에', '따라'],
#  ['일반인', '대상', '으로', '소매'],
#  [],
#  ['금은방', '에서'],
#  ['조리', '하', '여'],
#  ['일반', '대상', '으로'],
#  ['소비자', '에게'],
#  ['고객', '의', '요청', '으로'],
#  ['일반', '소비자', '대상', '으로'],
#  ['수주', '를', '받', '아'],
#  ['일반', '소비자', '에게'],
#  ['방', '과', '후', '교재', '를', '주문', '받', '아'],
#  [],
#  ['절단', '가공'],
#  ['기독교', '계통', '종교', '활동'],
#  ...]

# %%
# test 데이터 토크나이징

mecab_test_text_obj = []
mecab_test_text_mthd = []
mecab_test_text_deal = []

mecab = Mecab()

for sentence in tqdm(test['text_obj']): # 진행상황 Progress Bar를 위한 tqdm library
    tokenized_sentence = mecab.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_test_text_obj.append(stopwords_removed_sentence)

for sentence in tqdm(test['text_mthd']): # 진행상황 Progress Bar를 위한 tqdm library
    tokenized_sentence = mecab.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_test_text_mthd.append(stopwords_removed_sentence)

for sentence in tqdm(test['text_deal']): # 진행상황 Progress Bar를 위한 tqdm library
    tokenized_sentence = mecab.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in list(stopwords)] # 불용어 제거
    mecab_test_text_deal.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 100000/100000 [00:04<00:00, 21685.03it/s]
# 100%|██████████| 100000/100000 [00:02<00:00, 38401.85it/s]
# 100%|██████████| 100000/100000 [00:02<00:00, 47631.84it/s]

# %%
mecab_test_text_mthd
# Out:
# [['고객', '의', '주문', '에', '의해'],
#  ['다른', '소매업자', '에게'],
#  ['신도', '을', '대상', '으로'],
#  ['고객', '요구', '로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['스크린', '인쇄'],
#  ['접객', '시설', '가지', '고'],
#  ['프레스', '가공', '하', '여', '제조'],
#  ['서비스', '센터', '에서'],
#  ['완성품', '입', '고', '수선'],
#  ['원재료', '입', '고', '반죽'],
#  ['일반인', '대상', '으로'],
#  ['고객', '의', '요구', '에', '따라'],
#  ['소아', '청소년', '을', '대상', '으로'],
#  ['사무실', '에서'],
#  ['일반', '고객', '대상'],
#  ['관련', '사용', '자', '에게'],
#  ['주문', '에', '의해'],
#  ['일반인', '대상'],
#  ['고객', '요청', '에', '의해'],
#  ['도금'],
#  [],
#  ['고객', '에', '의뢰', '를', '받', '아'],
#  ['일반인'],
#  ['나무', '를', '이용', '해'],
#  ['고객', '요구', '로'],
#  ['일반인', '을', '대상', '으로'],
#  ['고객', '의뢰', '로'],
#  ['계약', '및', '중개', '수수료', '받', '고'],
#  ['인터넷', '시설', '을', '갖추', '고'],
#  ['어린이', '들', '을', '대상', '으로'],
#  ['선', '별장', '에서'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['사업장', '에서'],
#  ['남성', '두', '발', '서비스'],
#  ['접객', '시설', '을', '갗', '추고'],
#  ['일반', '소비자', '대상', '으로'],
#  ['기술'],
#  ['원료', '투입', '압출'],
#  ['외래', '환자', '위주', '로'],
#  ['일반', '고객', '을', '대상', '으로'],
#  ['재단기', '사용'],
#  ['가정', '소비자', '에게', '소매'],
#  ['일반인', '을', '대상', '으로'],
#  ['업자', '를', '대상', '으로'],
#  ['철', '파이프', '보관'],
#  ['관광객', '을', '대상', '으로'],
#  ['판매장', '에서'],
#  ['인테리어'],
#  ['일반', '소비자', '에게'],
#  ['남성', '캐', '쥬얼'],
#  ['일반', '고객', '대상'],
#  ['제조', '및', '가공'],
#  [],
#  ['산업', '사용', '자', '에게'],
#  ['일반인', '대상', '으로', '세탁물', '수집', '세탁', '하', '여'],
#  ['회화', '또는', '시험', '활동', '을', '위해', '외국어', '강습'],
#  ['자재', '구입', '재단'],
#  ['재단', '재봉', '하', '여'],
#  ['고객', '의', '주문', '에', '따라'],
#  ['소매업자', '에게'],
#  ['고객', '의', '요구', '에', '따라'],
#  ['영업장', '에서'],
#  ['건축', '폐기물'],
#  ['계약', '을', '체결', '하', '여'],
#  ['자동차', '의', '전반', '적', '인'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['수산물'],
#  ['관할', '구역', '주민', '대상', '으로'],
#  [],
#  ['일반인', '을', '대상', '으로'],
#  ['고객', '의', '요청', '에', '의해'],
#  ['일반인', '을', '대상', '으로'],
#  ['서비스'],
#  ['고객', '대상'],
#  ['일반', '학생', '대상'],
#  ['즉석', '두부', '판매'],
#  ['남성', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상'],
#  ['소매업자', '소비자', '에게', '도', '소매'],
#  ['일반인', '대상'],
#  ['고객', '의', '요청', '에', '의해'],
#  ['일반', '소비자', '에게'],
#  ['일반인', '대상', '으로'],
#  ['일반인', '대상'],
#  ['개인'],
#  ['일반인'],
#  ['락', '생', '대상', '으로'],
#  ['자동차', '의', '특정', '부분', '수리'],
#  ['다른', '소매업자', '에게', '도매'],
#  ['사무실', '에서'],
#  ['주문', '제작'],
#  ['설계', '소재', '입', '고'],
#  ['신장', '장애', '인', '회원', '을', '대상', '으로'],
#  ['외래', '환자', '를', '대상', '으로'],
#  [],
#  ['소매업자', '에게', '도매'],
#  ['운영', '체제', '등의'],
#  ['고객', '의', '의뢰', '에', '의해'],
#  ['사업장', '에서'],
#  ['소매업자', '에게', '도매'],
#  ['차량', '가정용'],
#  ['소비자', '에게'],
#  ['중개', '등', '을', '통해'],
#  ['건물', '구조'],
#  ['농약', '예술', '단체'],
#  ['피부', '미용', '서비스', '제공'],
#  ['휴게소', '에서'],
#  ['의뢰', '받', '아'],
#  ['고객', '대상', '으로'],
#  ['외래', '환자', '를'],
#  ['고객', '으로부터', '자금', '조성', '및', '여', '수신'],
#  ['가정', '용', '세탁물', '을', '세탁'],
#  ['회원', '에', '친목도모', '및', '회원', '이익', '향상'],
#  ['고객', '요청', '에', '의해'],
#  ['일반인', '대상'],
#  [],
#  ['고객', '요구', '에', '따라'],
#  ['사업장', '에서'],
#  ['기계', '시설', '갖추', '고'],
#  ['로봇', '을', '조립', '하', '여'],
#  ['농업', '관련', '외국인'],
#  ['일반', '소비자', '에게'],
#  ['육지', '수산', '동물', '과실', '한약재', '를', '혼합'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['사료'],
#  ['고객', '요청', '에', '의해'],
#  ['꽃', '가게', '를', '대상', '으로'],
#  ['일반인', '대상'],
#  ['소비자', '를', '대상', '으로'],
#  ['농민', '을', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['조리', '해서', '배달'],
#  ['서비스업'],
#  ['일반', '고객', '대상', '으로'],
#  ['가정', '용', '의류', '를', '전문', '으로', '세탁', '하', '는', '산업'],
#  ['일반인', '대상'],
#  ['일반인', '대상'],
#  ['일반', '고객', '을', '대상', '으로'],
#  [],
#  ['고객', '에게'],
#  ['수강', '생', '을', '위한', '교육', '서비스'],
#  ['사업주', '를', '대상', '으로'],
#  ['고객', '의', '주문', '에', '의해'],
#  ['일반인', '대상', '으로'],
#  [],
#  ['접객', '시설', '을', '갖추', '고', '라면', '판매'],
#  ['쌀', '등', '식량', '작물'],
#  ['기관', '과', '계약', '을', '맺', '고'],
#  ['재단', '봉재', '하', '여'],
#  ['고등', '학생', '들', '에게'],
#  ['일반인', '을', '대상', '으로'],
#  ['두', '발미', '용'],
#  ['일반인', '대상', '으로', '소매'],
#  ['엔', '투', '베', '이킹', '번들', '포장'],
#  ['사업체', '에서'],
#  ['산업', '사용', '자', '에게'],
#  ['일반', '대중', '을', '대상', '으로'],
#  ['계약', '및', '중개', '수수료', '받', '음'],
#  ['고객', '의', '주문', '에'],
#  ['일반', '소비자', '에게'],
#  ['일반', '소비자', '에게'],
#  ['의뢰', '를', '받', '아'],
#  ['가공', '발굴', '하', '여', '도매', '소매', '판매'],
#  ['손님', '들', '에게'],
#  ['업체', '대상', '으로'],
#  ['접객', '시설', '갖추', '고'],
#  ['연사', '하', '여'],
#  ['학생', '들', '대상', '으로'],
#  ['소매업자', '에게'],
#  ['목재'],
#  ['고객', '을', '방문', '하', '여', '학습지', '를'],
#  ['인문', '계', '고등학교', '교육', '을'],
#  ['관련', '산업', '사용', '자', '대상', '으로'],
#  ['초등학생', '대상', '으로'],
#  [],
#  ['부동산', '에서'],
#  ['일반인', '에게'],
#  ['개별', '룸서비스', '없이', '일반은', '을', '대상', '으로'],
#  ['일반인', '대상', '으로', '소매'],
#  ['일반', '소비자', '에게', '소매'],
#  ['사업장', '내', '에'],
#  ['의뢰', '를', '받', '아'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '소비자', '을', '대상', '으로', '소매'],
#  ['일반', '대중', '기업', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['관련', '고객', '을', '대상', '으로'],
#  ['학생', '들', '에게', '교육'],
#  ['일반', '집', '건물'],
#  [],
#  ['운영', '체제', '등의'],
#  ['산업', '사용', '자', '에게'],
#  ['조립'],
#  ['대량', '으로', '도매'],
#  ['고객', '의', '요청', '에', '따라'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '상대', '로'],
#  ['무역', '도매'],
#  ['특정', '사회', '정치', '적', '대의', '를', '옹호', '하', '는', '시민운동', '단체'],
#  ['고객', '의', '요청', '에', '의해'],
#  ['머시닝', '센터'],
#  ['소매'],
#  ['일반인', '대상'],
#  ['고객', '을', '방문', '하', '여', '학습지', '를'],
#  ['일반인', '을', '대상', '으로'],
#  ['아파트', '입주자', '을', '위하', '여'],
#  ['일반', '소비자', '에게'],
#  ['계약', '및', '중개', '수수료'],
#  ['기계', '장비', '수리'],
#  ['의뢰', '받', '아'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['학생', '대상', '으로'],
#  ['음식점', '에서'],
#  ['고객', '의', '요청', '에', '따라'],
#  ['수입', '하', '여', '타사', '업체', '에'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '대상'],
#  ['과자', '도매'],
#  ['학생', '을', '대상', '으로'],
#  ['일반', '고객', '에게'],
#  ['표면', '처리', '인쇄'],
#  ['병', '의원', '상대', '로'],
#  ['청', '을', '제조'],
#  ['일반인'],
#  ['특수', '시설', '없이'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['오픈', '마켓', '등'],
#  ['절단', '절곡', '하', '여', '도매', '및', '소매'],
#  ['미술품', '공예품', '예술품', '판매'],
#  ['교육', '관련', '정보', '를', '구하', '는', '고객', '에게'],
#  [],
#  ['세무', '관련', '의뢰', '를', '받', '아'],
#  ['제작', '하', '여', '건물', '지붕', '으로', '사용', '되', '는', '채', '광판', '생산'],
#  ['고객', '대상'],
#  ['절단', '용접'],
#  ['완성품', '입', '고', '도장'],
#  ['재료', '입', '고', '설계', '재단'],
#  ['정밀', '기계', '로', '측정', '검사'],
#  ['어린이집', '에서'],
#  ['기독교', '신자', '대상', '으로'],
#  ['일반인', '대상', '으로', '세탁물', '을'],
#  ['사업체', '를', '대상', '으로', '조명', '기구', '램프', '등', '을', '판매'],
#  ['제련', '정련', '하', '여'],
#  ['고객', '을', '대상', '으로'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['고객', '의', '주문', '에', '의해'],
#  ['일반', '소비자', '에게'],
#  ['고객', '으로부터', '자금', '여', '수신'],
#  ['소비자', '에게'],
#  ['쌀', '을', '가공', '하', '여'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '을', '대상', '으로'],
#  ['전시관', '박물관', '시설물'],
#  ['절단', '용접'],
#  ['입주자', '를', '위하', '여'],
#  ['해외', '중국', '에서', '제조'],
#  ['고객', '의', '요청', '으로'],
#  ['사회', '적', '으로', '도움', '이', '필요', '한', '사람', '에게'],
#  ['일반', '학생', '을', '대상', '으로', '초', '중고'],
#  ['환자', '대상'],
#  ['불교', '계', '통의'],
#  ['칼국수', '판매', '함'],
#  ['관할', '구역', '주민', '에게'],
#  ['일반', '소비자', '에게'],
#  ['어린이', '들', '을', '대상', '으로'],
#  ['음식점', '에서'],
#  ['직영', '점', '에서'],
#  ['의뢰', '받', '아'],
#  ['전자', '상거래', '판매', '품목', '현재', '없', '음'],
#  ['소비자', '에게'],
#  ['신자', '를', '대상', '으로'],
#  ['고객', '요청', '으로'],
#  ['설계', '구매'],
#  ['설계', '도면'],
#  ['일반인', '에게'],
#  ['일반인', '대상', '으로'],
#  ['소매업자', '에게', '도매'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['소비자', '에게'],
#  ['일반', '소비자', '에게', '소매'],
#  ['접객', '시설', '없이', '일반', '소비자', '에게', '소매'],
#  ['소매'],
#  ['고객', '의', '요구', '에', '따라'],
#  ['서비스'],
#  ['일반', '고객', '에게'],
#  ['음식점', '에서'],
#  ['산업', '사용', '자', '를', '대상', '으로', '도매'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['의류', '재단', '하', '여'],
#  ['가정', '용', '의류'],
#  ['교육', '생', '대상', '으로'],
#  ['영업장', '에서'],
#  ['고객', '요청'],
#  ['도장', '공사'],
#  ['가공'],
#  ['컴퓨터', '인터넷', '이용', '하', '여'],
#  ['일반', '소비자', '대상', '으로'],
#  [],
#  ['외래', '환자', '를', '대상', '으로'],
#  ['유제품', '도매'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['판매'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['도배', '욕', '실리', '모델링'],
#  [],
#  ['주문', '설계'],
#  [],
#  ['임대', '를', '통하', '여'],
#  ['운영', '체제', '등', '의', '소프트웨어'],
#  ['일반', '소비자', '를', '상대', '로'],
#  ['동동', '까지'],
#  ['프로그램', '개발'],
#  ['병', '의원', '약국'],
#  ['일반', '고객', '을', '대상', '으로'],
#  ['일반인', '대상'],
#  ['자동차', '부품', '을', '교체'],
#  ['시장', '상인', '들', '의', '이익', '증진'],
#  ['일반인', '들', '에게'],
#  ['절곡', '조립', '하', '여'],
#  ['일반', '소비자', '의', '요청', '에', '의해'],
#  ['배합', '성형'],
#  ['일반인', '의', '의뢰', '를', '받', '아'],
#  ['외래', '환자', '위주', '로'],
#  ['접객', '시설', '가지', '고'],
#  ['고객', '요구', '로'],
#  ['김밥', '라면', '등'],
#  ['일반인', '대상'],
#  ['사업장', '에서'],
#  ['광고', '문건', '작성'],
#  ['일반', '사무실', '을', '대상', '으로'],
#  ['초등학생', '대상'],
#  ['불교', '계통', '의', '종교', '서비스'],
#  ['영업장'],
#  ['계약', '을', '통하', '여'],
#  ['부동산', '중개', '부동산', '컨설팅'],
#  ['소프트웨어'],
#  ['산업', '사용', '자', '에게'],
#  ['계약', '및', '중개업', '의', '수수료', '받', '음'],
#  ['수강', '생', '을', '위한'],
#  ['목재', '재료', '절단'],
#  ['화물', '운송', '중개'],
#  ['무역', '도매'],
#  ['장애', '인', '대상', '으로'],
#  ['조합원', '및', '일반', '고객', '을', '대상', '으로'],
#  ['고객', '요청'],
#  ['고객', '요구', '에', '따라'],
#  ['약국', '에서'],
#  ['태양광', '발전', '시설'],
#  ['상가', '등'],
#  ['고객', '요청', '에', '의해'],
#  ['일반', '고객', '대상'],
#  ['수집', '하', '여'],
#  ['본사', '에서'],
#  ['일반인', '대상', '으로'],
#  ['건물', '임대'],
#  ['디지털', '서비스', '관련', '의뢰', '받', '아', '데이터', '분석', '등', '애널리스트', '작업', '함'],
#  ['노인', '대상'],
#  ['소프트웨어', '개발'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['소화물', '운송'],
#  ['산업', '사용', '자', '에게'],
#  ['안보', '관련', '지역', '안보', '교육'],
#  ['의뢰', '를', '받', '아'],
#  ['일반', '소비자', '에게'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상', '으로'],
#  ['고객', '의', '요구', '에', '따라'],
#  ['일반', '소비자', '에게'],
#  ['일반', '소비자'],
#  ['고객', '으로부터', '자금', '조성', '및', '여', '수신'],
#  ['매장', '에서'],
#  [],
#  ['컴퓨터'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['중고생', '대상', '수업'],
#  ['석재', '를', '절단', '및', '성형', '가공'],
#  ['관련', '고객', '을', '대상', '으로'],
#  ['고객', '의', '요청', '에', '의해'],
#  ['임차', '임대인', '을', '대리', '하', '여'],
#  ['고객', '의', '요구', '에', '따라'],
#  ['고객', '의', '요청', '에', '의해'],
#  ['기자재', '를', '갖추', '고'],
#  ['일반인', '대상', '으로'],
#  ['화주', '의', '요청', '에', '의해'],
#  ['승객', '을', '운송'],
#  ['제조업'],
#  ['수입', '하', '여', '판매'],
#  ['운영', '체제', '등', '의', '시스템'],
#  ['전기', '아연', '도금', '수세', '흑', '세', '백세'],
#  ['고객', '의', '주문', '요청', '에', '의해'],
#  ['의뢰', '받', '아'],
#  ['도로공사'],
#  [],
#  [],
#  ['접객', '요원', '없이'],
#  ['외래', '환자', '및', '입원', '환자'],
#  ['일반', '소비자', '에게'],
#  ['원자재', '입', '고', '코팅'],
#  ['교육', '용', '콘텐츠'],
#  ['소비자', '를', '대상', '으로'],
#  ['매장', '에서'],
#  ['고객', '으로부터', '자금', '조성', '및', '여', '수신'],
#  ['제조'],
#  ['매장', '에서'],
#  ['일반인', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['목재', '절단'],
#  ['고객', '의', '요구'],
#  ['건설', '기계', '를'],
#  ['일반', '소비자', '에게'],
#  ['개별', '룸서비스', '없이', '일반', '이', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '의', '요청', '에', '따라'],
#  ['도', '소매'],
#  ['일반', '대중', '및', '기업', '대상', '으로'],
#  ['도', '소매'],
#  [],
#  ['온라인', '상', '에서'],
#  ['여성', '의류', '소매'],
#  ['일반', '고객', '을', '대상', '으로'],
#  ['쇼트', '세척'],
#  ['일반', '소비자', '를', '대상'],
#  ['일반인', '대상', '으로', '소매'],
#  ['일반인', '을', '대상', '으로'],
#  ['정형', '후', '옷', '칠'],
#  ['일반인', '학생', '들', '을', '대상', '으로'],
#  ['고객', '의', '요구', '에', '따라'],
#  ['인쇄', '코팅'],
#  ['생지', '입', '고', '정련'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['절단', '조립'],
#  [],
#  ['고객', '의', '요청', '에', '따라'],
#  ['고객', '요구', '에', '따라'],
#  ['원료', '투입', '사출', '성형'],
#  ['건물', '모형'],
#  ['가공', '하', '여', '주문', '제작'],
#  [],
#  ['고객', '의', '주문', '으로'],
#  ['소매업자', '에게', '도매'],
#  ['제관', '용점'],
#  ['종이', '잉크'],
#  ['수강', '생', '대상', '으로'],
#  ['고객', '대상'],
#  ['입', '고', '검사'],
#  ['재단', '및', '재봉', '하', '여'],
#  ['사업체', '의', '요구', '에', '따라'],
#  ['임대', '를', '통하', '여'],
#  ['소비자', '대상', '으로'],
#  ['고객', '의', '의뢰', '을', '받', '아'],
#  [],
#  ['분쇄', '가공', '하', '여'],
#  ['소매업자', '에게', '도매'],
#  ['과수', '농민', '들', '에게', '판매'],
#  ['고등', '학생', '을', '대상', '으로'],
#  ['고객', '대상'],
#  ['구두', '류', '제조'],
#  ['과실', '류', '저장', '하', '여'],
#  ['금속제', '를', '조립', '제작'],
#  ['학생', '들', '에게', '교육', '서비스'],
#  ['보디빌딩', '회원'],
#  [],
#  ['외래', '환자', '위주', '로'],
#  ['일반', '고객', '에게'],
#  ['사업장', '에서'],
#  ['인쇄'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['소매업'],
#  ['매장', '면전', '제곱', '미터', '시설', '을', '갖추', '고'],
#  ['소비자', '를', '대상'],
#  ['성형'],
#  ['기계', '자', '수하', '여자', '수제품', '생산'],
#  ['도매', '소매'],
#  ['신체', '부자유', '장애', '우', '을', '의뢰', '를', '받', '아'],
#  ['일반', '소비자', '를', '대상'],
#  ['사업체', '의뢰', '받', '아'],
#  ['고객', '에게'],
#  ['일반인', '을', '대상'],
#  ['학생', '교육', '서비스'],
#  ['일반', '소비자', '상대', '로'],
#  ['검사', '자재', '분류'],
#  ['일반인', '을', '대상', '으로'],
#  ['스크린', '인쇄'],
#  ['사진관', '에서'],
#  ['관리', '실', '에서'],
#  ['장애', '인', '대상', '으로'],
#  ['계약', '빛', '중개', '등', '을', '통해', '수수료', '받', '음'],
#  ['일반인', '대상', '으로'],
#  ['설계', '를', '기초', '로', '하', '여', '자동', '화', '기계', '제조'],
#  ['어린이', '들', '을', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['사업장', '에서'],
#  ['일반인', '대상', '으로'],
#  ['태양광'],
#  ['고객', '요구', '에', '따라'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '고객'],
#  ['사업주', '를', '대상', '으로'],
#  ['의뢰', '를', '받', '아'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '소비자', '에게', '소매'],
#  ['수리'],
#  ['고객', '요청', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '학생', '을', '대상', '으로'],
#  ['학생', '들', '을', '대상', '으로', '교육'],
#  ['인쇄물', '코팅', '하', '여'],
#  ['일반인', '대상'],
#  ['준비', '접착제', '도포'],
#  ['소비자', '대상', '으로'],
#  ['고객', '의', '요청', '에', '의해'],
#  ['고객', '을', '대상', '으로'],
#  ['대부'],
#  ['수강', '학생', '들', '대상', '으로'],
#  ['절단', '절곡', '가공'],
#  ['일반인', '에게'],
#  ['주문', '에', '의해'],
#  [],
#  ['일반', '고객', '대상'],
#  ['일반', '소비자', '에게'],
#  ['고객', '의뢰', '로'],
#  ['소매업자', '대상', '으로'],
#  ['가공', '하', '여'],
#  ['일반', '소비자', '에게'],
#  ['철판', '을', '절단', '용접'],
#  ['일반', '소비자', '대상', '으로'],
#  ['일반인', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['미용', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상'],
#  ['매장', '에서'],
#  ['고객', '의', '요청', '에', '따라'],
#  ['일반', '소비자', '에게'],
#  ['배합', '분산'],
#  ['고객', '의', '요청', '으로'],
#  ['일반', '소비자', '에게'],
#  ['서비스', '교육', '관련', '업'],
#  [],
#  ['일상', '생활', '에', '지장', '이', '없', '는', '노인', '을', '입소', '시켜'],
#  [],
#  ['케이블', '프로그램', '제작'],
#  ['도매'],
#  ['의뢰', '를', '받', '아'],
#  ['사업장', '에서'],
#  ['가공'],
#  ['산업', '사용', '자', '에게'],
#  ['접객', '시설'],
#  ['일반인', '대상'],
#  ['상가', '를'],
#  ['일반인', '을', '대상', '로'],
#  ['일반인', '대상', '으로'],
#  ['신자', '를', '대상'],
#  ['화물', '운송'],
#  ['고객', '의', '요청', '에', '따라'],
#  ['입주자', '를', '위하', '여'],
#  ['상가', '입주자', '를', '위하', '여'],
#  ['미술품', '을', '가지', '고'],
#  ['소매업자', '에게'],
#  ['임차인', '에게'],
#  ['성형', '열처리'],
#  ['소매'],
#  ['소매업자', '에게'],
#  ['설계', '모형', '제작'],
#  ['절단', '절곡', '하', '여'],
#  ['기러기'],
#  [],
#  ['어린이', '들', '을', '위한'],
#  ['아동', '대상', '으로'],
#  ['고객', '의', '요청', '에', '의해'],
#  ['소매업자', '대상', '으로'],
#  ['국민은행', '국민카드', '제반', '업무', '지원'],
#  ['주민', '대상', '으로'],
#  ['일반', '고객', '을', '대상', '으로'],
#  ['일반', '사업장', '을', '상대', '로'],
#  ['월간', '으로'],
#  ['일반', '소비자', '에게', '소매'],
#  ['배관', '및', '냉난방', '공', '사업', '배관'],
#  ['유치', '부초', '등', '학생', '을', '대상', '으로'],
#  ['어린이', '를', '대상', '으로'],
#  ['일반인', '대상'],
#  ['고물상', '에서'],
#  ['철판', '가공'],
#  ['절', '단절', '합하', '에'],
#  ['학생', '들', '을', '대상', '으로'],
#  ['분쇄', '미싱', '성형', '하', '여', '떡', '제조'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['초등', '학교', '과정', '을', '수료', '한', '사람', '의', '교육', '을'],
#  ['일반', '소비자', '에게'],
#  ['상가'],
#  ['직물', '을', '재단', '봉재'],
#  ['사업장', '에서'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['사업장', '에서'],
#  ['개별', '룸서비스', '없이', '일반인', '대상', '으로'],
#  ['제단', '절단'],
#  ['고객', '을', '대상', '으로'],
#  ['일반인', '을', '대상', '으로'],
#  ['다른', '소매업자', '에게', '도매'],
#  ['접객', '시설', '갖추', '고'],
#  ['사회', '적', '으로', '도움', '이', '필요', '한', '사람', '에게'],
#  ['가정', '의', '세탁물', '을', '수집', '세탁'],
#  ['접객', '시설', '가', '자', '추', '고'],
#  ['일반인', '대상'],
#  ['입주자', '를', '위하', '여'],
#  ['도배장판', '등', '인테리어', '공사'],
#  ['계약'],
#  ['광고', '대행'],
#  ['입주', '업체', '를', '대상', '으로'],
#  ['장애', '인', '대상', '으로'],
#  ['매장', '에서'],
#  ['노인', '대상'],
#  ['안전', '용구', '판매점', '에서'],
#  ['자기', '계정', '으로'],
#  ['고객', '대상'],
#  ['꽃집', '에', '도매'],
#  ['드림', '스타트', '에서'],
#  ['장애', '인', '대상'],
#  ['도매', '및', '소매업'],
#  ['사진', '이나', '비디오', '를', '일반인', '에게'],
#  ['일반', '고객', '대상'],
#  ['주민', '들', '을', '위하', '여'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반', '소비자', '에서'],
#  ['고객', '의', '요청', '에', '따라'],
#  ['일반인', '대상', '으로'],
#  ['임대', '대여'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['업체', '에서'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['여객', '및', '화물', '을', '운송'],
#  ['산업', '사용', '자', '에게'],
#  ['일반인', '대상', '으로'],
#  ['설계', '제작', '설치'],
#  ['일반', '고객', '대상'],
#  ['주방', '가구', '제조'],
#  [],
#  ['학생', '및', '일반인', '대상'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['일반', '고객', '에게'],
#  ['멸치', '를', '조리', '하', '여'],
#  ['소개', '수수료', '를', '받', '고'],
#  ['고객', '대상'],
#  ['매장'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['가구', '매장', '에서'],
#  ['지하수'],
#  ['수집', '분리'],
#  ['사업장', '에서'],
#  ['일반인', '에게'],
#  ['사업자', '에게'],
#  [],
#  ['서비스'],
#  ['공용', '부', '시설', '관리'],
#  ['원재료', '프레스'],
#  ['고객', '을', '대상', '으로'],
#  ['대상', '업체', '에'],
#  ['재료', '혼합', '숙성'],
#  ['제조업'],
#  ['사업장', '에서'],
#  ['수입', '하', '여', '판매'],
#  ['체인', '계약', '하', '고', '소비자', '에게'],
#  ['소매업자', '대상', '으로'],
#  ['고객', '의', '요청', '에', '따라'],
#  ['다', '이', '캐스팅', '공법', '으로'],
#  ['일반', '소비자', '들', '에게'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반', '소비자', '에게', '소매'],
#  ['일반', '가정', '을', '방문', '하', '여'],
#  ['악기', '를', '도', '소매'],
#  ['교육', '기관', '및', '민간', '인', '대상'],
#  ['온라인'],
#  ['어르신', '대상', '으로'],
#  ['일반', '소비자', '에게'],
#  ['운전자', '와', '함께'],
#  ['일반인', '대상', '으로'],
#  [],
#  ['일반인', '대상', '으로'],
#  ['약초'],
#  ['고객', '의', '요청', '으로'],
#  ['소매업자', '에게'],
#  ['일반', '소비자', '를', '대상', '으로'],
#  ['영업소', '에서'],
#  ['계약', '중개', '수수료', '받', '음'],
#  ['인쇄', '후', '가공'],
#  ['제조', '활동', '하', '는', '산업체', '에'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['가공', '하', '여'],
#  ['버스', '사고', '시', '보험', '처리'],
#  ['고객', '의', '주문', '에', '의해'],
#  ['환자', '대상'],
#  [],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['외국', '항로', '에'],
#  ['기관', '과', '의', '계약', '으로'],
#  ['일반', '소비자', '에게', '소매'],
#  ['장애', '인', '대상'],
#  ['학생', '일반인', '등', '에게'],
#  ['고객', '의', '요청', '에', '따라'],
#  ['관련', '산업', '사용', '자', '에게'],
#  ['일반인', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['중학생', '을', '대상', '으로'],
#  ['중고', '가전제품', '수리'],
#  ['일반인', '들', '에게'],
#  ['의뢰', '인', '대상', '으로'],
#  ['입', '고', '사출'],
#  ['일반인', '을', '대상'],
#  ['일반', '고객', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상', '으로'],
#  ['섬유', '직물', '직조'],
#  ['고객', '에게'],
#  ['일반인', '들', '에게'],
#  ['고객', '의뢰', '로'],
#  ['한', '약제', '직접', '처방', '하', '여'],
#  ['입', '고', '사출'],
#  ['소매업자', '대상', '으로'],
#  ['일반인', '들', '에게'],
#  ['도매', '및', '소매업'],
#  ['상가', '사무실'],
#  ['기계', '부품'],
#  ['구획', '경지', '정리', '시', '의뢰', '받', '아'],
#  ['입', '고', '수세', '피막'],
#  ['일반', '소비자', '에게'],
#  ['외래', '환자', '들', '에게'],
#  ['도매'],
#  ['일반', '학생', '을', '대상', '으로'],
#  ['고객', '요구', '에', '따라', '철근', '시멘트', '이용'],
#  ['체', '렬단련시설을갖추고'],
#  ['일반', '소비자'],
#  ['일반인', '들', '에게'],
#  ['고객'],
#  ['매트', '를', '매장', '에서', '소매', '로', '판매'],
#  ['승객', '수송'],
#  ['소비자', '에게'],
#  ['제조'],
#  ['고객', '을', '상대', '로'],
#  ['인쇄', '상표', '작업', '된', '종이', '를', '접착', '후'],
#  ['원재료', '매입', '원재료', '가공'],
#  ['제조'],
#  ['일반', '고객'],
#  ['기름', '제', '조기', '등', '시설', '을', '갖추', '고'],
#  ['영업'],
#  ['일반', '소비자', '대상', '으로'],
#  ['고객', '을', '대상', '으로'],
#  ['계약', '중개', '수수료'],
#  ['도매', '및', '소매업'],
#  ['프레스', '가공', '재단'],
#  ['여성', '의류', '소매'],
#  ['일반인', '대상', '으로'],
#  ['실크', '인쇄'],
#  ['제조업'],
#  ['비', '거주', '용', '임대', '사무실', '오피스텔'],
#  ['일반인', '대상', '으로'],
#  ['지하철', '중계기', '관리'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고철', '을'],
#  ['절단', '절곡', '드릴', '가공', '하', '여'],
#  ['건축', '관련'],
#  ['학생', '들', '을'],
#  ['도매'],
#  ['의뢰', '를', '받', '아'],
#  ['고객', '대상'],
#  ['주야간', '센터', '에'],
#  ['일반인', '대상', '으로', '수거'],
#  ['교육', '컨설팅'],
#  ['학생', '대상'],
#  ['입', '고', '융', '해'],
#  ['소비자', '에게'],
#  ['일반', '소비자', '대상'],
#  ['병', '의원', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['외래', '환자', '에게'],
#  ['거래처', '에', '도매'],
#  ['외래', '환자', '위주', '로'],
#  [],
#  ['소매상인', '에게', '도매'],
#  ['일반', '고객', '대상'],
#  [],
#  ['일반인', '대상'],
#  ['절단', '절곡', '프레스', '용접', '도색', '출하'],
#  ['어린이', '대상'],
#  ['홈', '인테리어'],
#  ['학생', '들', '에게'],
#  ['혼합', '반죽'],
#  ['일반인', '을', '대상', '으로'],
#  ['고객', '의뢰', '에', '따라'],
#  ['접객', '시설', '갖추', '고'],
#  ['일반', '소비자', '대상', '으로'],
#  ['콘솔', '게임', '소프트웨어', '개발'],
#  ['학교', '관공서'],
#  ['도', '소매'],
#  ['상가', '입주자', '를', '위해'],
#  ['고객', '요청', '에', '따라'],
#  ['고객', '의뢰', '로'],
#  ['일반인', '에게'],
#  ['보관', '업무'],
#  ['외래', '환자', '위주'],
#  ['유치', '부초', '등', '학생', '을', '대상', '으로'],
#  ['일반', '소비자', '들', '에게'],
#  ['사업장', '에서'],
#  ['일반', '소비자', '대상', '으로'],
#  ['일반', '대중'],
#  ['악세사리', '를'],
#  ['고객', '의', '요청', '에', '따라'],
#  ['가공', '하', '여'],
#  ['식품', '비누', '방향제', '생산'],
#  ['아파트', '유지', '보수'],
#  ['일반', '소비자', '에게'],
#  ['사업장', '에서'],
#  ['의뢰', '를', '받', '아'],
#  ['포스터', '분배'],
#  ['일반인', '대상'],
#  ['사진', '촬영'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '대상'],
#  ['농업', '사무', '집행'],
#  ['고객', '의', '요구', '에', '따라'],
#  ['일반인', '을', '대상', '으로'],
#  ['일반인', '대상'],
#  ['일반인', '을', '대상', '으로'],
#  ['전세월', '세', '매매', '를', '통해'],
#  ['고객', '의', '요청', '에', '의해'],
#  ['일반', '소비자', '에게'],
#  ['항공', '기업체', '를', '대상', '으로'],
#  ['다이케', '스팅'],
#  ['주택', '등', '을'],
#  ['자동차', '의', '특정', '부분', '을', '전문', '적', '으로', '수리'],
#  ['조세', '세무', '관련', '업무', '를', '의뢰', '를', '받', '아서'],
#  ['환자', '대상'],
#  ['일반인', '대상', '으로', '두', '발미', '용', '서비스'],
#  ['일반인', '들', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['자동차', '의', '특정', '부분', '을', '전문', '적', '으로', '수리'],
#  ['소비자', '에게', '소매', '로'],
#  ['의뢰인', '에게'],
#  ['불교', '계통', '의', '종교', '활동'],
#  ['일반인', '을', '대상', '으로'],
#  ['건물', '및', '구축물'],
#  ['강의'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['수집', '하', '여'],
#  ['재단', '봉재'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반', '소비자', '에게', '소매'],
#  ['일반인', '대상', '으로'],
#  ['일반인', '대상', '으로'],
#  ['자동차'],
#  ['철판'],
#  ['일반인', '대상', '으로'],
#  ['도', '소매'],
#  ['절', '단절', '합', '하', '여'],
#  ['고객', '의', '의뢰', '를', '받', '아'],
#  ['일반', '소비자', '에게'],
#  ['소매업자', '를', '대상', '으로', '도매'],
#  ['여객', '및', '화물', '을', '대상', '으로'],
#  ['일반', '소비자', '를', '대상'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['고객', '의', '요구', '에', '따라'],
#  ['타발'],
#  ['소비자', '대상', '으로'],
#  ['고객', '요청', '에', '따라'],
#  ['고객', '의', '요청', '에', '따라'],
#  ['일반', '인', '게', '게'],
#  [],
#  ['사업장', '에서'],
#  ['체인', '계약', '을', '체결', '하', '여'],
#  ['관련', '고객', '을', '대상', '으로'],
#  ['접객', '시설', '을', '갖추', '고'],
#  [],
#  ['일반인', '대상', '으로'],
#  ['가공', '후', '조립'],
#  ['사무실', '이', '용자', '를', '위하', '여'],
#  ['화물', '운수업자', '와', '화주'],
#  ['고객', '요구', '에', '따라'],
#  ['원재료', '재단'],
#  ['제조', '하', '여'],
#  ['다른', '도매업자', '에게', '소매'],
#  ['일반', '고객', '을', '대상', '으로'],
#  ['일반인', '을', '대상'],
#  ['소매업'],
#  ['일반인', '에게'],
#  ['제조'],
#  ['인터넷', '으로'],
#  ['업체', '의뢰', '를', '받', '아'],
#  [],
#  ['태양광', '발전'],
#  ['일반', '대중', '과', '업체', '를', '대상', '으로'],
#  ['일반', '고객', '에게'],
#  ['오토바이', '부품', '제조', '판매'],
#  ['일반', '소비자', '에게'],
#  ['학생', '대상'],
#  ['학생', '를', '대상', '으로'],
#  ['물류', '운송'],
#  ['접객', '시설', '갖추', '고'],
#  ['절단', '밴', '딩', '하', '여'],
#  ['산업', '사용', '자', '에게'],
#  ['의뢰', '를', '받', '아'],
#  ['일반', '인상', '대로'],
#  ['일반인', '을', '대상', '으로'],
#  ['고객', '대상'],
#  ['일반인', '대상'],
#  ['한우', '국밥', '전문점'],
#  ['장례식장', '에서'],
#  ['유리', '소매'],
#  ['시행', '사', '요청', '으로'],
#  ['산업', '사용', '자', '에게'],
#  ['초벌', '페인팅'],
#  ['틀', '을', '만들', '어'],
#  ['가게', '에서'],
#  ['제조', '소매'],
#  ['고객', '의', '요구', '에', '따라'],
#  ['전기', '배선', '공사'],
#  ['일반', '소비자', '에게', '소매'],
#  ['유치원', '학생', '을', '대상', '으로'],
#  ['일반', '시민', '을', '대상', '으로'],
#  ['고객', '의', '요청', '으로'],
#  ['전공', '분야', '에', '관한'],
#  ['친목도모', '향상'],
#  ['일반', '고객', '대상'],
#  ['산업', '사용', '자', '에게'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['진공', '용해'],
#  ['일반', '소비자', '에게'],
#  ['고객', '대상'],
#  ['소개', '수수료', '를', '받', '고'],
#  ['일반', '소비자', '에게'],
#  ['수선', '장비', '를', '갖추', '고'],
#  ['지류', '입', '고', '접착'],
#  ['조립'],
#  ['대안', '교육', '복지'],
#  ['화물', '장비'],
#  ['음향', '기계'],
#  ['콘텍트', '렌즈', '를', '수출', '하', '여'],
#  ['사진', '촬영', '시설', '을', '갖추', '고'],
#  ['산업', '공단', '조성', '시'],
#  ['학생', '일반인', '등', '에게', '교육', '서비스'],
#  ['소매업자', '에게', '도매'],
#  ['고객', '요청', '에다', '라'],
#  ['제작', '조립'],
#  ['업체', '를', '대상', '으로'],
#  ['학생', '들', '을', '대상', '으로'],
#  ['도', '소매'],
#  ['학생', '들', '에게'],
#  ['일반', '소비자', '에게'],
#  ['일반', '고객', '대상'],
#  ['영상', '장비', '등', '으로'],
#  ['고객', '요구', '에', '따라'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['선반', '밀링'],
#  ['고객', '의', '요청', '에', '따라'],
#  ['만화책', '대여'],
#  ['의뢰'],
#  ['일반', '소비자', '에게', '소매'],
#  ['학생', '대상'],
#  ['일반', '고객', '대상'],
#  ['구두', '류', '제조'],
#  ['영업장', '에서'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['접객', '시설', '을', '갖추', '고'],
#  ['일반인', '대상', '으로'],
#  ['원두', '내려서'],
#  ['절단', '제재', '하', '여', '갖', '재', '제조'],
#  ['의뢰', '받', '은', '의류'],
#  ['건축물', '현장', '에서', '설치', '시공'],
#  ['일반인', '대상'],
#  ['고객', '대상'],
#  ['장애', '인', '대상'],
#  [],
#  ['영남', '향우', '회원', '들', '을', '위해'],
#  ['절단', '절', '합', '하', '여'],
#  ['언어', '치료', '센타', '에서'],
#  ['환자', '를', '위하', '여'],
#  ['산업', '사용', '자', '에게'],
#  ['공연장', '운영'],
#  ['부기', '안료'],
#  ['고객', '의', '주문', '으로'],
#  ['일반인', '에게', '소매'],
#  ['육계', '농장'],
#  ['서비스', '쎈', '타', '에서'],
#  ['환자', '대상', '으로'],
#  ['의뢰', '을', '받', '아'],
#  ['일반', '소비자', '에게', '소매'],
#  ['일반인', '대상', '으로'],
#  ['절단', '가공'],
#  ['고객', '요청', '에', '따라'],
#  ['일반인', '대상'],
#  ['상가', '업체', '들', '의'],
#  [],
#  ['여성', '정장', '의류', '소매'],
#  ['접객', '시설', '갖추', '고'],
#  ...]

# %%
train['text'] = mecab_train_text_obj
train['text'] = train['text'] + mecab_train_text_mthd
train['text'] = train['text'] + mecab_train_text_deal
# Out:
# C:\Users\Huitaek\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:69: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return op(a, b)

# %%
test['text'] = mecab_test_text_obj
test['text'] = test['text'] + mecab_test_text_mthd
test['text'] = test['text'] + mecab_test_text_deal

# %%
train.to_csv('./train_user_dictionary.csv', index=False, encoding='CP949')

test.to_csv('./test_user_dictionary.csv', index=False, encoding='CP949')
